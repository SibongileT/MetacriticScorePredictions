# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time, os
from time import sleep
from random import randint
import re
import json
from fake_useragent import UserAgent
import math

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}
pages = np.arange(1980,1982)
nom = []
imdb_ids=[]
#Get all the raw title ids
for page in pages:
    url = 'https://www.imdb.com/event/ev0000003/'+str(page)
    response = requests.get(url,headers=user_agent).text
    data = json.loads( re.findall(r'IMDbReactWidgets\.NomineesWidget\.push.*?(\{.*\})', response)[0] )

    #print(json.dumps(data, indent=4)) # <-- comment this out to print all data

    award_dict = {}
    for award in data['nomineesWidgetModel']['eventEditionSummary']['awards']:
        if award['awardName'] != 'Oscar':
            continue
        for title in award['categories']:
            category_name = title['categoryName']
            award_dict[category_name] = []
            noms = title['nominations']
            #category_names.append(category_name)
            for nom in noms:
                if len(nom['secondaryNominees'])!=0:
                    id_ = nom['secondaryNominees'][0]['const'] 
                id_2 = nom['primaryNominees'][0]['const']
                award_dict[category_name].append(id_)
                award_dict[category_name].append(id_2)
    sleep(randint(2,10))
nom.append(award_dict)
# Out:
# {
#     "nomineesWidgetModel": {
#         "title": "",
#         "description": "",
#         "refMarker": "ev_nom",
#         "eventEditionSummary": {
#             "awards": [
#                 {
#                     "awardName": "Oscar",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": "Best Actor in a Leading Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Dustin Hoffman",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTc3NzU0ODczMF5BMl5BanBnXkFtZTcwODEyMDY5Mg@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 298,
#                                             "const": "nm0000163"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Kramer vs. Kramer",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNDM3YjNlYmMtOGY3NS00MmRjLWIyY2UtNDA0MWM3OTNlZTY2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 869,
#                                             "imageWidth": 566,
#                                             "originalName": null,
#                                             "const": "tt0079417"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057073",
#                                     "characterNames": [],
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Al Pacino",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 266,
#                                             "const": "nm0000199"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "And Justice for All",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMDk1MTljZjAtZDY5MC00YTAwLTk5MzEtZTMyMjI4YzRmZjcxXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_.jpg",
#                                             "imageHeight": 1200,
#                                             "imageWidth": 786,
#                                             "originalName": "...and justice for all.",
#                                             "const": "tt0078718"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057075",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jack Lemmon",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTE5NTE3ODE1N15BMl5BanBnXkFtZTYwOTU1MTM2._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 323,
#                                             "const": "nm0000493"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The China Syndrome",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTY5YTdhODktMWUwMC00MDE1LWI1NmUtZWUyYzU3M2NiNWY2XkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 969,
#                                             "imageWidth": 645,
#                                             "originalName": null,
#                                             "const": "tt0078966"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057074",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Peter Sellers",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTI0MjE1MjczMF5BMl5BanBnXkFtZTYwMDIxNTQ2._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 369,
#                                             "const": "nm0000634"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Being There",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BY2JkZTcxYjEtNmUwNi00MjIzLWE1YjUtMDYzNWJjYWQwMzA5XkEyXkFqcGdeQXVyNzM0MTUwNTY@._V1_.jpg",
#                                             "imageHeight": 1828,
#                                             "imageWidth": 1200,
#                                             "originalName": null,
#                                             "const": "tt0078841"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057077",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Roy Scheider",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTA2ODY5ODg4OTdeQTJeQWpwZ15BbWU2MDUzOTM3Nw@@._V1_.jpg",
#                                             "imageHeight": 471,
#                                             "imageWidth": 312,
#                                             "const": "nm0001702"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "All That Jazz",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZWE4N2JkNDUtZDU4MC00ZjNhLTlkMjYtOTNkMjZhMDAwMDMyXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg",
#                                             "imageHeight": 755,
#                                             "imageWidth": 511,
#                                             "originalName": null,
#                                             "const": "tt0078754"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057076",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actor in a Supporting Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Melvyn Douglas",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjA5MDMxMDAxMV5BMl5BanBnXkFtZTYwODg1NDQ2._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 351,
#                                             "const": "nm0002048"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Being There",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BY2JkZTcxYjEtNmUwNi00MjIzLWE1YjUtMDYzNWJjYWQwMzA5XkEyXkFqcGdeQXVyNzM0MTUwNTY@._V1_.jpg",
#                                             "imageHeight": 1828,
#                                             "imageWidth": 1200,
#                                             "originalName": null,
#                                             "const": "tt0078841"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": "Melvyn Douglas was not present at the awards ceremony. Co-presenter Liza Minnelli accepted the award on his behalf.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057083",
#                                     "characterNames": [],
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Frederic Forrest",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjAzNDIyMDQwN15BMl5BanBnXkFtZTYwMzM5NzE1._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 262,
#                                             "const": "nm0002078"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Rose",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZGNiM2I2YTMtMjEwOS00ZjYyLTliZmMtN2E2NWVhZGQxMzExXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg",
#                                             "imageHeight": 1157,
#                                             "imageWidth": 797,
#                                             "originalName": null,
#                                             "const": "tt0079826"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057085",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Justin Henry",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTgzOTk3NjQ3MF5BMl5BanBnXkFtZTYwMDI1NzU0._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 277,
#                                             "const": "nm0377888"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Kramer vs. Kramer",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNDM3YjNlYmMtOGY3NS00MmRjLWIyY2UtNDA0MWM3OTNlZTY2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 869,
#                                             "imageWidth": 566,
#                                             "originalName": null,
#                                             "const": "tt0079417"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": "At age 8 years, 10 months and 20 days, Henry is (to date) the youngest nominee for any competitive honor in Academy Award history.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057086",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Mickey Rooney",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTU5NjA4MDU0MV5BMl5BanBnXkFtZTYwMDI0MzQ2._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 296,
#                                             "const": "nm0001682"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Black Stallion",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMzgzOTgwOTEzM15BMl5BanBnXkFtZTcwMzI2MTcyNA@@._V1_.jpg",
#                                             "imageHeight": 1023,
#                                             "imageWidth": 682,
#                                             "originalName": null,
#                                             "const": "tt0078872"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057087",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Robert Duvall",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjk1MjA2Mjc2MF5BMl5BanBnXkFtZTcwOTE4MTUwMg@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 286,
#                                             "const": "nm0000380"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Apocalypse Now",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMDdhODg0MjYtYzBiOS00ZmI5LWEwZGYtZDEyNDU4MmQyNzFkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_.jpg",
#                                             "imageHeight": 2362,
#                                             "imageWidth": 1575,
#                                             "originalName": null,
#                                             "const": "tt0078788"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057084",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actress in a Leading Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Sally Field",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTQwOTMyMDI4MV5BMl5BanBnXkFtZTcwMDYzMTM5OA@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1492,
#                                             "const": "nm0000398"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Norma Rae",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BYjk0NDRjMzctNjkwMS00ODYwLWFkZDEtYjFjODE3ZTk3OGY5XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_.jpg",
#                                             "imageHeight": 1440,
#                                             "imageWidth": 960,
#                                             "originalName": null,
#                                             "const": "tt0079638"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057078",
#                                     "characterNames": [],
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Bette Midler",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTIyNjU3NDYyMl5BMl5BanBnXkFtZTcwODUyNjY0MQ@@._V1_.jpg",
#                                             "imageHeight": 600,
#                                             "imageWidth": 410,
#                                             "const": "nm0000541"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Rose",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZGNiM2I2YTMtMjEwOS00ZjYyLTliZmMtN2E2NWVhZGQxMzExXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg",
#                                             "imageHeight": 1157,
#                                             "imageWidth": 797,
#                                             "originalName": null,
#                                             "const": "tt0079826"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057082",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jane Fonda",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMzQ5NTE2MDAzOV5BMl5BanBnXkFtZTgwOTQ3MTQ3MjE@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1740,
#                                             "const": "nm0000404"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The China Syndrome",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTY5YTdhODktMWUwMC00MDE1LWI1NmUtZWUyYzU3M2NiNWY2XkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 969,
#                                             "imageWidth": 645,
#                                             "originalName": null,
#                                             "const": "tt0078966"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057080",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jill Clayburgh",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTY3NTgyNjg5MV5BMl5BanBnXkFtZTcwMTQ5OTYwNA@@._V1_.jpg",
#                                             "imageHeight": 500,
#                                             "imageWidth": 390,
#                                             "const": "nm0001049"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Starting Over",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWUyMDZjYTEtNDhjYy00NDhlLTg3YTgtOTllNzU2Yzk1YWEwXkEyXkFqcGdeQXVyMjUyNDk2ODc@._V1_.jpg",
#                                             "imageHeight": 1205,
#                                             "imageWidth": 800,
#                                             "originalName": null,
#                                             "const": "tt0079948"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057079",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Marsha Mason",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTg0OTEyOTE0NV5BMl5BanBnXkFtZTcwODI3MzcyNA@@._V1_.jpg",
#                                             "imageHeight": 1023,
#                                             "imageWidth": 677,
#                                             "const": "nm0556850"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Chapter Two",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWE0ZGUxZTQtY2U0MC00MGM5LWE2NDctZTdmNjdkMmZhYjY2XkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_.jpg",
#                                             "imageHeight": 2103,
#                                             "imageWidth": 1428,
#                                             "originalName": null,
#                                             "const": "tt0078952"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057081",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actress in a Supporting Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Meryl Streep",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTU4Mjk5MDExOF5BMl5BanBnXkFtZTcwOTU1MTMyMw@@._V1_.jpg",
#                                             "imageHeight": 600,
#                                             "imageWidth": 427,
#                                             "const": "nm0000658"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Kramer vs. Kramer",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNDM3YjNlYmMtOGY3NS00MmRjLWIyY2UtNDA0MWM3OTNlZTY2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 869,
#                                             "imageWidth": 566,
#                                             "originalName": null,
#                                             "const": "tt0079417"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057088",
#                                     "characterNames": [],
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Barbara Barrie",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjI1ODIyNzI0MF5BMl5BanBnXkFtZTcwMTExNTg2OA@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1359,
#                                             "const": "nm0057363"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Breaking Away",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNzgyOWE0ZTMtNDNmZi00ZjVlLWJhYTktZWFjNjJkODdkMzE5XkEyXkFqcGdeQXVyMjgxMzgyNjI@._V1_.jpg",
#                                             "imageHeight": 601,
#                                             "imageWidth": 400,
#                                             "originalName": null,
#                                             "const": "tt0078902"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057090",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Candice Bergen",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTA3MTM1MTIxNTdeQTJeQWpwZ15BbWU3MDc4NDY2MjE@._V1_.jpg",
#                                             "imageHeight": 420,
#                                             "imageWidth": 300,
#                                             "const": "nm0000298"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Starting Over",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWUyMDZjYTEtNDhjYy00NDhlLTg3YTgtOTllNzU2Yzk1YWEwXkEyXkFqcGdeQXVyMjUyNDk2ODc@._V1_.jpg",
#                                             "imageHeight": 1205,
#                                             "imageWidth": 800,
#                                             "originalName": null,
#                                             "const": "tt0079948"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057091",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jane Alexander",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTgzODYyMTc0OF5BMl5BanBnXkFtZTYwNDc4NzU0._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 297,
#                                             "const": "nm0000737"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Kramer vs. Kramer",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNDM3YjNlYmMtOGY3NS00MmRjLWIyY2UtNDA0MWM3OTNlZTY2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 869,
#                                             "imageWidth": 566,
#                                             "originalName": null,
#                                             "const": "tt0079417"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057089",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Mariel Hemingway",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTI2ODI4ODc4MV5BMl5BanBnXkFtZTYwNjY1OTYz._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 281,
#                                             "const": "nm0000446"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Manhattan",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMzdmY2I3MmEtOGFiZi00MTg1LWIxY2QtNWUwM2NmNWNlY2U5XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg",
#                                             "imageHeight": 1500,
#                                             "imageWidth": 1000,
#                                             "originalName": null,
#                                             "const": "tt0079522"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057092",
#                                     "characterNames": [],
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Art Direction-Set Decoration",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "All That Jazz",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZWE4N2JkNDUtZDU4MC00ZjNhLTlkMjYtOTNkMjZhMDAwMDMyXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg",
#                                             "imageHeight": 755,
#                                             "imageWidth": 511,
#                                             "originalName": null,
#                                             "const": "tt0078754"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Philip Rosenberg",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTQ4MjQ3NTcyMl5BMl5BanBnXkFtZTcwMjk4MDY0Mw@@._V1_.jpg",
#                                             "imageHeight": 1392,
#                                             "imageWidth": 996,
#                                             "const": "nm0742303"
#                                         },
#                                         {
#                                             "name": "Tony Walton",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNDI1ODgzMTczMl5BMl5BanBnXkFtZTcwMDA1OTYzNw@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1439,
#                                             "const": "nm0910589"
#                                         },
#                                         {
#                                             "name": "Edward Stewart",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0829357"
#                                         },
#                                         {
#                                             "name": "Gary J. Brink",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0109549"
#                                         }
#                                     ],
#                                     "categoryName": "Best Art Direction-Set Decoration",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardName": "Oscar",
#                                     "awardNominationId": "an0057113",
#                                     "characterNames": [],
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Alien",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMmQ2MmU3NzktZjAxOC00ZDZhLTk4YzEtMDMyMzcxY2IwMDAyXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_.jpg",
#                                             "imageHeight": 2922,
#                                             "imageWidth": 1984,
#                                             "originalName": null,
#                                             "const": "tt0078748"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Michael Seymour",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0786854"
#                                         },
#                                         {
#                                             "name": "Leslie Dilley",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0226896"
#                                         },
#                                         {
#                                             "name": "Roger Christian",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTYwMDc1OTM3N15BMl5BanBnXkFtZTcwODcyNTQ5Mw@@._V1_.jpg",
#                                             "imageHeight": 480,
#                                             "imageWidth": 399,
#                                             "const": "nm0002337"
# ...
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the concept, engineering and development of the Acme-Dunn Optical Printer for motion picture special effects.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051805",
#                                     "characterNames": [],
#                                     "awardName": "Academy Award of Merit",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000017"
#                 },
#                 {
#                     "awardName": "Scientific and Engineering Award",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": null,
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "David Grafton",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0333849"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the optical design and engineering of a telecentric anamorphic lens for motion picture optical effects printers.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051810",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jean-Marie Lavalou",
#                                             "note": "(Samuelson Alga Cinema S.A./Samuelson Film Service, Ltd.)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0491759"
#                                         },
#                                         {
#                                             "name": "Alain Masseron",
#                                             "note": "(Samuelson Alga Cinema S.A./Samuelson Film Service, Ltd.)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0557251"
#                                         },
#                                         {
#                                             "name": "David Samuelson",
#                                             "note": "(Samuelson Alga Cinema S.A./Samuelson Film Service, Ltd.)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm1038141"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the engineering and development of the Louma Camera Crane and remote control system for motion picture production.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051806",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the progressive engineering and manufacture of the OSRAM HMI light source for motion picture color photography.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051809",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the concept and development of a system of air guns for propelling objects used in special effects motion picture production.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051808",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the engineering and manufacture of the micro-demand drive for continuous motion picture film processors.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051807",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000018"
#                 },
#                 {
#                     "awardName": "Technical Achievement Award",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": null,
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Peter Regla",
#                                             "note": "(Elicon)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0716664"
#                                         },
#                                         {
#                                             "name": "Dan Slater",
#                                             "note": "(Elicon)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0805361"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development of a follow-focus system for motion picture optical effects printers and animation stands.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051817",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the advanced design and manufacture of a film sprocket for motion picture projectors.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051816",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development and manufacture of a modular continuous contact motion picture film printer.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051815",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development of a versatile general purpose computer system for animation and optical effects motion picture photography.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051814",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development of a continuous contact, total immersion, additive color motion picture printer.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051813",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development of a continuous contact, total immersion, additive color motion picture printer.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051812",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the development of a continuous contact, total immersion, additive color motion picture printer.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051811",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000019"
#                 }
#             ],
#             "requestKey": {
#                 "year": 1981,
#                 "occurrence": 1,
#                 "preferredLanguage": "en",
#                 "preferredRegion": "US",
#                 "userRegion": "US",
#                 "eventId": "ev0000003"
#             },
#             "eventName": "Academy Awards, USA",
#             "eventEditionId": "ee0035679",
#             "occurrence": 1,
#             "eventId": "ev0000003",
#             "year": 1981
#         },
#         "alwaysDisplayAwardNames": true,
#         "shouldDisplayNotes": true,
#         "showOnlyPremiumCategories": false,
#         "mobile": false
#     }
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c32bc04b3a6f> in <module>
#      28                 award_dict[category_name].append(id_2)
#      29     sleep(randint(2,10))
# ---> 30 nom.append(award_dict)
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
nom
# Out:
# {'primaryNominees': [{'name': 'Private Benjamin',
#    'note': None,
#    'imageUrl': 'https://m.media-amazon.com/images/M/MV5BMjIyNjkxMjUyMF5BMl5BanBnXkFtZTgwMzU0MjEyMDE@._V1_.jpg',
#    'imageHeight': 1000,
#    'imageWidth': 675,
#    'originalName': None,
#    'const': 'tt0081375'}],
#  'secondaryNominees': [{'name': 'Nancy Meyers',
#    'note': None,
#    'imageUrl': 'https://m.media-amazon.com/images/M/MV5BY2Q2Yjg5ZGMtYWEyNC00MGZhLWIyNTYtMjE5OGFhNmExNmE1XkEyXkFqcGdeQXVyNjcwNDc1Mjc@._V1_.jpg',
#    'imageHeight': 720,
#    'imageWidth': 541,
#    'const': 'nm0583600'},
#   {'name': 'Charles Shyer',
#    'note': None,
#    'imageUrl': 'https://m.media-amazon.com/images/M/MV5BMTAxODAxNTEyNjVeQTJeQWpwZ15BbWU3MDQ1MzQyNjg@._V1_.jpg',
#    'imageHeight': 600,
#    'imageWidth': 548,
#    'const': 'nm0796124'},
#   {'name': 'Harvey Miller',
#    'note': None,
#    'imageUrl': None,
#    'imageHeight': 0,
#    'imageWidth': 0,
#    'const': 'nm0588458'}],
#  'categoryName': 'Best Writing, Screenplay Written Directly for the Screen',
#  'winAnnouncementTime': None,
#  'notes': None,
#  'songNames': [],
#  'episodeNames': [],
#  'awardNominationId': 'an0054807',
#  'characterNames': [],
#  'awardName': 'Oscar',
#  'isWinner': False}

# %%
# ua = UserAgent()
# user_agent = {'User-agent': ua.random}

# url = 'https://www.imdb.com/event/ev0000003/2000'
# response = requests.get(url,headers=user_agent).text
# data = json.loads( re.findall(r'IMDbReactWidgets\.NomineesWidget\.push.*?(\{.*\})', response)[0] )
# imdb_ids=[]
# category_names={}
# #print(json.dumps(data, indent=4)) # <-- comment this out to print all data
# award_dict = {}
# for award in data['nomineesWidgetModel']['eventEditionSummary']['awards']:
#     if award['awardName'] != 'Oscar':
#         continue
#     for title in award['categories']:
#         category_name = title['categoryName']
#         award_dict[category_name] = []
#         noms = title['nominations']
#         #category_names.append(category_name)
#         for nom in noms:
#             if len(nom['secondaryNominees'])!=0:
#                 id_ = nom['secondaryNominees'][0]['const'] 
#             id_2 = nom['primaryNominees'][0]['const']
#             award_dict[category_name].append(id_)
#             award_dict[category_name].append(id_2)
# sleep(randint(2,10))
# award_dict
# Out:
# {'Best Actor in a Leading Role': ['tt0169547',
#   'nm0000228',
#   'tt0174856',
#   'nm0000243',
#   'tt0166896',
#   'nm0002070',
#   'tt0140352',
#   'nm0000128',
#   'tt0158371',
#   'nm0000576'],
#  'Best Actor in a Supporting Role': ['tt0124315',
#   'nm0000323',
#   'tt0167404',
#   'nm0005286',
#   'tt0134119',
#   'nm0000179',
#   'tt0120689',
#   'nm0003817',
#   'tt0175880',
#   'nm0000129'],
#  'Best Actress in a Leading Role': ['tt0171804',
#   'nm0005476',
#   'tt0169547',
#   'nm0000906',
#   'tt0161023',
#   'nm0005216',
#   'tt0172396',
#   'nm0000194',
#   'tt0166943',
#   'nm0000658'],
#  'Best Actress in a Supporting Role': ['tt0172493',
#   'nm0001401',
#   'tt0120601',
#   'nm0001416',
#   'tt0171804',
#   'nm0001721',
#   'tt0158371',
#   'nm0608090',
#   'tt0167404',
#   'nm0001057'],
#  'Best Art Direction-Set Decoration': ['nm0374511',
#   'tt0162661',
#   'nm0002186',
#   'tt0166485',
#   'nm0343222',
#   'tt0124315',
#   'nm0908178',
#   'tt0134119',
#   'nm0829378',
#   'tt0151568'],
#  'Best Cinematography': ['nm0005734',
#   'tt0169547',
#   'nm0523881',
#   'tt0162661',
#   'nm0724744',
#   'tt0120834',
#   'nm0695536',
#   'tt0172396',
#   'nm0005883',
#   'tt0140352'],
#  'Best Costume Design': ['nm0376089',
#   'tt0151568',
#   'nm0064746',
#   'tt0166485',
#   'nm0041181',
#   'tt0162661',
#   'nm0744778',
#   'tt0134119',
#   'nm0134382',
#   'tt0120866'],
#  'Best Director': ['tt0169547',
#   'nm0005222',
#   'tt0124315',
#   'nm0002120',
#   'tt0167404',
#   'nm0796117',
#   'tt0140352',
#   'nm0000520',
#   'tt0120601',
#   'nm0005069'],
#  'Best Documentary, Features': ['nm0004453',
#   'tt0230591',
#   'nm0000694',
#   'tt0186508',
#   'nm0067861',
#   'tt0187859',
#   'nm0123379',
#   'tt0181733',
#   'nm0223814',
#   'tt0181835'],
#  'Best Documentary, Short Subjects': ['nm0169804',
#   'tt0239528',
#   'nm0885769',
#   'tt0239379',
#   'nm0812144',
#   'tt0240216'],
#  'Best Effects, Sound Effects Editing': ['nm0204424',
#   'tt0133093',
#   'nm0460274',
#   'tt0137523',
#   'nm0123785',
#   'tt0120915'],
#  'Best Effects, Visual Effects': ['nm0300665',
#   'tt0133093',
#   'nm0461306',
#   'tt0120915',
#   'nm0004375',
#   'tt0164912'],
#  'Best Film Editing': ['nm0821205',
#   'tt0133093',
#   'nm0031697',
#   'tt0169547',
#   'nm0161497',
#   'tt0124315',
#   'nm0325549',
#   'tt0140352',
#   'nm0597812',
#   'tt0167404'],
#  'Best Foreign Language Film': ['nm0597812',
#   'tt0185125',
#   'nm0597812',
#   'tt0181530',
#   'nm0597812',
#   'tt0210727',
#   'nm0597812',
#   'tt0181830',
#   'nm0597812',
#   'tt0158302'],
#  'Best Makeup': ['nm0089879',
#   'tt0151568',
#   'nm0121807',
#   'tt0145660',
#   'nm0134148',
#   'tt0182789',
#   'nm0000711',
#   'tt0123964'],
#  'Best Music, Original Score': ['nm0179858',
#   'tt0120802',
#   'nm0002353',
#   'tt0169547',
#   'nm0002354',
#   'tt0145653',
#   'nm0006235',
#   'tt0124315',
#   'nm0001189',
#   'tt0134119'],
#  'Best Music, Original Song': ['nm0002015',
#   'tt0120855',
#   'nm0005181',
#   'tt0175880',
#   'nm0005534',
#   'tt0166943',
#   'nm0005295',
#   'tt0158983',
#   'nm0005271',
#   'tt0120363'],
#  'Best Picture': ['nm0169260',
#   'tt0169547',
#   'nm0321621',
#   'tt0124315',
#   'nm0883603',
#   'tt0120689',
#   'nm0000520',
#   'tt0140352',
#   'nm0550881',
#   'tt0167404'],
#  'Best Short Film, Animated': ['nm0678154',
#   'tt0207639',
#   'nm0237895',
#   'tt0239206',
#   'nm0668849',
#   'tt0192145',
#   'nm0468380',
#   'tt0210853',
#   'nm0863195',
#   'tt0200282'],
#  'Best Short Film, Live Action': ['nm0774294',
#   'tt0177023',
#   'nm0635741',
#   'tt0236386',
#   'nm0090596',
#   'tt0200780',
#   'nm0648103',
#   'tt0239583',
#   'nm0313227',
#   'tt0191850'],
#  'Best Sound': ['nm0718676',
#   'tt0133093',
#   'nm0003977',
#   'tt0120915',
#   'nm0514448',
#   'tt0120689',
#   'nm0625144',
#   'tt0140352',
#   'nm0789458',
#   'tt0120616'],
#  'Best Writing, Screenplay Based on Material Previously Produced or Published': ['nm0410288',
#   'tt0124315',
#   'nm0668247',
#   'tt0126886',
#   'nm0001104',
#   'tt0120689',
#   'nm0744839',
#   'tt0140352',
#   'nm0005237',
#   'tt0134119'],
#  'Best Writing, Screenplay Written Directly for the Screen': ['nm0050332',
#   'tt0169547',
#   'nm0442109',
#   'tt0120601',
#   'nm0000759',
#   'tt0175880',
#   'nm0796117',
#   'tt0167404',
#   'nm0005139',
#   'tt0151568']}
