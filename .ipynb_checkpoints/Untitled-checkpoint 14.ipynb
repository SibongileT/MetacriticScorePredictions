# %% [markdown]
# ## Explore the relationship between metacritic score and the current features to find what features to encode or engineer

# %%
# %config InlineBackend.figure_formats = ['retina']

import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %%
oscars_df = pd.read_csv('oscar_movies_data.csv')

# %%
oscars_df.describe()
# Out:
#         Unnamed: 0  runtime (mins)  metacritic score        budget
# count  1136.000000     1136.000000       1136.000000  1.072000e+03
# mean    708.796655      120.032570         72.083627  4.268831e+07
# std     425.941679       21.817864         13.554168  5.070841e+07
# min       0.000000       70.000000         16.000000  6.500000e+04
# 25%     342.750000      105.000000         64.000000  1.136429e+07
# 50%     687.500000      118.000000         74.000000  2.500000e+07
# 75%    1081.250000      132.000000         82.000000  5.200000e+07
# max    1493.000000      224.000000        100.000000  3.210000e+08

# %%
oscars_df.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
plt.figure(figsize=(40,40))
sns.displot(oscars_df, x="genre", hue="metacritic score");

# %%
oscars_df['Director_Avg_Score'] =  oscars_df.groupby(['director'])['metacritic score'].transform('mean')

# %%
oscars_df.sort_values('director')
# Out:
#         IMDBId                                    movie title  language  \
# 100  tt1291584                                        Warrior   English
# 643  tt0161023                                    Tumbleweeds   English
# 848  tt0328880                                   Brother Bear   English
# 854  tt4209788                                   Molly's Game   English
# 638  tt3409392                                       Timbuktu    French
# ..         ...                                            ...       ...
# 481  tt0351817                                Tasogare Seibei  Japanese
# 5    tt1069238                                     Departures  Japanese
# 906  tt0388789  Born Into Brothels: Calcutta's Red Light Kids   Bengali
# 477  tt2991224                                     Tangerines  Estonian
# 301  tt7048622                                     The Insult    Arabic
#
#         country  runtime (mins) mpaarating  metacritic score       budget  \
# 100         USA             140      PG-13              71.0   25000000.0
# 643         USA             102      PG-13              75.0     312000.0
# 848         USA              85          G              48.0  128000000.0
# 854       China             140          R              71.0   30000000.0
# 638  Mauritania              96      PG-13              92.0    3000000.0
# ..          ...             ...        ...               ...          ...
# 481       Japan             129    Unrated              82.0    5000000.0
# 5         Japan             130      PG-13              68.0          NaN
# 906         USA              85          R              78.0          NaN
# 477     Estonia              87  Not Rated              73.0    1800000.0
# 301      France             113          R              72.0    3000000.0
#
#       distributionCompany               writer1  ...              director  \
# 100             Lionsgate      "Gavin O'Connor"  ...      "Gavin O'Connor"
# 643    Fine Line Features        Angela Shelton  ...      "Gavin O'Connor"
# 848  Buena Vista Pictures            Tab Murphy  ...          Aaron Blaise
# 854     STX Entertainment          Aaron Sorkin  ...          Aaron Sorkin
# 638     Cohen Media Group  Abderrahmane Sissako  ...  Abderrahmane Sissako
# ..                    ...                   ...  ...                   ...
# 481       Empire Pictures       Shûhei Fujisawa  ...           Yôji Yamada
# 5        Regent Releasing          Kundô Koyama  ...         Yôjirô Takita
# 906           Think Films           Zana Briski  ...           Zana Briski
# 477  Samuel Goldwyn Films      Tatjana Mülbeier  ...        Zaza Urushadze
# 301     Cohen Media Group          Ziad Doueiri  ...          Ziad Doueiri
#
#            Lead_Actor Supporting_Actor_1 Supporting_Actor_2  \
# 100         Tom Hardy         Nick Nolte      Joel Edgerton
# 643      Janet McTeer  Kimberly J. Brown     Jay O. Sanders
# 848   Joaquin Phoenix      Jeremy Suarez       Rick Moranis
# 854  Jessica Chastain         Idris Elba      Kevin Costner
# 638     Ibrahim Ahmed         Abel Jafri        Toulou Kiki
# ..                ...                ...                ...
# 481   Hiroyuki Sanada       Rie Miyazawa    Nenji Kobayashi
# 5     Masahiro Motoki      Ryôko Hirosue   Tsutomu Yamazaki
# 906             Kochi      Avijit Halder         Shanti Das
# 477     Lembit Ulfsak       Elmo Nüganen  Giorgi Nakashidze
# 301        Adel Karam     Kamel El Basha    Camille Salameh
#
#                        genre   main_genre   subgenre release_date  season  \
# 100           Action' 'Drama       Action      Drama   2011-09-09    Fall
# 643           Comedy' 'Drama       Comedy      Drama   2000-03-03  Winter
# 848    Animation' 'Adventure    Animation  Adventure   2003-11-07    Fall
# 854        Biography' 'Crime    Biography      Crime   2018-01-05  Winter
# 638              Drama' 'War        Drama        War   2014-12-10  Winter
# ..                       ...          ...        ...          ...     ...
# 481          Drama' 'History        Drama    History          NaN    Fall
# 5              Drama' 'Music        Drama      Music   2009-06-19  Summer
# 906  Documentary' 'Biography  Documentary  Biography   2005-03-11  Winter
# 477              Drama' 'War        Drama        War   2015-04-17  Spring
# 301            Crime' 'Drama        Crime      Drama   2019-06-25  Summer
#
#     Director_Avg_Score
# 100               73.0
# 643               73.0
# 848               48.0
# 854               71.0
# 638               92.0
# ..                 ...
# 481               82.0
# 5                 68.0
# 906               78.0
# 477               73.0
# 301               72.0
#
# [1136 rows x 21 columns]

# %%
oscars_df.groupby('director')['metacritic score'].mean()
# Out:
# director
# "Gavin O'Connor"        73.0
# Aaron Blaise            48.0
# Aaron Sorkin            71.0
# Abderrahmane Sissako    92.0
# Adam McKay              71.0
#                         ...
# Yôji Yamada             82.0
# Yôjirô Takita           68.0
# Zana Briski             78.0
# Zaza Urushadze          73.0
# Ziad Doueiri            72.0
# Name: metacritic score, Length: 613, dtype: float64

# %%
oscars_df.groupby('Lead_Actor')['metacritic score'].mean()
# Out:
# Lead_Actor
# "Auli'i Cravalho"                    81.0
# "Elizabeth 'Eliza' Maganga Nsese"    84.0
# "Jack O'Connell"                     59.0
# "Latrenda 'Boosie' Ash"              85.0
# "O'Shea Jackson Jr."                 72.0
#                                      ...
# Yun-Fat Chow                         82.0
# Zachary Quinto                       76.0
# Zaide Silvia Gutiérrez               67.0
# Zain Al Rafeea                       75.0
# Ziyi Zhang                           89.0
# Name: metacritic score, Length: 645, dtype: float64
