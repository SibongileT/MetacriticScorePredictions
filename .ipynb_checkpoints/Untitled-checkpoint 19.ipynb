# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time, os
from time import sleep
from random import randint
import re
import json
from fake_useragent import UserAgent
import math

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}
pages = np.arange(1980,2021)
#title_ids=[]
nom_dict = {}
def get_title_ids(pages):
    imdb_ids=[]
    #Get all the raw title ids
    #for page in pages:
    url = 'https://www.imdb.com/event/ev0000003/'+str(page)
    response = requests.get(url,headers=user_agent).text
    data = json.loads( re.findall(r'IMDbReactWidgets\.NomineesWidget\.push.*?(\{.*\})', response)[0] )

    print(json.dumps(data, indent=4)) # <-- comment this out to print all data

    for award in data['nomineesWidgetModel']['eventEditionSummary']['awards']:
        if award['awardName'] != 'Oscar':
            continue
        for title in award['categories']:
            noms = title['nominations']
            for nom in noms:
                if len(nom['secondaryNominees'])!=0:
                    id_ = nom['secondaryNominees'][0]['const'] 
                id_2 = nom['primaryNominees'][0]['const']
                imdb_ids.append(id_)
                imdb_ids.append(id_2)
    sleep(randint(2,10))

#change the titleId into a set
imdb_ids_set = set(imdb_ids)
imdb_film_ids = []

#Set Contains id for people and films extract the films only 
for film_id in imdb_ids_set:
    if film_id[0]=='t':
        imdb_film_ids.append(film_id)
return imdb_film_ids

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}

url = 'https://www.imdb.com/event/ev0000003/2000'
response = requests.get(url,headers=user_agent).text
data = json.loads( re.findall(r'IMDbReactWidgets\.NomineesWidget\.push.*?(\{.*\})', response)[0] )
imdb_ids=[]
category_names={}
print(json.dumps(data, indent=4)) # <-- comment this out to print all data
award_dict = {}
for award in data['nomineesWidgetModel']['eventEditionSummary']['awards']:
    if award['awardName'] != 'Oscar':
        continue
    for title in award['categories']:
        category_name = title['categoryName']
        award_dict[category_name] = []
        noms = title['nominations']
        category_names.append(category_name)
        for nom in noms:
            if len(nom['secondaryNominees'])!=0:
                id_ = nom['secondaryNominees'][0]['const'] 
            id_2 = nom['primaryNominees'][0]['const']
            award_dict[category_name].append(id_)
            award_dict[category_name].append(id_2)
sleep(randint(2,10))
award_dict
# Out:
# {
#     "nomineesWidgetModel": {
#         "title": "",
#         "description": "",
#         "refMarker": "ev_nom",
#         "eventEditionSummary": {
#             "awards": [
#                 {
#                     "awardName": "Oscar",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": "Best Actor in a Leading Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Kevin Spacey",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTY1NzMyODc3Nl5BMl5BanBnXkFtZTgwNzE2MzA1NDM@._V1_.jpg",
#                                             "imageHeight": 1471,
#                                             "imageWidth": 1800,
#                                             "const": "nm0000228"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "American Beauty",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNTBmZWJkNjctNDhiNC00MGE2LWEwOTctZTk5OGVhMWMyNmVhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg",
#                                             "imageHeight": 1000,
#                                             "imageWidth": 675,
#                                             "originalName": null,
#                                             "const": "tt0169547"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055164",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Denzel Washington",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjE5NDU2Mzc3MV5BMl5BanBnXkFtZTcwNjAwNTE5OQ@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1536,
#                                             "const": "nm0000243"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Hurricane",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTA3OTYxMzg0MDFeQTJeQWpwZ15BbWU4MDY1MjY0MTEx._V1_.jpg",
#                                             "imageHeight": 487,
#                                             "imageWidth": 329,
#                                             "originalName": null,
#                                             "const": "tt0174856"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055168",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Richard Farnsworth",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTk2MDM1NTU2Nl5BMl5BanBnXkFtZTYwNjE2MzQ2._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 293,
#                                             "const": "nm0002070"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Straight Story",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNmE1MDk4OWEtYjk1NS00MWU2LTk5ZWItYjZhYmRkODRjMDc0XkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_.jpg",
#                                             "imageHeight": 755,
#                                             "imageWidth": 505,
#                                             "originalName": null,
#                                             "const": "tt0166896"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": "At age 79 years and 167 days, Farnsworth is (to date) the oldest ever nominee for the Academy Award for Best Actor.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055166",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Russell Crowe",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTQyMTExNTMxOF5BMl5BanBnXkFtZTcwNDg1NzkzNw@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1365,
#                                             "const": "nm0000128"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Insider",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BODg0YjAzNDQtOGFkMi00Yzk2LTg1NzYtYTNjY2UwZTM2ZDdkL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 833,
#                                             "imageWidth": 580,
#                                             "originalName": null,
#                                             "const": "tt0140352"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055165",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Sean Penn",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTc1NjMzMjY3NF5BMl5BanBnXkFtZTcwMzkxNjQzMg@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 272,
#                                             "const": "nm0000576"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Sweet and Lowdown",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjE2MzA5MDQ4NV5BMl5BanBnXkFtZTgwNjI4ODQxMDE@._V1_.jpg",
#                                             "imageHeight": 500,
#                                             "imageWidth": 337,
#                                             "originalName": null,
#                                             "const": "tt0158371"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055167",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actor in a Supporting Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Michael Caine",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjAwNzIwNTQ4Ml5BMl5BanBnXkFtZTYwMzE1MTUz._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 288,
#                                             "const": "nm0000323"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Cider House Rules",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNmY5YzA4OTQtOTQzZS00NDZmLTlhNzQtNzk5NTIyZWE2ZjVkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 1500,
#                                             "imageWidth": 1000,
#                                             "originalName": null,
#                                             "const": "tt0124315"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055169",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Haley Joel Osment",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZjY0MjRhNjEtNGVlYi00YzZhLWFhNDEtMjlhNjBiNzM3Y2RkXkEyXkFqcGdeQXVyMjQxMDQzMjA@._V1_.jpg",
#                                             "imageHeight": 450,
#                                             "imageWidth": 600,
#                                             "const": "nm0005286"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Sixth Sense",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWM4NTFhYjctNzUyNi00NGMwLTk3NTYtMDIyNTZmMzRlYmQyXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 739,
#                                             "imageWidth": 500,
#                                             "originalName": null,
#                                             "const": "tt0167404"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055173",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Jude Law",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTMwOTg5NTQ3NV5BMl5BanBnXkFtZTcwNzM3MDAzNQ@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1457,
#                                             "const": "nm0000179"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Talented Mr. Ripley",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BODA3NDhiZjYtYTk2NS00ZWYwLTljYTQtMjU0NzcyMGEzNTU2L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 1500,
#                                             "imageWidth": 1009,
#                                             "originalName": null,
#                                             "const": "tt0134119"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055172",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Michael Clarke Duncan",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTI3NDY2ODk5OV5BMl5BanBnXkFtZTYwMjQ0NzE0._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 340,
#                                             "const": "nm0003817"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Green Mile",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_.jpg",
#                                             "imageHeight": 740,
#                                             "imageWidth": 500,
#                                             "originalName": null,
#                                             "const": "tt0120689"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055171",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Tom Cruise",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTk1MjM3NTU5M15BMl5BanBnXkFtZTcwMTMyMjAyMg@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 305,
#                                             "const": "nm0000129"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Magnolia",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZjk3YThkNDktNjZjMS00MTBiLTllNTAtYzkzMTU0N2QwYjJjXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg",
#                                             "imageHeight": 2771,
#                                             "imageWidth": 1752,
#                                             "originalName": null,
#                                             "const": "tt0175880"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actor in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055170",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actress in a Leading Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Hilary Swank",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNWNjZjc1NTYtZmY2Mi00MjZhLWE4ZjYtYTMyNWFmYjRkZDdmXkEyXkFqcGdeQXVyMTAyNzUwOTA5._V1_.jpg",
#                                             "imageHeight": 640,
#                                             "imageWidth": 427,
#                                             "const": "nm0005476"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Boys Don't Cry",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BN2YyODgyYjMtN2ZiZC00OWMzLTg1NjgtZGIwN2NlYTYxMTkwXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 668,
#                                             "imageWidth": 450,
#                                             "originalName": null,
#                                             "const": "tt0171804"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055174",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Annette Bening",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTc4ODQ1ODM5Ml5BMl5BanBnXkFtZTcwOTU2NDk3OQ@@._V1_.jpg",
#                                             "imageHeight": 1024,
#                                             "imageWidth": 683,
#                                             "const": "nm0000906"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "American Beauty",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNTBmZWJkNjctNDhiNC00MGE2LWEwOTctZTk5OGVhMWMyNmVhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg",
#                                             "imageHeight": 1000,
#                                             "imageWidth": 675,
#                                             "originalName": null,
#                                             "const": "tt0169547"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055175",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Janet McTeer",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNzk5MzQ3MDQxOF5BMl5BanBnXkFtZTcwOTU4OTI2Mg@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 256,
#                                             "const": "nm0005216"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Tumbleweeds",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZTgwOGVjNTEtMzRlYS00ZGE3LTk1ZGYtMDY3ODMzMjFiNmQxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg",
#                                             "imageHeight": 1280,
#                                             "imageWidth": 867,
#                                             "originalName": null,
#                                             "const": "tt0161023"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055176",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Julianne Moore",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTM5NDI1MjE2Ml5BMl5BanBnXkFtZTgwNDE0Nzk0MDE@._V1_.jpg",
#                                             "imageHeight": 827,
#                                             "imageWidth": 596,
#                                             "const": "nm0000194"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The End of the Affair",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BYzhkNDRkMDctYTcxMy00MTI3LWI5ODQtZWNkYWQ2ZjA2ZDk2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 770,
#                                             "imageWidth": 520,
#                                             "originalName": null,
#                                             "const": "tt0172396"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055177",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Meryl Streep",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTU4Mjk5MDExOF5BMl5BanBnXkFtZTcwOTU1MTMyMw@@._V1_.jpg",
#                                             "imageHeight": 600,
#                                             "imageWidth": 427,
#                                             "const": "nm0000658"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Music of the Heart",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZTU0ODZiNTktMTI0OC00NzZjLTlhZTMtYTE3ZjVlMmVhMmI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 1600,
#                                             "imageWidth": 1075,
#                                             "originalName": null,
#                                             "const": "tt0166943"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Leading Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055178",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Actress in a Supporting Role",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Angelina Jolie",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BODg3MzYwMjE4N15BMl5BanBnXkFtZTcwMjU5NzAzNw@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1665,
#                                             "const": "nm0001401"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Girl, Interrupted",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNzdjZDYwM2QtMGNlZS00MGQzLTlhMjctYTU4NWI5MWJlYmQwXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 746,
#                                             "imageWidth": 500,
#                                             "originalName": null,
#                                             "const": "tt0172493"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055179",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Catherine Keener",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjIwMzQ1Mzg1MF5BMl5BanBnXkFtZTcwNTE4MTU5MQ@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 267,
#                                             "const": "nm0001416"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Being John Malkovich",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BYmUxY2MyOTQtYjRlMi00ZWEwLTkzODctZDMxNDcyNTFhYjNjXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg",
#                                             "imageHeight": 1187,
#                                             "imageWidth": 836,
#                                             "originalName": null,
#                                             "const": "tt0120601"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055181",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Chlo\u00eb Sevigny",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTA3ODUwMTc1NDFeQTJeQWpwZ15BbWU4MDk1MjE2Nzkx._V1_.jpg",
#                                             "imageHeight": 968,
#                                             "imageWidth": 634,
#                                             "const": "nm0001721"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Boys Don't Cry",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BN2YyODgyYjMtN2ZiZC00OWMzLTg1NjgtZGIwN2NlYTYxMTkwXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 668,
#                                             "imageWidth": 450,
#                                             "originalName": null,
#                                             "const": "tt0171804"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055183",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Samantha Morton",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTUwNjc2MTg3N15BMl5BanBnXkFtZTcwOTQzODI3MQ@@._V1_.jpg",
#                                             "imageHeight": 400,
#                                             "imageWidth": 293,
#                                             "const": "nm0608090"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Sweet and Lowdown",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMjE2MzA5MDQ4NV5BMl5BanBnXkFtZTgwNjI4ODQxMDE@._V1_.jpg",
#                                             "imageHeight": 500,
#                                             "imageWidth": 337,
#                                             "originalName": null,
#                                             "const": "tt0158371"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055182",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Toni Collette",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BODYzOTE3ODc1Ml5BMl5BanBnXkFtZTgwODYwMjE4NTM@._V1_.jpg",
#                                             "imageHeight": 640,
#                                             "imageWidth": 503,
#                                             "const": "nm0001057"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "The Sixth Sense",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWM4NTFhYjctNzUyNi00NGMwLTk3NTYtMDIyNTZmMzRlYmQyXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_.jpg",
#                                             "imageHeight": 739,
#                                             "imageWidth": 500,
#                                             "originalName": null,
#                                             "const": "tt0167404"
#                                         }
#                                     ],
#                                     "categoryName": "Best Actress in a Supporting Role",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055180",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         },
#                         {
#                             "categoryName": "Best Art Direction-Set Decoration",
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Sleepy Hollow",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTQ4Yjk5ODEtNGFkOS00OTY1LTgwYTYtOTFkNmU2NzBmNGM2XkEyXkFqcGdeQXVyNDQ2MTMzODA@._V1_.jpg",
#                                             "imageHeight": 1488,
#                                             "imageWidth": 1000,
#                                             "originalName": null,
#                                             "const": "tt0162661"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Rick Heinrichs",
#                                             "note": "(art director)",
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMTY3NDQzMzI0NV5BMl5BanBnXkFtZTcwNzA1OTYzNw@@._V1_.jpg",
#                                             "imageHeight": 2048,
#                                             "imageWidth": 1570,
#                                             "const": "nm0374511"
#                                         },
#                                         {
#                                             "name": "Peter Young",
#                                             "note": "(set decorator)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0949952"
#                                         }
#                                     ],
#                                     "categoryName": "Best Art Direction-Set Decoration",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055199",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Anna and the King",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BZWQzMmY1ZDktMjk0Yi00MGJmLWI0ZWQtYzQzNjU2MTk5ZjA5XkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_.jpg",
#                                             "imageHeight": 1083,
#                                             "imageWidth": 736,
#                                             "originalName": null,
#                                             "const": "tt0166485"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
#                                             "name": "Luciana Arrighi",
#                                             "note": "(art director)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0002186"
#                                         },
#                                         {
#                                             "name": "Ian Whittaker",
#                                             "note": "(set decorator)",
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0926434"
#                                         }
#                                     ],
#                                     "categoryName": "Best Art Direction-Set Decoration",
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0055200",
#                                     "characterNames": [],
#                                     "awardName": "Oscar",
#                                     "isWinner": false
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "The Cider House Rules",
#                                             "note": null,
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BNmY5YzA4OTQtOTQzZS00NDZmLTlhNzQtNzk5NTIyZWE2ZjVkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg",
#                                             "imageHeight": 1500,
#                                             "imageWidth": 1000,
#                                             "originalName": null,
#                                             "const": "tt0124315"
#                                         }
#                                     ],
#                                     "secondaryNominees": [
#                                         {
# ...
#                                     "awardName": "Academy Award of Merit",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000017"
#                 },
#                 {
#                     "awardName": "Scientific and Engineering Award",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": null,
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Huw Gwyllyn",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0350357"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the design and development of the AMS/Neve-Logic Digital Film Console for motion picture sound mixing.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051233",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Nick Phillips",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm0680673"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the design and development of the three-axis Libra III remote control camera head.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051230",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the production of high-quality, durable, laminated color filters for motion picture photography.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051237",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the concept, design and engineering of the Linear Loop Film Projectors.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051236",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For development of the process for manufacturing Electro-Formed Metal Reflectors which, when combined with the DC Short Arc Xenon Lamp, became the worldwide standard for motion picture projection systems.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051235",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the mechanical (Moultrie) and the optical design (Salter/Gerchman) of the Cooke S4 Range of Fixed Focal Length Lenses for 35mm motion picture photography.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051234",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the optical (Neil) and the mechanical design (Gelbard) and for the development (Panavision) of the Millennium Camera System viewfinder.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051232",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the concept, design and engineering of the Moviecam Superlight 35mm Motion Picture Camera.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051231",
#                                     "characterNames": [],
#                                     "awardName": "Scientific and Engineering Award",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000018"
#                 },
#                 {
#                     "awardName": "Technical Achievement Award",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": null,
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Chris Woolf",
#                                             "note": null,
#                                             "imageUrl": null,
#                                             "imageHeight": 0,
#                                             "imageWidth": 0,
#                                             "const": "nm3918902"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the design and development of the Rycote Microphone Windshield Modular System.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051238",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [
#                                         {
#                                             "name": "Hoyt Yeatman",
#                                             "note": "(Dream Quest Images)",
#                                             "imageUrl": "https://m.media-amazon.com/images/M/MV5BMWM4ZjQwNzAtZDYxNS00ODY2LWE1M2ItZWJjNDBlOTYyMWQxXkEyXkFqcGdeQXVyMTExMTA4NjI5._V1_.jpg",
#                                             "imageHeight": 674,
#                                             "imageWidth": 452,
#                                             "const": "nm0947087"
#                                         }
#                                     ],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the identification and diagnosis leading to the elimination of the 'red fringe' artifact in traveling matte composite photography.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051241",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the concept (Sehlin), the design and development (Bogdanowicz/Schmoeger) of the Eastman Lamphouse Modification Filters.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051240",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 },
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": "For the design and development of the Light Wave microphone windscreens and isolation mounts from Light Wave Systems.",
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051239",
#                                     "characterNames": [],
#                                     "awardName": "Technical Achievement Award",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000019"
#                 },
#                 {
#                     "awardName": "Gordon E. Sawyer Award",
#                     "trivia": [],
#                     "categories": [
#                         {
#                             "categoryName": null,
#                             "nominations": [
#                                 {
#                                     "primaryNominees": [],
#                                     "secondaryNominees": [],
#                                     "categoryName": null,
#                                     "winAnnouncementTime": null,
#                                     "notes": null,
#                                     "songNames": [],
#                                     "episodeNames": [],
#                                     "awardNominationId": "an0051228",
#                                     "characterNames": [],
#                                     "awardName": "Gordon E. Sawyer Award",
#                                     "isWinner": true
#                                 }
#                             ],
#                             "isPremiumCategory": false
#                         }
#                     ],
#                     "id": "aw0000024"
#                 }
#             ],
#             "requestKey": {
#                 "year": 2000,
#                 "occurrence": 1,
#                 "preferredLanguage": "en",
#                 "preferredRegion": "US",
#                 "userRegion": "US",
#                 "eventId": "ev0000003"
#             },
#             "eventName": "Academy Awards, USA",
#             "eventEditionId": "ee0040348",
#             "occurrence": 1,
#             "eventId": "ev0000003",
#             "year": 2000
#         },
#         "alwaysDisplayAwardNames": true,
#         "shouldDisplayNotes": true,
#         "showOnlyPremiumCategories": false,
#         "mobile": false
#     }
# }
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1b6c74c6d8cb> in <module>
#      16         award_dict[category_name] = []
#      17         noms = title['nominations']
# ---> 18         category_names.append(category_name)
#      19         for nom in noms:
#      20             if len(nom['secondaryNominees'])!=0:
#
# AttributeError: 'dict' object has no attribute 'append'
