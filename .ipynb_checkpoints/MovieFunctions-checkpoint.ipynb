# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time, os
from time import sleep
from random import randint
import re
import json
from fake_useragent import UserAgent
import math

# %%
# url = 'https://www.imdb.com/title/tt1302006/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, "lxml")

# %%
def get_movie_crew_and_genre(soup,field_name):
    movie_crew_list = []
    for a in soup.find('h4', text=re.compile(field_name)).parent.find_all('a'):
        movie_crew_list.append(a.text.strip())
    return movie_crew_list

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
import dateutil.parser

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %%
def get_movie_dict(titleId):
    
    url = 'https://www.imdb.com/title/'+str(titleId)
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    
    title_div = soup.find('div',class_='title_wrapper')
    title_div

    IMDB_id = titleId
    
    #title 
    title = get_movie_value(soup,'title')
    title = title.split('(')[0].strip()

    #Get the directors for the movie
    directors = get_movie_crew_and_genre(soup,'Director')


    #get the writers for the movie
    writers = get_movie_crew_and_genre(soup,'Writer')

    #get the cast of the movie:
    casts = get_movie_crew_and_genre(soup,'Stars')
    casts = casts[0:3]

    #genre
    genres = get_movie_crew_and_genre(soup,'Genres')

    #country 
    country = get_movie_crew_and_genre(soup,'Country')
    country = country[0]

    #language
    language = get_movie_crew_and_genre(soup,'Language')
    language = language[0]

    #runtime
    runtime = get_movie_value(soup,'Run')
    try:
        converted_runtime = int(runtime.split()[0])
    except:
        converted_runtime = 0

    #rating
    release_and_rating_string = title_div.find('div',{'class':'subtext'}).text
    rating = release_and_rating_string.split('|')[0].strip()
    rating

    #Release Date
    release_and_rating_string = title_div.find('div',{'class':'subtext'}).text
    release = release_and_rating_string.split('|')[3].strip()
    release = release.split('(')
    release = release[0]
    print(release)
    #converted_release_date = to_date(release_date)

    try:
        budget = soup.find('h4', text=re.compile('Budget')).parent.text
        budget = budget.split('\n')
        budget = budget[1].split('$')
        budget = budget[1].replace(',','')
        budget = int(budget) 
    except:
        budget = math.nan


    #metacritic score
    metacritic_score = soup.find('div',{'class':'titleReviewBar'}).span.text
    try:
        metacritic_score = int(metacritic_score)
    except:
        metacritic_score = math.nan
    
    headers = ['IMDBId','movie title','director(s)','writer(s)','casts','genre(s)','language','country',
           'runtime (mins)', 'mpaarating', 'release date','metacritic score','budget']

    movie_data = []
    movie_dict = dict(zip(headers, [IMDB_id,
                                    title,
                                    directors,
                                    writers,
                                    casts,
                                    genres,
                                    language,
                                    country,
                                    converted_runtime,
                                    rating,
                                    release,
                                    metacritic_score,
                                    budget]))

    movie_data.append(movie_dict)
    sleep(randint(2,10))
    return movie_data

# %%
get_movie_dict('tt5052448')
# Out:
# 24 February 2017
# [{'IMDBId': 'tt5052448',
#   'movie title': 'Get Out',
#   'director(s)': ['Jordan Peele'],
#   'writer(s)': ['Jordan Peele'],
#   'casts': ['Daniel Kaluuya', 'Allison Williams', 'Bradley Whitford'],
#   'genre(s)': ['Horror', 'Mystery', 'Thriller'],
#   'language': 'English',
#   'country': 'USA',
#   'runtime (mins)': 104,
#   'mpaarating': 'R',
#   'release date': '24 February 2017 ',
#   'metacritic score': 85,
#   'budget': 4500000}]

# %%
# headers = ['IMDBId','movie title','director(s)','writer(s)','casts','genre(s)','language','country',
#            'runtime (mins)', 'rating', 'release date','budget']

# movie_data = []
# movie_dict = dict(zip(headers, [IMDB_id,
#                                 title,
#                                 directors,
#                                 writers,
#                                 casts,
#                                 genres,
#                                 language,
#                                 country,
#                                 converted_runtime,
#                                 converted_release_date,
#                                 rating, 
#                                 budget]))

# movie_data.append(movie_dict)
# movie_data

# %%
distribution_list = []
links = ['tt0454876',
 'tt0092593',
 'tt7131622',
 'tt0088683',
 'tt0090886',
 'tt0268126',
 'tt0090756',
 'tt1532503',
 'tt0119164',
 'tt0478304',
 'tt0100557',
 'tt0082095',
 'tt0167404',
 'tt0308644',
 'tt0245712',
 'tt0080678',
 'tt6304162',
 'tt0120338',
 'tt4595882',
 'tt2080374',
 'tt0107206',
 'tt0111495',
 'tt0150915',
 'tt0387131',
 'tt2582802',
 'tt0124315',
 'tt0450259',
 'tt0079522',
 'tt4550098',
 'tt2278388',
 'tt0138097',
 'tt3224458',
 'tt2852470',
 'tt0082971',
 'tt0414387',
 'tt0117364',
 'tt0404203',
 'tt0113720']
for link in links:
    distribution_list.append(get_movie_dict(link))
distribution_list
# Out:
# 21 November 2012
# 12 February 1988
# 26 July 2019
# 27 September 1985
# 23 January 1987
# 14 February 2003
# 23 October 1986
# 9 June 2011
# 19 September 1997
# 17 May 2011
# March 1991
# 18 December 1981
# 6 August 1999
# 17 December 2004
# 13 April 2001
# 10 October 1980
# 1 June 2017
# 19 December 1997
# 2 November 2018
# 23 October 2015
# 9 July 1993
# 23 November 1994
# 5 February 1999
# 31 August 2005
# 15 October 2014
# 7 January 2000
# 8 December 2006
# 25 April 1979
# 9 December 2016
# 28 March 2014
# 8 January 1999
# 22 November 2019
# 19 March 2014
# 12 June 1981
# 23 November 2005
# 17 January 1997
# 9 February 2007
# 8 March 1996
# [[{'IMDBId': 'tt0454876',
#    'movie title': 'Life of Pi',
#    'director(s)': ['Ang Lee'],
#    'writer(s)': ['Yann Martel', 'David Magee'],
#    'casts': ['Suraj Sharma', 'Irrfan Khan', 'Adil Hussain'],
#    'genre(s)': ['Adventure', 'Drama', 'Fantasy'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 127,
#    'mpaarating': 'PG',
#    'release date': '21 November 2012 ',
#    'metacritic score': 79,
#    'budget': 120000000}],
#  [{'IMDBId': 'tt0092593',
#    'movie title': 'Au Revoir les Enfants',
#    'director(s)': ['Louis Malle'],
#    'writer(s)': ['Louis Malle', 'Louis Malle'],
#    'casts': ['Gaspard Manesse', 'Raphael Fejtö', 'Francine Racette'],
#    'genre(s)': ['Drama', 'War'],
#    'language': 'French',
#    'country': 'France',
#    'runtime (mins)': 104,
#    'mpaarating': 'PG',
#    'release date': '12 February 1988 ',
#    'metacritic score': 88,
#    'budget': nan}],
#  [{'IMDBId': 'tt7131622',
#    'movie title': 'Once Upon a Time... in Hollywood',
#    'director(s)': ['Quentin Tarantino'],
#    'writer(s)': ['Quentin Tarantino'],
#    'casts': ['Leonardo DiCaprio', 'Brad Pitt', 'Margot Robbie'],
#    'genre(s)': ['Comedy', 'Drama'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 161,
#    'mpaarating': 'R',
#    'release date': '26 July 2019 ',
#    'metacritic score': 83,
#    'budget': 90000000}],
#  [{'IMDBId': 'tt0088683',
#    'movie title': 'Agnes of God',
#    'director(s)': ['Norman Jewison'],
#    'writer(s)': ['John Pielmeier', 'John Pielmeier'],
#    'casts': ['Jane Fonda', 'Anne Bancroft', 'Meg Tilly'],
#    'genre(s)': ['Drama', 'Mystery'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 98,
#    'mpaarating': 'PG-13',
#    'release date': '27 September 1985 ',
#    'metacritic score': 52,
#    'budget': 10000000}],
#  [{'IMDBId': 'tt0090886',
#    'movie title': 'Crimes of the Heart',
#    'director(s)': ['Bruce Beresford'],
#    'writer(s)': ['Beth Henley', 'Beth Henley'],
#    'casts': ['Diane Keaton', 'Jessica Lange', 'Sissy Spacek'],
#    'genre(s)': ['Comedy', 'Drama'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 105,
#    'mpaarating': 'PG-13',
#    'release date': '23 January 1987 ',
#    'metacritic score': nan,
#    'budget': 20000000}],
#  [{'IMDBId': 'tt0268126',
#    'movie title': 'Adaptation.',
#    'director(s)': ['Spike Jonze'],
#    'writer(s)': ['Susan Orlean', 'Charlie Kaufman'],
#    'casts': ['Nicolas Cage', 'Meryl Streep', 'Chris Cooper'],
#    'genre(s)': ['Comedy', 'Drama'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 115,
#    'mpaarating': 'R',
#    'release date': '14 February 2003 ',
#    'metacritic score': 83,
#    'budget': 19000000}],
#  [{'IMDBId': 'tt0090756',
#    'movie title': 'Blue Velvet',
#    'director(s)': ['David Lynch'],
#    'writer(s)': ['David Lynch'],
#    'casts': ['Isabella Rossellini', 'Kyle MacLachlan', 'Dennis Hopper'],
#    'genre(s)': ['Drama', 'Mystery', 'Thriller'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 120,
#    'mpaarating': 'R',
#    'release date': '23 October 1986 ',
#    'metacritic score': 76,
#    'budget': 6000000}],
#  [{'IMDBId': 'tt1532503',
#    'movie title': 'Beginners',
#    'director(s)': ['Mike Mills'],
#    'writer(s)': ['Mike Mills'],
#    'casts': ['Ewan McGregor', 'Christopher Plummer', 'Mélanie Laurent'],
#    'genre(s)': ['Comedy', 'Drama', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 105,
#    'mpaarating': 'R',
#    'release date': '9 June 2011 ',
#    'metacritic score': 81,
#    'budget': 3200000}],
#  [{'IMDBId': 'tt0119164',
#    'movie title': 'The Full Monty',
#    'director(s)': ['Peter Cattaneo'],
#    'writer(s)': ['Simon Beaufoy'],
#    'casts': ['Robert Carlyle', 'Tom Wilkinson', 'Mark Addy'],
#    'genre(s)': ['Comedy', 'Drama'],
#    'language': 'English',
#    'country': 'UK',
#    'runtime (mins)': 91,
#    'mpaarating': 'R',
#    'release date': '19 September 1997 ',
#    'metacritic score': 75,
#    'budget': 3500000}],
#  [{'IMDBId': 'tt0478304',
#    'movie title': 'The Tree of Life',
#    'director(s)': ['Terrence Malick'],
#    'writer(s)': ['Terrence Malick'],
#    'casts': ['Brad Pitt', 'Sean Penn', 'Jessica Chastain'],
#    'genre(s)': ['Drama', 'Fantasy'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 139,
#    'mpaarating': 'PG-13',
#    'release date': '17 May 2011 ',
#    'metacritic score': 85,
#    'budget': 32000000}],
#  [{'IMDBId': 'tt0100557',
#    'movie title': 'The Nasty Girl',
#    'director(s)': ['Michael Verhoeven'],
#    'writer(s)': ['Michael Verhoeven'],
#    'casts': ['Lena Stolze', 'Hans-Reinhard Müller', 'Monika Baumgartner'],
#    'genre(s)': ['Comedy', 'Drama', 'History', 'War'],
#    'language': 'German',
#    'country': 'West Germany',
#    'runtime (mins)': 0,
#    'mpaarating': 'PG-13',
#    'release date': 'March 1991 ',
#    'metacritic score': nan,
#    'budget': nan}],
#  [{'IMDBId': 'tt0082095',
#    'movie title': 'Das Boot ist voll',
#    'director(s)': ['Markus Imhoof'],
#    'writer(s)': ['Alfred A. Haesler', 'Markus Imhoof'],
#    'casts': ['Tina Engel', 'Hans Diehl', 'Martin Walz'],
#    'genre(s)': ['Drama', 'War'],
#    'language': 'German',
#    'country': 'Switzerland',
#    'runtime (mins)': 101,
#    'mpaarating': 'PG',
#    'release date': '18 December 1981 ',
#    'metacritic score': nan,
#    'budget': nan}],
#  [{'IMDBId': 'tt0167404',
#    'movie title': 'The Sixth Sense',
#    'director(s)': ['M. Night Shyamalan'],
#    'writer(s)': ['M. Night Shyamalan'],
#    'casts': ['Bruce Willis', 'Haley Joel Osment', 'Toni Collette'],
#    'genre(s)': ['Drama', 'Mystery', 'Thriller'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 107,
#    'mpaarating': 'PG-13',
#    'release date': '6 August 1999 ',
#    'metacritic score': 64,
#    'budget': 40000000}],
#  [{'IMDBId': 'tt0308644',
#    'movie title': 'Finding Neverland',
#    'director(s)': ['Marc Forster'],
#    'writer(s)': ['Allan Knee', 'David Magee'],
#    'casts': ['Johnny Depp', 'Kate Winslet', 'Julie Christie'],
#    'genre(s)': ['Biography', 'Drama', 'Family'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 106,
#    'mpaarating': 'PG',
#    'release date': '17 December 2004 ',
#    'metacritic score': 67,
#    'budget': 25000000}],
#  [{'IMDBId': 'tt0245712',
#    'movie title': 'Amores Perros',
#    'director(s)': ['Alejandro G. Iñárritu'],
#    'writer(s)': ['Guillermo Arriaga'],
#    'casts': ['Emilio Echevarría', 'Gael García Bernal', 'Goya Toledo'],
#    'genre(s)': ['Drama', 'Thriller'],
#    'language': 'Spanish',
#    'country': 'Mexico',
#    'runtime (mins)': 154,
#    'mpaarating': 'R',
#    'release date': '13 April 2001 ',
#    'metacritic score': 83,
#    'budget': 2000000}],
#  [{'IMDBId': 'tt0080678',
#    'movie title': 'The Elephant Man',
#    'director(s)': ['David Lynch'],
#    'writer(s)': ['Christopher De Vore', 'Eric Bergren', '3 more credits'],
#    'casts': ['Anthony Hopkins', 'John Hurt', 'Anne Bancroft'],
#    'genre(s)': ['Biography', 'Drama'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 124,
#    'mpaarating': 'PG',
#    'release date': '10 October 1980 ',
#    'metacritic score': 78,
#    'budget': 5000000}],
#  [{'IMDBId': 'tt6304162',
#    'movie title': 'Loveless',
#    'director(s)': ['Andrey Zvyagintsev'],
#    'writer(s)': ['Oleg Negin', 'Andrey Zvyagintsev'],
#    'casts': ['Maryana Spivak', 'Aleksey Rozin', 'Matvey Novikov'],
#    'genre(s)': ['Drama'],
#    'language': 'Russian',
#    'country': 'Russia',
#    'runtime (mins)': 127,
#    'mpaarating': 'R',
#    'release date': '1 June 2017 ',
#    'metacritic score': 86,
#    'budget': nan}],
#  [{'IMDBId': 'tt0120338',
#    'movie title': 'Titanic',
#    'director(s)': ['James Cameron'],
#    'writer(s)': ['James Cameron'],
#    'casts': ['Leonardo DiCaprio', 'Kate Winslet', 'Billy Zane'],
#    'genre(s)': ['Drama', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 194,
#    'mpaarating': 'PG-13',
#    'release date': '19 December 1997 ',
#    'metacritic score': 75,
#    'budget': 200000000}],
#  [{'IMDBId': 'tt4595882',
#    'movie title': 'Can You Ever Forgive Me?',
#    'director(s)': ['Marielle Heller'],
#    'writer(s)': ['Nicole Holofcener', 'Jeff Whitty'],
#    'casts': ['Melissa McCarthy', 'Richard E. Grant', 'Dolly Wells'],
#    'genre(s)': ['Biography', 'Comedy', 'Crime', 'Drama'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 106,
#    'mpaarating': 'R',
#    'release date': '2 November 2018 ',
#    'metacritic score': 87,
#    'budget': 10000000}],
#  [{'IMDBId': 'tt2080374',
#    'movie title': 'Steve Jobs',
#    'director(s)': ['Danny Boyle'],
#    'writer(s)': ['Aaron Sorkin', 'Walter Isaacson'],
#    'casts': ['Michael Fassbender', 'Kate Winslet', 'Seth Rogen'],
#    'genre(s)': ['Biography', 'Drama'],
#    'language': 'English',
#    'country': 'UK',
#    'runtime (mins)': 122,
#    'mpaarating': 'R',
#    'release date': '23 October 2015 ',
#    'metacritic score': 82,
#    'budget': 30000000}],
#  [{'IMDBId': 'tt0107206',
#    'movie title': 'In the Line of Fire',
#    'director(s)': ['Wolfgang Petersen'],
#    'writer(s)': ['Jeff Maguire'],
#    'casts': ['Clint Eastwood', 'John Malkovich', 'Rene Russo'],
#    'genre(s)': ['Action', 'Crime', 'Drama', 'Thriller'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 128,
#    'mpaarating': 'R',
#    'release date': '9 July 1993 ',
#    'metacritic score': 74,
#    'budget': 40000000}],
#  [{'IMDBId': 'tt0111495',
#    'movie title': 'Three Colors: Red',
#    'director(s)': ['Krzysztof Kieslowski'],
#    'writer(s)': ['Krzysztof Kieslowski',
#     'Krzysztof Piesiewicz',
#     '4 more credits'],
#    'casts': ['Irène Jacob', 'Jean-Louis Trintignant', 'Frédérique Feder'],
#    'genre(s)': ['Drama', 'Mystery', 'Romance'],
#    'language': 'French',
#    'country': 'Switzerland',
#    'runtime (mins)': 99,
#    'mpaarating': 'R',
#    'release date': '23 November 1994 ',
#    'metacritic score': 100,
#    'budget': nan}],
#  [{'IMDBId': 'tt0150915',
#    'movie title': 'Hilary and Jackie',
#    'director(s)': ['Anand Tucker'],
#    'writer(s)': ['Hilary du Pré', 'Piers du Pré', '1 more credit'],
#    'casts': ['Emily Watson', 'Rachel Griffiths', 'James Frain'],
#    'genre(s)': ['Biography', 'Drama', 'Music'],
#    'language': 'English',
#    'country': 'UK',
#    'runtime (mins)': 121,
#    'mpaarating': 'R',
#    'release date': '5 February 1999 ',
#    'metacritic score': 78,
#    'budget': 7000000}],
#  [{'IMDBId': 'tt0387131',
#    'movie title': 'The Constant Gardener',
#    'director(s)': ['Fernando Meirelles'],
#    'writer(s)': ['Jeffrey Caine', 'John le Carré'],
#    'casts': ['Ralph Fiennes', 'Rachel Weisz', 'Danny Huston'],
#    'genre(s)': ['Drama', 'Mystery', 'Romance', 'Thriller'],
#    'language': 'English',
#    'country': 'UK',
#    'runtime (mins)': 129,
#    'mpaarating': 'R',
#    'release date': '31 August 2005 ',
#    'metacritic score': 82,
#    'budget': 25000000}],
#  [{'IMDBId': 'tt2582802',
#    'movie title': 'Whiplash',
#    'director(s)': ['Damien Chazelle'],
#    'writer(s)': ['Damien Chazelle'],
#    'casts': ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist'],
#    'genre(s)': ['Drama', 'Music'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 106,
#    'mpaarating': 'R',
#    'release date': '15 October 2014 ',
#    'metacritic score': 88,
#    'budget': 3300000}],
#  [{'IMDBId': 'tt0124315',
#    'movie title': 'The Cider House Rules',
#    'director(s)': ['Lasse Hallström'],
#    'writer(s)': ['John Irving', 'John Irving'],
#    'casts': ['Tobey Maguire', 'Charlize Theron', 'Michael Caine'],
#    'genre(s)': ['Drama', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 0,
#    'mpaarating': 'PG-13',
#    'release date': '7 January 2000 ',
#    'metacritic score': 75,
#    'budget': 24000000}],
#  [{'IMDBId': 'tt0450259',
#    'movie title': 'Blood Diamond',
#    'director(s)': ['Edward Zwick'],
#    'writer(s)': ['Charles Leavitt', 'Charles Leavitt', '1 more credit'],
#    'casts': ['Leonardo DiCaprio', 'Djimon Hounsou', 'Jennifer Connelly'],
#    'genre(s)': ['Adventure', 'Drama', 'Thriller'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 143,
#    'mpaarating': 'R',
#    'release date': '8 December 2006 ',
#    'metacritic score': 64,
#    'budget': 100000000}],
#  [{'IMDBId': 'tt0079522',
#    'movie title': 'Manhattan',
#    'director(s)': ['Woody Allen'],
#    'writer(s)': ['Woody Allen', 'Marshall Brickman'],
#    'casts': ['Woody Allen', 'Diane Keaton', 'Mariel Hemingway'],
#    'genre(s)': ['Comedy', 'Drama', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 96,
#    'mpaarating': 'R',
#    'release date': '25 April 1979 ',
#    'metacritic score': 83,
#    'budget': 9000000}],
#  [{'IMDBId': 'tt4550098',
#    'movie title': 'Nocturnal Animals',
#    'director(s)': ['Tom Ford'],
#    'writer(s)': ['Tom Ford', 'Austin Wright'],
#    'casts': ['Amy Adams', 'Jake Gyllenhaal', 'Michael Shannon'],
#    'genre(s)': ['Drama', 'Thriller'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 116,
#    'mpaarating': 'R',
#    'release date': '9 December 2016 ',
#    'metacritic score': 67,
#    'budget': 22500000}],
#  [{'IMDBId': 'tt2278388',
#    'movie title': 'The Grand Budapest Hotel',
#    'director(s)': ['Wes Anderson'],
#    'writer(s)': ['Stefan Zweig', 'Wes Anderson', '2 more credits'],
#    'casts': ['Ralph Fiennes', 'F. Murray Abraham', 'Mathieu Amalric'],
#    'genre(s)': ['Adventure', 'Comedy', 'Crime'],
#    'language': 'English',
#    'country': 'Germany',
#    'runtime (mins)': 99,
#    'mpaarating': 'R',
#    'release date': '28 March 2014 ',
#    'metacritic score': 88,
#    'budget': 25000000}],
#  [{'IMDBId': 'tt0138097',
#    'movie title': 'Shakespeare in Love',
#    'director(s)': ['John Madden'],
#    'writer(s)': ['Marc Norman', 'Tom Stoppard'],
#    'casts': ['Gwyneth Paltrow', 'Joseph Fiennes', 'Geoffrey Rush'],
#    'genre(s)': ['Comedy', 'Drama', 'History', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 123,
#    'mpaarating': 'R',
#    'release date': '8 January 1999 ',
#    'metacritic score': 87,
#    'budget': 25000000}],
#  [{'IMDBId': 'tt3224458',
#    'movie title': 'A Beautiful Day in the Neighborhood',
#    'director(s)': ['Marielle Heller'],
#    'writer(s)': ['Micah Fitzerman-Blue', 'Noah Harpster', '1 more credit'],
#    'casts': ['Tom Hanks', 'Matthew Rhys', 'Chris Cooper'],
#    'genre(s)': ['Biography', 'Drama'],
#    'language': 'English',
#    'country': 'China',
#    'runtime (mins)': 109,
#    'mpaarating': 'PG',
#    'release date': '22 November 2019 ',
#    'metacritic score': 80,
#    'budget': 25000000}],
#  [{'IMDBId': 'tt2852470',
#    'movie title': 'The Missing Picture',
#    'director(s)': ['Rithy Panh'],
#    'writer(s)': ['Rithy Panh', 'Christophe Bataille'],
#    'casts': ['Randal Douc', 'Jean-Baptiste Phou'],
#    'genre(s)': ['Documentary'],
#    'language': 'French',
#    'country': 'Cambodia',
#    'runtime (mins)': 92,
#    'mpaarating': 'Not Rated',
#    'release date': '19 March 2014 ',
#    'metacritic score': 87,
#    'budget': nan}],
#  [{'IMDBId': 'tt0082971',
#    'movie title': 'Raiders of the Lost Ark',
#    'director(s)': ['Steven Spielberg'],
#    'writer(s)': ['Lawrence Kasdan', 'George Lucas', '1 more credit'],
#    'casts': ['Harrison Ford', 'Karen Allen', 'Paul Freeman'],
#    'genre(s)': ['Action', 'Adventure'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 115,
#    'mpaarating': 'PG',
#    'release date': '12 June 1981 ',
#    'metacritic score': 85,
#    'budget': 18000000}],
#  [{'IMDBId': 'tt0414387',
#    'movie title': 'Pride & Prejudice',
#    'director(s)': ['Joe Wright'],
#    'writer(s)': ['Deborah Moggach', 'Jane Austen'],
#    'casts': ['Keira Knightley', 'Matthew Macfadyen', 'Brenda Blethyn'],
#    'genre(s)': ['Drama', 'Romance'],
#    'language': 'English',
#    'country': 'France',
#    'runtime (mins)': 129,
#    'mpaarating': 'PG',
#    'release date': '23 November 2005 ',
#    'metacritic score': 82,
#    'budget': 28000000}],
#  [{'IMDBId': 'tt0117364',
#    'movie title': 'The Portrait of a Lady',
#    'director(s)': ['Jane Campion'],
#    'writer(s)': ['Henry James', 'Laura Jones'],
#    'casts': ['Nicole Kidman', 'John Malkovich', 'Barbara Hershey'],
#    'genre(s)': ['Drama', 'Romance'],
#    'language': 'English',
#    'country': 'UK',
#    'runtime (mins)': 144,
#    'mpaarating': 'PG-13',
#    'release date': '17 January 1997 ',
#    'metacritic score': 61,
#    'budget': nan}],
#  [{'IMDBId': 'tt0404203',
#    'movie title': 'Little Children',
#    'director(s)': ['Todd Field'],
#    'writer(s)': ['Todd Field', 'Tom Perrotta', '1 more credit'],
#    'casts': ['Kate Winslet', 'Jennifer Connelly', 'Patrick Wilson'],
#    'genre(s)': ['Comedy', 'Drama', 'Romance'],
#    'language': 'English',
#    'country': 'USA',
#    'runtime (mins)': 137,
#    'mpaarating': 'R',
#    'release date': '9 February 2007 ',
#    'metacritic score': 75,
#    'budget': 26000000}],
#  [{'IMDBId': 'tt0113720',
#    'movie title': 'Love Lessons',
#    'director(s)': ['Bo Widerberg'],
#    'writer(s)': ['Bo Widerberg'],
#    'casts': ['Johan Widerberg', 'Marika Lagercrantz', 'Tomas von Brömssen'],
#    'genre(s)': ['Drama', 'Romance', 'War'],
#    'language': 'Swedish',
#    'country': 'Denmark',
#    'runtime (mins)': 130,
#    'mpaarating': 'Unrated',
#    'release date': '8 March 1996 ',
#    'metacritic score': nan,
#    'budget': nan}]]
