# %% [markdown]
# ## Read in Oscar CSV back into Dataframe

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
oscars_df = pd.read_csv('oscar_info_movies.csv')

# %%
oscars_df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  metacritic score        budget   Total_Noms
# count  3712.000000   3712.000000       3303.000000  2.947000e+03  3712.000000
# mean   1855.500000   1855.500000         76.183470  4.557873e+07     4.961746
# std    1071.706427   1071.706427         12.732737  5.040656e+07     3.545241
# min       0.000000      0.000000         16.000000  5.000000e+04     1.000000
# 25%     927.750000    927.750000         68.000000  1.440000e+07     2.000000
# 50%    1855.500000   1855.500000         78.000000  2.500000e+07     4.000000
# 75%    2783.250000   2783.250000         86.000000  5.500000e+07     8.000000
# max    3711.000000   3711.000000        100.000000  3.210000e+08    16.000000

# %%
#oscars_df['Unnamed: 0'].value_counts()

# %%
oscars_df.drop(columns = ['Unnamed: 0','Unnamed: 0.1',
      ],inplace=True)

# %%
oscars_df.shape
# Out:
# (3712, 16)

# %%
oscars_df.tail()
# Out:
#          IMDBId      movie title              director(s)  \
# 3707  tt0097351  Field of Dreams  ['Phil Alden Robinson']
# 3708  tt0097351  Field of Dreams  ['Phil Alden Robinson']
# 3709  tt0097351  Field of Dreams  ['Phil Alden Robinson']
# 3710  tt0281850     Fait d'hiver          ['Dirk Beliën']
# 3711  tt0087957      Purple Rain       ['Albert Magnoli']
#
#                                      writer(s)  \
# 3707  ['W.P. Kinsella', 'Phil Alden Robinson']
# 3708  ['W.P. Kinsella', 'Phil Alden Robinson']
# 3709  ['W.P. Kinsella', 'Phil Alden Robinson']
# 3710                     ['Johan Verschueren']
# 3711       ['Albert Magnoli', 'William Blinn']
#
#                                                   casts  \
# 3707  ['Kevin Costner', 'James Earl Jones', 'Ray Lio...
# 3708  ['Kevin Costner', 'James Earl Jones', 'Ray Lio...
# 3709  ['Kevin Costner', 'James Earl Jones', 'Ray Lio...
# 3710  ['Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decl...
# 3711       ['Prince', 'Apollonia Kotero', 'Morris Day']
#
#                                      genre(s) language  country  \
# 3707  ['Drama', 'Family', 'Fantasy', 'Sport']  English      USA
# 3708  ['Drama', 'Family', 'Fantasy', 'Sport']  English      USA
# 3709  ['Drama', 'Family', 'Fantasy', 'Sport']  English      USA
# 3710  ['Short', 'Comedy', 'Drama', 'Romance']    Dutch  Belgium
# 3711            ['Drama', 'Music', 'Romance']  English      USA
#
#      runtime (mins) mpaarating release date  metacritic score     budget  \
# 3707       1h 47min         PG     5-May-89              57.0        NaN
# 3708       1h 47min         PG     5-May-89              57.0        NaN
# 3709       1h 47min         PG     5-May-89              57.0        NaN
# 3710           7min       7min          NaN               NaN    80000.0
# 3711       1h 51min          R    27-Jul-84              55.0  7200000.0
#
#      distributionCompany                                             Awards  \
# 3707  Universal Pictures                         Best Music, Original Score
# 3708  Universal Pictures                                       Best Picture
# 3709  Universal Pictures  Best Writing, Screenplay Based on Material fro...
# 3710                 NaN                       Best Short Film, Live Action
# 3711        Warner Bros.                    Best Music, Original Song Score
#
#       Total_Noms
# 3707           3
# 3708           3
# 3709           3
# 3710           1
# 3711           1

# %%
#oscars_df.to_csv('oscar_moviesBackup.csv',encoding='utf-8-sig')

# %%
oscars_df.head()
# Out:
#       IMDBId movie title       director(s)         writer(s)  \
# 0  tt0091763     Platoon  ['Oliver Stone']  ['Oliver Stone']
# 1  tt0091763     Platoon  ['Oliver Stone']  ['Oliver Stone']
# 2  tt0091763     Platoon  ['Oliver Stone']  ['Oliver Stone']
# 3  tt0091763     Platoon  ['Oliver Stone']  ['Oliver Stone']
# 4  tt0091763     Platoon  ['Oliver Stone']  ['Oliver Stone']
#
#                                                casts          genre(s)  \
# 0  ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']  ['Drama', 'War']
# 1  ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']  ['Drama', 'War']
# 2  ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']  ['Drama', 'War']
# 3  ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']  ['Drama', 'War']
# 4  ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']  ['Drama', 'War']
#
#   language country runtime (mins) mpaarating release date  metacritic score  \
# 0  English     USA             2h          R     6-Feb-87              92.0
# 1  English     USA             2h          R     6-Feb-87              92.0
# 2  English     USA             2h          R     6-Feb-87              92.0
# 3  English     USA             2h          R     6-Feb-87              92.0
# 4  English     USA             2h          R     6-Feb-87              92.0
#
#       budget distributionCompany                           Awards  Total_Noms
# 0  6000000.0      Orion Pictures  Best Actor in a Supporting Role           7
# 1  6000000.0      Orion Pictures              Best Cinematography           7
# 2  6000000.0      Orion Pictures                    Best Director           7
# 3  6000000.0      Orion Pictures                Best Film Editing           7
# 4  6000000.0      Orion Pictures                     Best Picture           7

# %%
oscars_df.columns
# Out:
# Index(['IMDBId', 'movie title', 'director(s)', 'writer(s)', 'casts',
#        'genre(s)', 'language', 'country', 'runtime (mins)', 'mpaarating',
#        'release date', 'metacritic score', 'budget', 'distributionCompany',
#        'Awards', 'Total_Noms'],
#       dtype='object')

# %%
oscars_df.shape
# Out:
# (3712, 16)

# %%
oscars_df['IMDBId'].value_counts()
# Out:
# tt0401383    16
# tt0120338    14
# tt5580390    13
# tt0138097    13
# tt3783958    13
#              ..
# tt0097044     1
# tt0113671     1
# tt1313104     1
# tt0088161     1
# tt0114808     1
# Name: IMDBId, Length: 1493, dtype: int64

# %%
oscars_df.drop_duplicates(subset=['IMDBId'],inplace=True)

# %%
def clean_columns(column):
    oscars_df[column] = oscars_df[column].str.strip('[]').astype(str)
    return oscars_df

# %%
def remove_quotation(column):
    oscars_df[column]= oscars_df[column].str.strip()
    oscars_df[column]= oscars_df[column].str.strip("''")
    oscars_df[column]= oscars_df[column].str.strip("'")
    return oscars_df

# %%
clean_columns('writer(s)')
clean_columns('director(s)')
clean_columns('casts')
clean_columns('genre(s)')
# Out:
#          IMDBId                 movie title             director(s)  \
# 0     tt0091763                     Platoon          'Oliver Stone'
# 7     tt0082979                        Reds         'Warren Beatty'
# 19    tt0084434  An Officer and a Gentleman       'Taylor Hackford'
# 25    tt0119360                    In & Out              'Frank Oz'
# 26    tt0292542            Son of the Bride  'Juan José Campanella'
# ...         ...                         ...                     ...
# 3705  tt3346410                      Helium         'Anders Walter'
# 3706  tt2980764                Get a Horse!      'Lauren MacMullan'
# 3707  tt0097351             Field of Dreams   'Phil Alden Robinson'
# 3710  tt0281850                Fait d'hiver           'Dirk Beliën'
# 3711  tt0087957                 Purple Rain        'Albert Magnoli'
#
#                                               writer(s)  \
# 0                                        'Oliver Stone'
# 7                   'Warren Beatty', 'Trevor Griffiths'
# 19                                'Douglas Day Stewart'
# 25                                       'Paul Rudnick'
# 26           'Juan José Campanella', 'Fernando Castets'
# ...                                                 ...
# 3705   'Christian Gamst Miller-Harris', 'Anders Walter'
# 3706  'Lauren MacMullan', 'Paul Briggs', '2 more cre...
# 3707             'W.P. Kinsella', 'Phil Alden Robinson'
# 3710                                'Johan Verschueren'
# 3711                  'Albert Magnoli', 'William Blinn'
#
#                                                   casts  \
# 0       'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7     'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19        'Richard Gere', 'Debra Winger', 'David Keith'
# 25          'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26    'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
# ...                                                 ...
# 3705  'Casper Crump', 'Pelle Falk Krusbæk', 'Marijan...
# 3706  'Walt Disney', 'Marcellite Garner', 'Russi Tay...
# 3707  'Kevin Costner', 'James Earl Jones', 'Ray Liotta'
# 3710  'Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decle...
# 3711         'Prince', 'Apollonia Kotero', 'Morris Day'
#
#                                         genre(s) language    country  \
# 0                                 'Drama', 'War'  English        USA
# 7     'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                            'Drama', 'Romance'  English        USA
# 25                           'Comedy', 'Romance'  English        USA
# 26                             'Comedy', 'Drama'  Spanish  Argentina
# ...                                          ...      ...        ...
# 3705                  'Short', 'Drama', 'Family'   Danish    Denmark
# 3706    'Animation', 'Short', 'Comedy', 'Family'  English        USA
# 3707       'Drama', 'Family', 'Fantasy', 'Sport'  English        USA
# 3710       'Short', 'Comedy', 'Drama', 'Romance'    Dutch    Belgium
# 3711                 'Drama', 'Music', 'Romance'  English        USA
#
#      runtime (mins) mpaarating release date  metacritic score      budget  \
# 0                2h          R     6-Feb-87              92.0   6000000.0
# 7          3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19          2h 4min          R    13-Aug-82              75.0   7500000.0
# 25         1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26          2h 3min          R    16-Aug-01              68.0         NaN
# ...             ...        ...          ...               ...         ...
# 3705          23min  Not Rated    31-Jan-14               NaN         NaN
# 3706           6min          G    27-Nov-13               NaN         NaN
# 3707       1h 47min         PG     5-May-89              57.0         NaN
# 3710           7min       7min          NaN               NaN     80000.0
# 3711       1h 51min          R    27-Jul-84              55.0   7200000.0
#
#                       distributionCompany                             Awards  \
# 0                          Orion Pictures    Best Actor in a Supporting Role
# 7                      Paramount Pictures       Best Actor in a Leading Role
# 19                     Paramount Pictures    Best Actor in a Supporting Role
# 25                     Paramount Pictures  Best Actress in a Supporting Role
# 26                 Sony Pictures Classics         Best Foreign Language Film
# ...                                   ...                                ...
# 3705                                  NaN       Best Short Film, Live Action
# 3706  Walt Disney Studios Motion Pictures          Best Short Film, Animated
# 3707                   Universal Pictures         Best Music, Original Score
# 3710                                  NaN       Best Short Film, Live Action
# 3711                         Warner Bros.    Best Music, Original Song Score
#
#       Total_Noms
# 0              7
# 7             12
# 19             6
# 25             1
# 26             1
# ...          ...
# 3705           1
# 3706           1
# 3707           3
# 3710           1
# 3711           1
#
# [1493 rows x 16 columns]

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title             director(s)  \
# 0   tt0091763                     Platoon          'Oliver Stone'
# 7   tt0082979                        Reds         'Warren Beatty'
# 19  tt0084434  An Officer and a Gentleman       'Taylor Hackford'
# 25  tt0119360                    In & Out              'Frank Oz'
# 26  tt0292542            Son of the Bride  'Juan José Campanella'
#
#                                      writer(s)  \
# 0                               'Oliver Stone'
# 7          'Warren Beatty', 'Trevor Griffiths'
# 19                       'Douglas Day Stewart'
# 25                              'Paul Rudnick'
# 26  'Juan José Campanella', 'Fernando Castets'
#
#                                                 casts  \
# 0     'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7   'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19      'Richard Gere', 'Debra Winger', 'David Keith'
# 25        'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26  'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
#
#                                       genre(s) language    country  \
# 0                               'Drama', 'War'  English        USA
# 7   'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                          'Drama', 'Romance'  English        USA
# 25                         'Comedy', 'Romance'  English        USA
# 26                           'Comedy', 'Drama'  Spanish  Argentina
#
#    runtime (mins) mpaarating release date  metacritic score      budget  \
# 0              2h          R     6-Feb-87              92.0   6000000.0
# 7        3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19        2h 4min          R    13-Aug-82              75.0   7500000.0
# 25       1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26        2h 3min          R    16-Aug-01              68.0         NaN
#
#        distributionCompany                             Awards  Total_Noms
# 0           Orion Pictures    Best Actor in a Supporting Role           7
# 7       Paramount Pictures       Best Actor in a Leading Role          12
# 19      Paramount Pictures    Best Actor in a Supporting Role           6
# 25      Paramount Pictures  Best Actress in a Supporting Role           1
# 26  Sony Pictures Classics         Best Foreign Language Film           1

# %% [markdown]
# Split the writers columns and explore how many writers are in each new column

# %%
oscars_df[['writer1','writer2','writer3']] = oscars_df['writer(s)'].apply(lambda x: pd.Series(x.split(',')))

# %%
oscars_df.tail()
# Out:
#          IMDBId      movie title            director(s)  \
# 3705  tt3346410           Helium        'Anders Walter'
# 3706  tt2980764     Get a Horse!     'Lauren MacMullan'
# 3707  tt0097351  Field of Dreams  'Phil Alden Robinson'
# 3710  tt0281850     Fait d'hiver          'Dirk Beliën'
# 3711  tt0087957      Purple Rain       'Albert Magnoli'
#
#                                               writer(s)  \
# 3705   'Christian Gamst Miller-Harris', 'Anders Walter'
# 3706  'Lauren MacMullan', 'Paul Briggs', '2 more cre...
# 3707             'W.P. Kinsella', 'Phil Alden Robinson'
# 3710                                'Johan Verschueren'
# 3711                  'Albert Magnoli', 'William Blinn'
#
#                                                   casts  \
# 3705  'Casper Crump', 'Pelle Falk Krusbæk', 'Marijan...
# 3706  'Walt Disney', 'Marcellite Garner', 'Russi Tay...
# 3707  'Kevin Costner', 'James Earl Jones', 'Ray Liotta'
# 3710  'Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decle...
# 3711         'Prince', 'Apollonia Kotero', 'Morris Day'
#
#                                       genre(s) language  country  \
# 3705                'Short', 'Drama', 'Family'   Danish  Denmark
# 3706  'Animation', 'Short', 'Comedy', 'Family'  English      USA
# 3707     'Drama', 'Family', 'Fantasy', 'Sport'  English      USA
# 3710     'Short', 'Comedy', 'Drama', 'Romance'    Dutch  Belgium
# 3711               'Drama', 'Music', 'Romance'  English      USA
#
#      runtime (mins) mpaarating release date  metacritic score     budget  \
# 3705          23min  Not Rated    31-Jan-14               NaN        NaN
# 3706           6min          G    27-Nov-13               NaN        NaN
# 3707       1h 47min         PG     5-May-89              57.0        NaN
# 3710           7min       7min          NaN               NaN    80000.0
# 3711       1h 51min          R    27-Jul-84              55.0  7200000.0
#
#                       distributionCompany                           Awards  \
# 3705                                  NaN     Best Short Film, Live Action
# 3706  Walt Disney Studios Motion Pictures        Best Short Film, Animated
# 3707                   Universal Pictures       Best Music, Original Score
# 3710                                  NaN     Best Short Film, Live Action
# 3711                         Warner Bros.  Best Music, Original Song Score
#
#       Total_Noms                          writer1                 writer2  \
# 3705           1  'Christian Gamst Miller-Harris'         'Anders Walter'
# 3706           1               'Lauren MacMullan'           'Paul Briggs'
# 3707           3                  'W.P. Kinsella'   'Phil Alden Robinson'
# 3710           1              'Johan Verschueren'                     NaN
# 3711           1                 'Albert Magnoli'         'William Blinn'
#
#                 writer3
# 3705                NaN
# 3706   '2 more credits'
# 3707                NaN
# 3710                NaN
# 3711                NaN

# %%
#Writers one should have the same number of writers as length of data frame
oscars_df['writer1'].count()
# Out:
# 1493

# %%
#Writers 2 should have less
oscars_df['writer2'].count()
# Out:
# 1070

# %%
#Writers 3 should have less
oscars_df['writer3'].count()
# Out:
# 572

# %%
oscars_df['writer3'].value_counts()
# Out:
#  '1 more credit'      274
#  '2 more credits'     149
#  '3 more credits'      74
#  '4 more credits'      27
#  '5 more credits'      16
#  '6 more credits'      13
#  '7 more credits'       6
#  '9 more credits'       3
#  '8 more credits'       2
#  '24 more credits'      2
#  '27 more credits'      1
#  '18 more credits'      1
#  '14 more credits'      1
#  '11 more credits'      1
#  '29 more credits'      1
#  '16 more credits'      1
# Name: writer3, dtype: int64

# %% [markdown]
# ### The third writers column is not telling us who wrote for the movie so that column will be dropped

# %%
oscars_df.drop(['writer(s)','writer3'], axis=1,inplace=True)

# %%
remove_quotation('writer1')
remove_quotation('writer2')
# Out:
#          IMDBId                 movie title             director(s)  \
# 0     tt0091763                     Platoon          'Oliver Stone'
# 7     tt0082979                        Reds         'Warren Beatty'
# 19    tt0084434  An Officer and a Gentleman       'Taylor Hackford'
# 25    tt0119360                    In & Out              'Frank Oz'
# 26    tt0292542            Son of the Bride  'Juan José Campanella'
# ...         ...                         ...                     ...
# 3705  tt3346410                      Helium         'Anders Walter'
# 3706  tt2980764                Get a Horse!      'Lauren MacMullan'
# 3707  tt0097351             Field of Dreams   'Phil Alden Robinson'
# 3710  tt0281850                Fait d'hiver           'Dirk Beliën'
# 3711  tt0087957                 Purple Rain        'Albert Magnoli'
#
#                                                   casts  \
# 0       'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7     'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19        'Richard Gere', 'Debra Winger', 'David Keith'
# 25          'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26    'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
# ...                                                 ...
# 3705  'Casper Crump', 'Pelle Falk Krusbæk', 'Marijan...
# 3706  'Walt Disney', 'Marcellite Garner', 'Russi Tay...
# 3707  'Kevin Costner', 'James Earl Jones', 'Ray Liotta'
# 3710  'Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decle...
# 3711         'Prince', 'Apollonia Kotero', 'Morris Day'
#
#                                         genre(s) language    country  \
# 0                                 'Drama', 'War'  English        USA
# 7     'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                            'Drama', 'Romance'  English        USA
# 25                           'Comedy', 'Romance'  English        USA
# 26                             'Comedy', 'Drama'  Spanish  Argentina
# ...                                          ...      ...        ...
# 3705                  'Short', 'Drama', 'Family'   Danish    Denmark
# 3706    'Animation', 'Short', 'Comedy', 'Family'  English        USA
# 3707       'Drama', 'Family', 'Fantasy', 'Sport'  English        USA
# 3710       'Short', 'Comedy', 'Drama', 'Romance'    Dutch    Belgium
# 3711                 'Drama', 'Music', 'Romance'  English        USA
#
#      runtime (mins) mpaarating release date  metacritic score      budget  \
# 0                2h          R     6-Feb-87              92.0   6000000.0
# 7          3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19          2h 4min          R    13-Aug-82              75.0   7500000.0
# 25         1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26          2h 3min          R    16-Aug-01              68.0         NaN
# ...             ...        ...          ...               ...         ...
# 3705          23min  Not Rated    31-Jan-14               NaN         NaN
# 3706           6min          G    27-Nov-13               NaN         NaN
# 3707       1h 47min         PG     5-May-89              57.0         NaN
# 3710           7min       7min          NaN               NaN     80000.0
# 3711       1h 51min          R    27-Jul-84              55.0   7200000.0
#
#                       distributionCompany                             Awards  \
# 0                          Orion Pictures    Best Actor in a Supporting Role
# 7                      Paramount Pictures       Best Actor in a Leading Role
# 19                     Paramount Pictures    Best Actor in a Supporting Role
# 25                     Paramount Pictures  Best Actress in a Supporting Role
# 26                 Sony Pictures Classics         Best Foreign Language Film
# ...                                   ...                                ...
# 3705                                  NaN       Best Short Film, Live Action
# 3706  Walt Disney Studios Motion Pictures          Best Short Film, Animated
# 3707                   Universal Pictures         Best Music, Original Score
# 3710                                  NaN       Best Short Film, Live Action
# 3711                         Warner Bros.    Best Music, Original Song Score
#
#       Total_Noms                        writer1              writer2
# 0              7                   Oliver Stone                  NaN
# 7             12                  Warren Beatty     Trevor Griffiths
# 19             6            Douglas Day Stewart                  NaN
# 25             1                   Paul Rudnick                  NaN
# 26             1           Juan José Campanella     Fernando Castets
# ...          ...                            ...                  ...
# 3705           1  Christian Gamst Miller-Harris        Anders Walter
# 3706           1               Lauren MacMullan          Paul Briggs
# 3707           3                  W.P. Kinsella  Phil Alden Robinson
# 3710           1              Johan Verschueren                  NaN
# 3711           1                 Albert Magnoli        William Blinn
#
# [1493 rows x 17 columns]

# %% [markdown]
# ### Now I will split and explore directors

# %%
oscars_df[['director1','director2','director3']] = oscars_df['director(s)'].apply(lambda x: pd.Series(x.split(',')))

# %%
oscars_df['director1'].count()
# Out:
# 1493

# %%
oscars_df['director2'].count()
# Out:
# 103

# %%
oscars_df['director2'].value_counts()
# Out:
#  'John Musker'         6
#  'Joel Coen'           6
#  'Ethan Coen'          3
#  'Alison Snowden'      3
#  'Chris Sanders'       2
#                       ..
#  'Lawrence R. Hott'    1
#  'Gary Goldman'        1
#  'Nick Park'           1
#  'Rob Minkoff'         1
#  'Valerie Faris'       1
# Name: director2, Length: 85, dtype: int64

# %%
oscars_df['director3'].count()
# Out:
# 13

# %% [markdown]
# #### With the count of directors being so low I will drop the column and rename directors 1 to director

# %%
oscars_df.drop(['director(s)','director2','director3'], axis=1,inplace=True)

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title  \
# 0   tt0091763                     Platoon
# 7   tt0082979                        Reds
# 19  tt0084434  An Officer and a Gentleman
# 25  tt0119360                    In & Out
# 26  tt0292542            Son of the Bride
#
#                                                 casts  \
# 0     'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7   'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19      'Richard Gere', 'Debra Winger', 'David Keith'
# 25        'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26  'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
#
#                                       genre(s) language    country  \
# 0                               'Drama', 'War'  English        USA
# 7   'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                          'Drama', 'Romance'  English        USA
# 25                         'Comedy', 'Romance'  English        USA
# 26                           'Comedy', 'Drama'  Spanish  Argentina
#
#    runtime (mins) mpaarating release date  metacritic score      budget  \
# 0              2h          R     6-Feb-87              92.0   6000000.0
# 7        3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19        2h 4min          R    13-Aug-82              75.0   7500000.0
# 25       1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26        2h 3min          R    16-Aug-01              68.0         NaN
#
#        distributionCompany                             Awards  Total_Noms  \
# 0           Orion Pictures    Best Actor in a Supporting Role           7
# 7       Paramount Pictures       Best Actor in a Leading Role          12
# 19      Paramount Pictures    Best Actor in a Supporting Role           6
# 25      Paramount Pictures  Best Actress in a Supporting Role           1
# 26  Sony Pictures Classics         Best Foreign Language Film           1
#
#                  writer1           writer2               director1
# 0           Oliver Stone               NaN          'Oliver Stone'
# 7          Warren Beatty  Trevor Griffiths         'Warren Beatty'
# 19   Douglas Day Stewart               NaN       'Taylor Hackford'
# 25          Paul Rudnick               NaN              'Frank Oz'
# 26  Juan José Campanella  Fernando Castets  'Juan José Campanella'

# %%
oscars_df.rename(columns={"director1": "director"},inplace=True)

# %%
remove_quotation('director')
# Out:
#          IMDBId                 movie title  \
# 0     tt0091763                     Platoon
# 7     tt0082979                        Reds
# 19    tt0084434  An Officer and a Gentleman
# 25    tt0119360                    In & Out
# 26    tt0292542            Son of the Bride
# ...         ...                         ...
# 3705  tt3346410                      Helium
# 3706  tt2980764                Get a Horse!
# 3707  tt0097351             Field of Dreams
# 3710  tt0281850                Fait d'hiver
# 3711  tt0087957                 Purple Rain
#
#                                                   casts  \
# 0       'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7     'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19        'Richard Gere', 'Debra Winger', 'David Keith'
# 25          'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26    'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
# ...                                                 ...
# 3705  'Casper Crump', 'Pelle Falk Krusbæk', 'Marijan...
# 3706  'Walt Disney', 'Marcellite Garner', 'Russi Tay...
# 3707  'Kevin Costner', 'James Earl Jones', 'Ray Liotta'
# 3710  'Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decle...
# 3711         'Prince', 'Apollonia Kotero', 'Morris Day'
#
#                                         genre(s) language    country  \
# 0                                 'Drama', 'War'  English        USA
# 7     'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                            'Drama', 'Romance'  English        USA
# 25                           'Comedy', 'Romance'  English        USA
# 26                             'Comedy', 'Drama'  Spanish  Argentina
# ...                                          ...      ...        ...
# 3705                  'Short', 'Drama', 'Family'   Danish    Denmark
# 3706    'Animation', 'Short', 'Comedy', 'Family'  English        USA
# 3707       'Drama', 'Family', 'Fantasy', 'Sport'  English        USA
# 3710       'Short', 'Comedy', 'Drama', 'Romance'    Dutch    Belgium
# 3711                 'Drama', 'Music', 'Romance'  English        USA
#
#      runtime (mins) mpaarating release date  metacritic score      budget  \
# 0                2h          R     6-Feb-87              92.0   6000000.0
# 7          3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19          2h 4min          R    13-Aug-82              75.0   7500000.0
# 25         1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26          2h 3min          R    16-Aug-01              68.0         NaN
# ...             ...        ...          ...               ...         ...
# 3705          23min  Not Rated    31-Jan-14               NaN         NaN
# 3706           6min          G    27-Nov-13               NaN         NaN
# 3707       1h 47min         PG     5-May-89              57.0         NaN
# 3710           7min       7min          NaN               NaN     80000.0
# 3711       1h 51min          R    27-Jul-84              55.0   7200000.0
#
#                       distributionCompany                             Awards  \
# 0                          Orion Pictures    Best Actor in a Supporting Role
# 7                      Paramount Pictures       Best Actor in a Leading Role
# 19                     Paramount Pictures    Best Actor in a Supporting Role
# 25                     Paramount Pictures  Best Actress in a Supporting Role
# 26                 Sony Pictures Classics         Best Foreign Language Film
# ...                                   ...                                ...
# 3705                                  NaN       Best Short Film, Live Action
# 3706  Walt Disney Studios Motion Pictures          Best Short Film, Animated
# 3707                   Universal Pictures         Best Music, Original Score
# 3710                                  NaN       Best Short Film, Live Action
# 3711                         Warner Bros.    Best Music, Original Song Score
#
#       Total_Noms                        writer1              writer2  \
# 0              7                   Oliver Stone                  NaN
# 7             12                  Warren Beatty     Trevor Griffiths
# 19             6            Douglas Day Stewart                  NaN
# 25             1                   Paul Rudnick                  NaN
# 26             1           Juan José Campanella     Fernando Castets
# ...          ...                            ...                  ...
# 3705           1  Christian Gamst Miller-Harris        Anders Walter
# 3706           1               Lauren MacMullan          Paul Briggs
# 3707           3                  W.P. Kinsella  Phil Alden Robinson
# 3710           1              Johan Verschueren                  NaN
# 3711           1                 Albert Magnoli        William Blinn
#
#                   director
# 0             Oliver Stone
# 7            Warren Beatty
# 19         Taylor Hackford
# 25                Frank Oz
# 26    Juan José Campanella
# ...                    ...
# 3705         Anders Walter
# 3706      Lauren MacMullan
# 3707   Phil Alden Robinson
# 3710           Dirk Beliën
# 3711        Albert Magnoli
#
# [1493 rows x 17 columns]

# %%
oscars_df['director']
# Out:
# 0               Oliver Stone
# 7              Warren Beatty
# 19           Taylor Hackford
# 25                  Frank Oz
# 26      Juan José Campanella
#                 ...
# 3705           Anders Walter
# 3706        Lauren MacMullan
# 3707     Phil Alden Robinson
# 3710             Dirk Beliën
# 3711          Albert Magnoli
# Name: director, Length: 1493, dtype: object

# %% [markdown]
# #### I will now explore split the cast and explore

# %%
oscars_df.casts.value_counts()
# Out:
# 'William Shatner', 'Leonard Nimoy', 'DeForest Kelley'          3
# 'Daniel Radcliffe', 'Emma Watson', 'Rupert Grint'              3
# 'Mark Hamill', 'Harrison Ford', 'Carrie Fisher'                2
# 'Ian McKellen', 'Martin Freeman', 'Richard Armitage'           2
# 'Shia LaBeouf', 'Megan Fox', 'Josh Duhamel'                    2
#                                                               ..
# 'Robert Downey Jr.', 'Geraldine Chaplin', 'Paul Rhys'          1
# 'Chris Pratt', 'Vin Diesel', 'Bradley Cooper'                  1
# 'John Lithgow', 'Melinda Dillon', 'Margaret Langrick'          1
# 'Keisha Castle-Hughes', 'Rawiri Paratene', 'Vicky Haughton'    1
# 'Derek Jacobi', 'Alec Guinness', 'Joan Greenwood'              1
# Name: casts, Length: 1481, dtype: int64

# %%
oscars_df[['Lead_Actor','Supporting_Actor_1','Supporting_Actor_2']] = oscars_df['casts'].apply(lambda x: pd.Series(x.split(',')))

# %%
oscars_df['Lead_Actor'].value_counts()
# Out:
# 'Tom Hanks'            19
# 'Meryl Streep'         16
# 'Tom Cruise'           12
# 'Leonardo DiCaprio'    12
# 'Brad Pitt'            11
#                        ..
# 'Janet Jackson'         1
# 'Haley Joel Osment'     1
# 'Rachel Mwanza'         1
# 'John Lone'             1
# 'Diego Abatantuono'     1
# Name: Lead_Actor, Length: 937, dtype: int64

# %%
oscars_df['Lead_Actor'].count()
# Out:
# 1493

# %%
oscars_df['Supporting_Actor_1'].value_counts()
# Out:
#  'Cate Blanchett'    8
#  'Meryl Streep'      8
#  'Kate Winslet'      7
#  'Matt Damon'        6
#  'Glenn Close'       6
#                     ..
#  'Steve Buscemi'     1
#  'Dennis Hopper'     1
#  'Bernard Jung'      1
#  'Adi Adouan'        1
#  'Liev Schreiber'    1
# Name: Supporting_Actor_1, Length: 1120, dtype: int64

# %%
oscars_df['Supporting_Actor_1'].count()
# Out:
# 1493

# %%
oscars_df['Supporting_Actor_2'].value_counts()
# Out:
#  'Scarlett Johansson'     5
#  'Robert De Niro'         5
#  'Willem Dafoe'           5
#  'Christopher Plummer'    5
#  'Ed Harris'              5
#                          ..
#  'Cher'                   1
#  'Julie Warner'           1
#  'Geraldine James'        1
#  'Saurabh Shukla'         1
#  'Michael Douglas'        1
# Name: Supporting_Actor_2, Length: 1247, dtype: int64

# %%
oscars_df['Supporting_Actor_2'].count()
# Out:
# 1471

# %%
remove_quotation('Lead_Actor')
remove_quotation('Supporting_Actor_1')
remove_quotation('Supporting_Actor_2')
# Out:
#          IMDBId                 movie title  \
# 0     tt0091763                     Platoon
# 7     tt0082979                        Reds
# 19    tt0084434  An Officer and a Gentleman
# 25    tt0119360                    In & Out
# 26    tt0292542            Son of the Bride
# ...         ...                         ...
# 3705  tt3346410                      Helium
# 3706  tt2980764                Get a Horse!
# 3707  tt0097351             Field of Dreams
# 3710  tt0281850                Fait d'hiver
# 3711  tt0087957                 Purple Rain
#
#                                                   casts  \
# 0       'Charlie Sheen', 'Tom Berenger', 'Willem Dafoe'
# 7     'Warren Beatty', 'Diane Keaton', 'Edward Herrm...
# 19        'Richard Gere', 'Debra Winger', 'David Keith'
# 25          'Kevin Kline', 'Joan Cusack', 'Tom Selleck'
# 26    'Ricardo Darín', 'Héctor Alterio', 'Norma Alea...
# ...                                                 ...
# 3705  'Casper Crump', 'Pelle Falk Krusbæk', 'Marijan...
# 3706  'Walt Disney', 'Marcellite Garner', 'Russi Tay...
# 3707  'Kevin Costner', 'James Earl Jones', 'Ray Liotta'
# 3710  'Tom Van Dyck', 'Ellen Van Cutsem', 'Aza Decle...
# 3711         'Prince', 'Apollonia Kotero', 'Morris Day'
#
#                                         genre(s) language    country  \
# 0                                 'Drama', 'War'  English        USA
# 7     'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                            'Drama', 'Romance'  English        USA
# 25                           'Comedy', 'Romance'  English        USA
# 26                             'Comedy', 'Drama'  Spanish  Argentina
# ...                                          ...      ...        ...
# 3705                  'Short', 'Drama', 'Family'   Danish    Denmark
# 3706    'Animation', 'Short', 'Comedy', 'Family'  English        USA
# 3707       'Drama', 'Family', 'Fantasy', 'Sport'  English        USA
# 3710       'Short', 'Comedy', 'Drama', 'Romance'    Dutch    Belgium
# 3711                 'Drama', 'Music', 'Romance'  English        USA
#
#      runtime (mins) mpaarating release date  metacritic score      budget  \
# 0                2h          R     6-Feb-87              92.0   6000000.0
# 7          3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19          2h 4min          R    13-Aug-82              75.0   7500000.0
# 25         1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26          2h 3min          R    16-Aug-01              68.0         NaN
# ...             ...        ...          ...               ...         ...
# 3705          23min  Not Rated    31-Jan-14               NaN         NaN
# 3706           6min          G    27-Nov-13               NaN         NaN
# 3707       1h 47min         PG     5-May-89              57.0         NaN
# 3710           7min       7min          NaN               NaN     80000.0
# 3711       1h 51min          R    27-Jul-84              55.0   7200000.0
#
#                       distributionCompany                             Awards  \
# 0                          Orion Pictures    Best Actor in a Supporting Role
# 7                      Paramount Pictures       Best Actor in a Leading Role
# 19                     Paramount Pictures    Best Actor in a Supporting Role
# 25                     Paramount Pictures  Best Actress in a Supporting Role
# 26                 Sony Pictures Classics         Best Foreign Language Film
# ...                                   ...                                ...
# 3705                                  NaN       Best Short Film, Live Action
# 3706  Walt Disney Studios Motion Pictures          Best Short Film, Animated
# 3707                   Universal Pictures         Best Music, Original Score
# 3710                                  NaN       Best Short Film, Live Action
# 3711                         Warner Bros.    Best Music, Original Song Score
#
#       Total_Noms                        writer1              writer2  \
# 0              7                   Oliver Stone                  NaN
# 7             12                  Warren Beatty     Trevor Griffiths
# 19             6            Douglas Day Stewart                  NaN
# 25             1                   Paul Rudnick                  NaN
# 26             1           Juan José Campanella     Fernando Castets
# ...          ...                            ...                  ...
# 3705           1  Christian Gamst Miller-Harris        Anders Walter
# 3706           1               Lauren MacMullan          Paul Briggs
# 3707           3                  W.P. Kinsella  Phil Alden Robinson
# 3710           1              Johan Verschueren                  NaN
# 3711           1                 Albert Magnoli        William Blinn
#
#                   director     Lead_Actor  Supporting_Actor_1  \
# 0             Oliver Stone  Charlie Sheen        Tom Berenger
# 7            Warren Beatty  Warren Beatty        Diane Keaton
# 19         Taylor Hackford   Richard Gere        Debra Winger
# 25                Frank Oz    Kevin Kline         Joan Cusack
# 26    Juan José Campanella  Ricardo Darín      Héctor Alterio
# ...                    ...            ...                 ...
# 3705         Anders Walter   Casper Crump  Pelle Falk Krusbæk
# 3706      Lauren MacMullan    Walt Disney   Marcellite Garner
# 3707   Phil Alden Robinson  Kevin Costner    James Earl Jones
# 3710           Dirk Beliën   Tom Van Dyck    Ellen Van Cutsem
# 3711        Albert Magnoli         Prince    Apollonia Kotero
#
#      Supporting_Actor_2
# 0          Willem Dafoe
# 7       Edward Herrmann
# 19          David Keith
# 25          Tom Selleck
# 26       Norma Aleandro
# ...                 ...
# 3705  Marijana Jankovic
# 3706       Russi Taylor
# 3707         Ray Liotta
# 3710       Aza Declercq
# 3711         Morris Day
#
# [1493 rows x 20 columns]

# %%
oscars_df.drop(['casts'], axis=1,inplace=True)

# %% [markdown]
# ### Explore genre

# %%
oscars_df['genre(s)'].unique()
# Out:
# array(["'Drama', 'War'", "'Biography', 'Drama', 'History', 'Romance'",
#        "'Drama', 'Romance'", "'Comedy', 'Romance'", "'Comedy', 'Drama'",
#        "'Drama', 'Music'", "'Drama'", "'Biography', 'Drama'",
#        "'Drama', 'Western'", "'Drama', 'Thriller'",
#        "'Drama', 'Mystery', 'Thriller'",
#        "'Biography', 'Drama', 'Romance'",
#        "'Biography', 'Drama', 'History'", "'Biography', 'Drama', 'Music'",
#        "'Documentary', 'Drama'",
#        "'Biography', 'Comedy', 'Drama', 'History'",
#        "'Action', 'Crime', 'Drama', 'Mystery', 'Thriller'",
#        "'Comedy', 'Drama', 'Romance'",
#        "'Crime', 'Drama', 'Mystery', 'Thriller'",
#        "'Biography', 'Drama', 'Sport'", "'Adventure', 'Drama', 'Mystery'",
#        "'Documentary'", "'Crime', 'Drama'",
#        "'Drama', 'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Biography', 'Drama', 'Music', 'War'",
#        "'Crime', 'Drama', 'Romance', 'Thriller'",
#        "'Drama', 'Mystery', 'Romance', 'Thriller'", "'Drama', 'History'",
#        "'Drama', 'Music', 'Romance'",
#        "'Biography', 'Drama', 'Thriller', 'War'",
#        "'Comedy', 'Drama', 'Music', 'Romance'",
#        "'Comedy', 'Drama', 'Mystery'",
#        "'Action', 'Drama', 'History', 'Thriller'",
#        "'Biography', 'Crime', 'Drama'", "'Adventure', 'Drama', 'Fantasy'",
#        "'Comedy', 'Drama', 'Thriller'", "'Comedy', 'War'",
#        "'Drama', 'Music', 'Musical'", "'Comedy', 'Drama', 'War'",
#        "'Adventure', 'Drama', 'War'",
#        "'Adventure', 'Biography', 'Crime', 'Drama', 'Thriller'",
#        "'Comedy', 'Crime', 'Drama', 'Mystery', 'Romance'",
#        "'Action', 'Comedy', 'Drama', 'Romance', 'Thriller'",
#        "'Drama', 'History', 'War'",
#        "'Action', 'Biography', 'Drama', 'History'",
#        "'Crime', 'Drama', 'History', 'War'",
#        "'Biography', 'Drama', 'History', 'Thriller', 'War'",
#        "'Drama', 'Romance', 'War'",
#        "'Drama', 'History', 'Thriller', 'War'", "'Romance', 'Drama'",
#        "'Crime', 'Drama', 'War'", "'Drama', 'Mystery', 'War'",
#        "'Drama', 'Thriller', 'War'", "'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Biography', 'Drama', 'Sport'",
#        "'Adventure', 'Biography', 'Drama'",
#        "'Action', 'Adventure', 'Fantasy', 'Romance'",
#        "'Adventure', 'Drama', 'Fantasy', 'Romance', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Drama', 'Sport'", "'Crime', 'Drama', 'Thriller'",
#        "'Drama', 'Fantasy', 'Thriller'", "'Drama', 'Mystery', 'Romance'",
#        "'Biography', 'Drama', 'War'",
#        "'Action', 'Adventure', 'Drama', 'Fantasy'",
#        "'Comedy', 'Crime', 'Drama', 'Thriller'",
#        "'Biography', 'Drama', 'Mystery'", "'Drama', 'Mystery'",
#        "'Crime', 'Drama', 'Thriller', 'War'",
#        "'Comedy', 'Crime', 'Drama', 'Romance'", "'Romance', 'Sci-Fi'",
#        "'Biography', 'Drama', 'History', 'War'",
#        "'Biography', 'Drama', 'Thriller'",
#        "'Drama', 'Musical', 'Romance'",
#        "'Action', 'Crime', 'Drama', 'Thriller'",
#        "'Comedy', 'Drama', 'Music', 'Musical', 'Romance'",
#        "'Biography', 'Drama', 'Romance', 'Thriller', 'War'",
#        "'Crime', 'Drama', 'Romance'", "'Comedy', 'Drama', 'Music'",
#        "'Comedy', 'Crime'", "'Comedy', 'Drama', 'Fantasy'",
#        "'Action', 'Adventure', 'Drama', 'History', 'War'",
#        "'Adventure', 'Drama', 'Western'",
#        "'Drama', 'History', 'Thriller'",
#        "'Biography', 'Drama', 'History', 'Thriller'",
#        "'Adventure', 'Drama', 'History'",
#        "'Biography', 'Crime', 'Drama', 'History', 'Mystery', 'Thriller'",
#        "'Drama', 'Fantasy', 'Mystery', 'Romance'", "'Comedy'",
#        "'Action', 'Drama', 'War'",
#        "'Comedy', 'Drama', 'History', 'Romance'",
#        "'Comedy', 'Fantasy', 'Romance'", "'Action', 'Adventure'",
#        "'Comedy', 'Drama', 'Sci-Fi'", "'Biography', 'Comedy', 'Drama'",
#        "'Comedy', 'Romance', 'Drama'",
#        "'Biography', 'Comedy', 'Drama', 'Music'",
#        "'Drama', 'Horror', 'Musical', 'Thriller'",
#        "'Drama', 'Family', 'Fantasy', 'Mystery'",
#        "'Crime', 'Drama', 'Mystery', 'Thriller', 'Western'",
#        "'Action', 'Adventure', 'Sci-Fi', 'Thriller'",
#        "'Comedy', 'Crime', 'Drama'",
#        "'Adventure', 'Drama', 'Musical', 'Sport'",
#        "'Biography', 'Crime', 'Drama', 'History', 'Western'",
#        "'Biography', 'Crime', 'Drama', 'Romance'",
#        "'Comedy', 'Drama', 'Fantasy', 'Romance'",
#        "'Crime', 'Drama', 'Mystery'",
#        "'Crime', 'Drama', 'History', 'Mystery', 'Thriller'",
#        "'Biography', 'Drama', 'Music', 'Romance'",
#        "'Biography', 'Drama', 'Family'",
#        "'Drama', 'History', 'Mystery', 'Thriller'", "'Drama', 'Sport'",
#        "'Drama', 'Romance', 'Thriller', 'War'",
#        "'Drama', 'Family', 'Sport'", "'Action', 'Adventure', 'Fantasy'",
#        "'Documentary', 'Animation', 'Biography', 'Drama', 'History', 'Mystery', 'War'",
#        "'Drama', 'Fantasy'", "'Biography', 'Comedy', 'Drama', 'Romance'",
#        "'Adventure', 'Biography', 'Drama', 'History'",
#        "'Adventure', 'Drama'", "'Adventure', 'Drama', 'Thriller', 'War'",
#        "'Family', 'Sci-Fi'", "'Drama', 'Romance', 'Thriller'",
#        "'Adventure', 'Comedy', 'Crime'",
#        "'Action', 'Comedy', 'Crime', 'Music', 'Romance', 'Thriller'",
#        "'Comedy', 'Drama', 'Family', 'History'",
#        "'Comedy', 'Drama', 'Romance', 'War'", "'Drama', 'Musical'",
#        "'Action', 'Biography', 'Drama', 'War'",
#        "'Adventure', 'Drama', 'Romance'",
#        "'Action', 'Biography', 'Drama', 'History', 'War'",
#        "'Drama', 'Family', 'Romance'",
#        "'Comedy', 'Drama', 'Romance', 'Sport'",
#        "'Crime', 'Drama', 'Fantasy', 'Mystery'",
#        "'Drama', 'History', 'Romance', 'War'",
#        "'Drama', 'History', 'Music', 'Romance'",
#        "'Biography', 'Drama', 'History', 'Romance', 'Sport'",
#        "'Drama', 'Sci-Fi', 'Thriller'", "'Action', 'Adventure', 'Drama'",
#        "'Drama', 'Romance', 'Sci-Fi'",
#        "'Biography', 'Comedy', 'Crime', 'Drama'",
#        "'Drama', 'History', 'Music', 'Romance', 'War'",
#        "'Action', 'Biography', 'Crime', 'Drama', 'History', 'Thriller'",
#        "'Biography', 'Comedy', 'Drama', 'War'",
#        "'Biography', 'Drama', 'History', 'Sport'",
#        "'Crime', 'Drama', 'Romance', 'Thriller', 'War'",
#        "'Drama', 'Mystery', 'Romance', 'War'",
#        "'Adventure', 'Drama', 'Sci-Fi'",
#        "'Action', 'Drama', 'Family', 'Sport'",
#        "'Action', 'Adventure', 'Drama', 'History', 'Western'",
#        "'Adventure', 'Drama', 'Thriller'",
#        "'Comedy', 'Drama', 'History', 'War'",
#        "'Comedy', 'Crime', 'Thriller'", "'Action', 'Comedy', 'War'",
#        "'Drama', 'History', 'Musical', 'Romance', 'War'",
#        "'Action', 'Adventure', 'Fantasy', 'Sci-Fi'",
#        "'Crime', 'Drama', 'Music', 'Romance'",
#        "'Drama', 'Fantasy', 'Romance'", "'Comedy', 'Drama', 'Family'",
#        "'Adventure', 'Comedy', 'Drama'", "'Comedy', 'Western'",
#        "'Drama', 'History', 'Romance'",
#        "'Biography', 'Crime', 'Drama', 'History'",
#        "'Drama', 'Fantasy', 'War'", "'Comedy', 'Music', 'Romance'",
#        "'Action', 'Adventure', 'Drama', 'Thriller'",
#        "'Adventure', 'Comedy', 'Drama', 'Music'",
#        "'Crime', 'Drama', 'Music'", "'Drama', 'Comedy'",
#        "'Crime', 'Mystery', 'Thriller'",
#        "'Biography', 'Drama', 'Music', 'Musical'",
#        "'Biography', 'Crime', 'Drama', 'Mystery', 'Thriller'",
#        "'History', 'Musical'", "'Biography', 'Comedy', 'Drama', 'Sport'",
#        "'Drama', 'Family'", "'Action', 'Adventure', 'History'",
#        "'Adventure', 'Drama', 'History', 'Romance', 'War'",
#        "'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Musical'",
#        "'Biography', 'Drama', 'History', 'Music'",
#        "'Biography', 'Drama', 'History', 'Mystery', 'Thriller'",
#        "'Adventure', 'Family', 'Sport'",
#        "'Comedy', 'Drama', 'Music', 'War'", "'Comedy', 'Musical'",
#        "'Biography', 'Crime', 'Drama', 'History', 'Thriller', 'War'",
#        "'Action', 'Biography', 'Drama', 'History', 'Romance', 'War'",
#        "'Crime', 'Mystery', 'Romance', 'Thriller'",
#        "'Biography', 'Crime', 'Drama', 'Thriller'",
#        "'Adventure', 'Drama', 'History', 'Romance'",
#        "'Action', 'Comedy', 'Crime', 'Drama'",
#        "'Adventure', 'Crime', 'Drama'", "'Comedy', 'Crime', 'Musical'",
#        "'Action', 'Crime', 'Drama', 'Thriller', 'Western'",
#        "'Horror', 'Mystery', 'Thriller'", "'Crime', 'Thriller'",
#        "'Comedy', 'Crime', 'Romance'", "'Drama', 'Sport', 'Thriller'",
#        "'Crime', 'Drama', 'Mystery', 'War'",
#        "'Action', 'Drama', 'History', 'Thriller', 'War'",
#        "'Drama', 'Fantasy', 'Romance', 'Thriller'", "'Drama', 'Horror'",
#        "'Animation', 'Adventure', 'Drama', 'Family', 'Fantasy'",
#        "'Short', 'Comedy', 'Drama', 'Family'", "'Mystery', 'Thriller'",
#        "'Crime', 'Drama', 'Musical'",
#        "'Short', 'Biography', 'Drama', 'Family', 'Romance'",
#        "'Crime', 'Drama', 'Fantasy', 'Romance', 'Thriller'",
#        "'Short', 'Comedy'", "'Animation', 'Comedy', 'Family', 'Sport'",
#        "'Short', 'Drama'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Romance'",
#        "'Adventure', 'Family'", "'Short', 'Crime', 'Drama'", "'Short'",
#        "'Adventure', 'Drama', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Adventure', 'Drama', 'Sci-Fi'",
#        "'Action', 'Adventure', 'Drama', 'Romance', 'War'",
#        "'Action', 'Sci-Fi'",
#        "'Animation', 'Action', 'Adventure', 'Family', 'Sci-Fi'",
#        "'Drama', 'Sci-Fi'", "'Documentary', 'Biography', 'Music'",
#        "'Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller'",
#        "'Documentary', 'Short', 'Drama'",
#        "'Drama', 'Mystery', 'Romance', 'Thriller', 'War'",
#        "'Short', 'Comedy', 'Drama'", "'Drama', 'History', 'Western'",
#        "'Animation', 'Short', 'Biography'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'",
#        "'Drama', 'Romance', 'Music'", "'Drama', 'History', 'Horror'",
#        "'Comedy', 'Short'",
#        "'Biography', 'Crime', 'Drama', 'History', 'Mystery', 'Romance'",
#        "'Documentary', 'Short', 'Biography'",
#        "'Animation', 'Adventure', 'Family', 'Sci-Fi'",
#        "'Documentary', 'Short'", "'Documentary', 'News'",
#        "'Action', 'Adventure', 'Comedy', 'Thriller', 'Western'",
#        "'Action', 'Adventure', 'Comedy', 'Romance', 'Thriller', 'Western'",
#        "'Action', 'Adventure', 'Comedy', 'Sci-Fi'",
#        "'Animation', 'Comedy', 'Drama', 'Family'",
#        "'Documentary', 'Music'", "'Drama', 'Short'",
#        "'Animation', 'Adventure', 'Comedy', 'Crime', 'Family'",
#        "'Adventure', 'Family', 'Fantasy', 'Mystery'",
#        "'Adventure', 'Comedy', 'Family', 'Fantasy'", "'Musical', 'Short'",
#        "'Action', 'Drama', 'Sci-Fi', 'Thriller'",
#        "'Animation', 'Action', 'Adventure', 'Family', 'Mystery'",
#        "'Action', 'Adventure', 'Sci-Fi'",
#        "'Animation', 'Short', 'Comedy', 'Fantasy'",
#        "'Adventure', 'Family', 'Fantasy'",
#        "'Adventure', 'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Animation', 'Comedy', 'Fantasy', 'Musical'",
#        "'Drama', 'Fantasy', 'History', 'Music', 'Musical', 'Romance'",
#        "'Adventure', 'Comedy', 'Romance'",
#        "'Action', 'Comedy', 'Thriller'", "'Action', 'Comedy', 'Fantasy'",
#        "'Animation', 'Comedy', 'Family', 'Fantasy', 'Musical', 'Romance'",
#        "'Comedy', 'Horror'", "'Short', 'Drama', 'Family', 'Thriller'",
#        "'Action', 'Family', 'Romance', 'Sport'", "'Documentary', 'War'",
#        "'Documentary', 'Short', 'Biography', 'Drama', 'Music'",
#        "'Horror', 'Thriller'", "'Animation', 'Short'",
#        "'Action', 'Adventure', 'Comedy', 'Romance'",
#        "'Action', 'Biography', 'Drama', 'Romance', 'War'",
#        "'Animation', 'Adventure', 'Drama', 'Family', 'Fantasy', 'Musical', 'Mystery', 'Romance'",
#        "'Drama', 'Romance', 'Short'",
#        "'Animation', 'Biography', 'Crime', 'Drama', 'Family', 'Mystery'",
#        "'Short', 'Drama', 'Music', 'Romance'",
#        "'Action', 'Adventure', 'Thriller'",
#        "'Animation', 'Short', 'Drama', 'Western'",
#        "'Animation', 'Short', 'Comedy', 'Family', 'Fantasy'",
#        "'Action', 'War'",
#        "'Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical'",
#        "'Comedy', 'Fantasy'",
#        "'Animation', 'Adventure', 'Comedy', 'Family'",
#        "'Animation', 'Short', 'Action', 'Comedy', 'Crime'",
#        "'Animation', 'Drama', 'Family', 'War'",
#        "'Action', 'Comedy', 'Crime', 'Thriller'",
#        "'Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'",
#        "'Documentary', 'Biography', 'Sport'",
#        "'Action', 'Crime', 'Sci-Fi', 'Thriller', 'Western'",
#        "'Animation', 'Short', 'Action', 'Comedy', 'Fantasy'",
#        "'Animation', 'Short', 'Comedy', 'Crime', 'Family', 'Sci-Fi'",
#        "'Animation', 'Drama', 'Family', 'Mystery'",
#        "'Comedy', 'Romance', 'Sci-Fi'",
#        "'Adventure', 'Mystery', 'Sci-Fi'",
#        "'Animation', 'Adventure', 'Family', 'Fantasy', 'Music', 'Mystery'",
#        "'Documentary', 'Short', 'Drama', 'Family'",
#        "'Documentary', 'Biography', 'War'",
#        "'Drama', 'Romance', 'War', 'Western'", "'Documentary', 'Sport'",
#        "'Documentary', 'Biography', 'Comedy'",
#        "'Short', 'Drama', 'History'",
#        "'Action', 'Drama', 'Romance', 'Thriller', 'War'",
#        "'Action', 'Drama', 'History', 'War'",
#        "'Animation', 'Short', 'Drama', 'Family'",
#        "'Animation', 'Family', 'Fantasy', 'Musical'",
#        "'Animation', 'Adventure', 'Family', 'Fantasy'",
#        "'Action', 'Thriller'",
#        "'Animation', 'Drama', 'Family', 'Musical', 'Romance'",
#        "'Adventure', 'Fantasy'", "'Short', 'Romance', 'Comedy'",
#        "'Animation', 'Adventure', 'Drama', 'Family', 'Western'",
#        "'Short', 'Comedy', 'Drama', 'Sport'",
#        "'Drama', 'Horror', 'Sci-Fi'", "'Animation', 'Short', 'Drama'",
#        "'Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller'",
#        "'Drama', 'Romance', 'Sport'", "'Action', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Crime', 'Thriller'",
#        "'Short', 'Comedy', 'Adventure', 'Romance'",
#        "'Biography', 'Drama', 'Fantasy', 'Romance'",
#        "'Family', 'Comedy', 'Animation', 'Short'",
#        "'Animation', 'Biography', 'Drama', 'Family', 'History', 'War'",
#        "'Documentary', 'History', 'War'",
#        "'Animation', 'Family', 'Fantasy'",
#        "'Animation', 'Short', 'Comedy'", "'Short', 'Comedy', 'Romance'",
#        "'Action', 'Adventure', 'Family', 'Fantasy', 'Thriller'",
#        "'Action', 'Mystery', 'Thriller'",
#        "'Adventure', 'Family', 'Fantasy', 'Romance'",
#        "'Drama', 'Horror', 'Romance', 'Sci-Fi'", "'Horror'",
#        "'Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi', 'Thriller'",
#        "'Short', 'Comedy', 'Drama', 'Fantasy'", "'Short', 'Drama', 'War'",
#        "'Comedy', 'Drama', 'Music', 'Mystery'",
#        "'Animation', 'Short', 'Adventure', 'Mystery', 'Sci-Fi'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi'",
#        "'Action', 'Drama', 'History', 'Romance'",
#        "'Adventure', 'Comedy', 'Fantasy', 'Mystery'",
#        "'Animation', 'Drama', 'Family', 'Fantasy', 'Thriller'",
#        "'Comedy', 'Drama', 'Romance', 'Western'",
#        "'Animation', 'Comedy', 'Family', 'Fantasy', 'Mystery'",
#        "'Adventure', 'Drama', 'Fantasy', 'Romance'",
#        "'Drama', 'Family', 'Fantasy'", "'Short', 'Drama', 'Music'",
#        "'Animation', 'Action', 'Adventure', 'Family', 'Fantasy'",
#        "'Short', 'Adventure', 'Drama'", "'Documentary', 'Biography'",
#        "'Short', 'Drama', 'Thriller', 'War'",
#        "'Animation', 'Adventure', 'Comedy', 'Crime', 'Drama', 'Family'",
#        "'Horror', 'Sci-Fi', 'Thriller'", "'Documentary', 'Crime'",
#        "'Short', 'Drama', 'Family', 'War'",
#        "'Action', 'Crime', 'Drama', 'Romance', 'Western'",
#        "'Animation', 'Adventure', 'Family', 'Fantasy', 'Mystery'",
#        "'Documentary', 'Biography', 'Crime', 'History'",
#        "'Animation', 'Adventure', 'Drama', 'Family', 'Musical'",
#        "'Documentary', 'Biography', 'History'",
#        "'Animation', 'Short', 'Action', 'Family', 'Fantasy', 'Thriller'",
#        "'Adventure', 'Family', 'Drama'",
#        "'Documentary', 'Biography', 'News'", "'Short', 'Family'",
#        "'Action', 'Adventure', 'Comedy', 'Crime', 'Romance', 'Thriller'",
#        "'Animation', 'Short', 'Comedy', 'Drama', 'Fantasy', 'Sci-Fi'",
#        "'Action', 'Crime', 'Drama', 'Western'", "'Comedy', 'Music'",
#        "'Adventure', 'Comedy', 'Drama', 'Romance', 'War', 'Western'",
#        "'Short', 'Drama', 'Romance'", "'Adventure', 'Comedy', 'Sci-Fi'",
#        "'Animation', 'Drama', 'Fantasy', 'Romance'",
#        "'Action', 'Crime', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Crime', 'Fantasy'",
#        "'Action', 'Adventure', 'Family', 'Fantasy', 'Romance'",
#        "'Short', 'Biography', 'Drama', 'War'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Music', 'Musical', 'Romance'",
#        "'Short', 'Drama', 'History', 'War'", "'Short', 'Music'",
#        "'Documentary', 'Drama', 'History', 'War'",
#        "'Action', 'Adventure', 'Drama', 'Romance'",
#        "'Animation', 'Short', 'Comedy', 'Drama'",
#        "'Adventure', 'Fantasy', 'Mystery', 'Thriller'",
#        "'Comedy', 'Family', 'Fantasy'",
#        "'Animation', 'Comedy', 'Family', 'Horror', 'Sci-Fi'",
#        "'Adventure', 'Comedy', 'Family'",
#        "'Animation', 'Comedy', 'Fantasy', 'Short'",
#        "'Drama', 'Horror', 'Sci-Fi', 'Thriller'", "'Action', 'Drama'",
#        "'Biography', 'Drama', 'Romance', 'Sport'",
#        "'Action', 'Adventure', 'Family', 'Fantasy', 'Mystery'",
#        "'Fantasy', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller'",
#        "'Animation', 'Action', 'Adventure', 'Comedy', 'Family'",
#        "'Documentary', 'History'",
#        "'Animation', 'Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Sci-Fi'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Horror', 'Mystery', 'Sci-Fi'",
#        "'Animation', 'Crime', 'Drama', 'Music', 'Romance'",
#        "'Documentary', 'Biography', 'Crime', 'Drama', 'History', 'News', 'Thriller'",
#        "'Family', 'Fantasy', 'Musical', 'Romance'",
#        "'Action', 'Crime', 'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Documentary', 'Drama', 'Family'",
#        "'Comedy', 'Drama', 'Romance', 'Sci-Fi', 'Thriller'",
#        "'Biography', 'Drama', 'Musical'",
#        "'Animation', 'Action', 'Adventure', 'Family'",
#        "'Comedy', 'Fantasy', 'Horror'", "'Comedy', 'Sci-Fi'",
#        "'Animation', 'Short', 'Comedy', 'Drama', 'Family', 'Romance'",
#        "'Animation', 'Adventure', 'Family', 'Fantasy', 'Musical', 'War'",
#        "'Documentary', 'Animation', 'Short', 'Music', 'War'",
#        "'Action', 'Horror', 'Sci-Fi'",
#        "'Adventure', 'Drama', 'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Fantasy'",
#        "'Animation', 'Adventure', 'Comedy', 'Crime', 'Family', 'Mystery'",
#        "'Action', 'Western'",
#        "'Adventure', 'Family', 'Fantasy', 'Horror', 'Mystery'",
#        "'Adventure', 'Comedy', 'Family', 'Musical'",
#        "'Animation', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Sci-Fi'",
#        "'Action', 'Drama', 'History', 'Romance', 'War'",
#        "'Action', 'Adventure', 'Mystery'",
#        "'Animation', 'Comedy', 'Short', 'Drama'",
#        "'Animation', 'Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy', 'Mystery'",
#        "'Animation', 'Adventure', 'Family'",
#        "'Animation', 'Short', 'Musical'",
#        "'Animation', 'Short', 'Comedy', 'Fantasy', 'Sci-Fi'",
#        "'Comedy', 'Horror', 'Musical', 'Romance', 'Sci-Fi'",
#        "'Comedy', 'Drama', 'Family', 'Fantasy'",
#        "'Animation', 'Short', 'Drama', 'Family', 'Fantasy'",
#        "'Documentary', 'Short', 'History'",
#        "'Animation', 'Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy'",
#        "'Drama', 'History', 'Sport'",
#        "'Action', 'Biography', 'Drama', 'Sport', 'War'",
#        "'Short', 'Comedy', 'Musical', 'Romance'",
#        "'Action', 'Adventure', 'Drama', 'Fantasy', 'Romance'",
#        "'Comedy', 'Crime', 'Drama', 'Romance', 'Thriller'",
#        "'Drama', 'Romance', 'Sci-Fi', 'Thriller'",
#        "'Adventure', 'Drama', 'Family', 'Fantasy'",
#        "'Documentary', 'Comedy', 'Drama', 'Family', 'Fantasy', 'Romance'",
#        "'Short', 'Comedy', 'Crime', 'Drama'", "'Animation', 'Comedy'",
#        "'Documentary', 'Family'",
#        "'Action', 'Crime', 'Drama', 'Sci-Fi', 'Thriller'",
#        "'Animation', 'Comedy', 'Romance', 'Short'",
#        "'Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thriller'",
#        "'Action', 'Drama', 'Music', 'Romance', 'Thriller'",
#        "'Animation', 'Adventure', 'Comedy', 'Drama', 'Family', 'Musical'",
#        "'Adventure', 'Sci-Fi', 'Thriller'", "'Drama', 'Family', 'Short'",
#        "'Documentary', 'Crime', 'Drama'",
#        "'Animation', 'Short', 'Comedy', 'Family'",
#        "'Comedy', 'Drama', 'Musical', 'Mystery', 'Romance', 'Western'",
#        "'Drama', 'Family', 'Fantasy', 'Romance'",
#        "'Animation', 'Short', 'Comedy', 'Family', 'Romance'",
#        "'Animation', 'Adventure', 'Family', 'Fantasy', 'Musical'",
#        "'Short', 'Fantasy'", "'Adventure', 'Comedy'",
#        "'Animation', 'Family', 'Fantasy', 'Musical', 'Romance'",
#        "'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Romance'",
#        "'Animation', 'Adventure', 'Drama', 'Family', 'Fantasy', 'Musical'",
#        "'Action', 'Adventure', 'Comedy', 'Crime'",
#        "'Documentary', 'Short', 'Family'",
#        "'Drama', 'Romance', 'Western'",
#        "'Animation', 'Short', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'",
#        "'Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical'",
#        "'Animation', 'Adventure', 'Comedy', 'Drama', 'Family'",
#        "'Fantasy', 'Horror', 'Mystery'",
#        "'Drama', 'Musical', 'Romance', 'Thriller'",
#        "'Short', 'Drama', 'Family'",
#        "'Drama', 'Family', 'Fantasy', 'Sport'",
#        "'Short', 'Comedy', 'Drama', 'Romance'"], dtype=object)

# %%
oscars_df[['genre']] = oscars_df['genre(s)'].apply(lambda x: pd.Series(''.join(x.split(',')[0:2])))

# %%
oscars_df[['main_genre']] = oscars_df['genre(s)'].apply(lambda x: pd.Series(''.join(x.split(',')[0:1])))

# %%
oscars_df[['subgenre']] = oscars_df['genre(s)'].apply(lambda x: pd.Series(''.join(x.split(',')[1:2])))

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title  \
# 0   tt0091763                     Platoon
# 7   tt0082979                        Reds
# 19  tt0084434  An Officer and a Gentleman
# 25  tt0119360                    In & Out
# 26  tt0292542            Son of the Bride
#
#                                       genre(s) language    country  \
# 0                               'Drama', 'War'  English        USA
# 7   'Biography', 'Drama', 'History', 'Romance'  English        USA
# 19                          'Drama', 'Romance'  English        USA
# 25                         'Comedy', 'Romance'  English        USA
# 26                           'Comedy', 'Drama'  Spanish  Argentina
#
#    runtime (mins) mpaarating release date  metacritic score      budget  ...  \
# 0              2h          R     6-Feb-87              92.0   6000000.0  ...
# 7        3h 15min         PG    25-Dec-81              76.0  32000000.0  ...
# 19        2h 4min          R    13-Aug-82              75.0   7500000.0  ...
# 25       1h 30min      PG-13    19-Sep-97              70.0  35000000.0  ...
# 26        2h 3min          R    16-Aug-01              68.0         NaN  ...
#
#    Total_Noms               writer1           writer2              director  \
# 0           7          Oliver Stone               NaN          Oliver Stone
# 7          12         Warren Beatty  Trevor Griffiths         Warren Beatty
# 19          6   Douglas Day Stewart               NaN       Taylor Hackford
# 25          1          Paul Rudnick               NaN              Frank Oz
# 26          1  Juan José Campanella  Fernando Castets  Juan José Campanella
#
#        Lead_Actor Supporting_Actor_1 Supporting_Actor_2                genre  \
# 0   Charlie Sheen       Tom Berenger       Willem Dafoe        'Drama' 'War'
# 7   Warren Beatty       Diane Keaton    Edward Herrmann  'Biography' 'Drama'
# 19   Richard Gere       Debra Winger        David Keith    'Drama' 'Romance'
# 25    Kevin Kline        Joan Cusack        Tom Selleck   'Comedy' 'Romance'
# 26  Ricardo Darín     Héctor Alterio     Norma Aleandro     'Comedy' 'Drama'
#
#      main_genre    subgenre
# 0       'Drama'       'War'
# 7   'Biography'     'Drama'
# 19      'Drama'   'Romance'
# 25     'Comedy'   'Romance'
# 26     'Comedy'     'Drama'
#
# [5 rows x 22 columns]

# %%
oscars_df['genre'].value_counts()
# Out:
# 'Comedy' 'Drama'       169
# 'Biography' 'Drama'    142
# 'Drama'                126
# 'Drama' 'Romance'      103
# 'Crime' 'Drama'         92
#                       ...
# 'History' 'Musical'      1
# 'Action' 'Western'       1
# 'Action' 'Horror'        1
# 'Fantasy' 'Mystery'      1
# 'Short' 'Romance'        1
# Name: genre, Length: 101, dtype: int64

# %%
oscars_df['genre'].count()
# Out:
# 1493

# %%
#oscars_df['subgenre1'].count()

# %%
oscars_df.drop(['genre(s)'], axis=1,inplace=True)

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title language    country runtime (mins)  \
# 0   tt0091763                     Platoon  English        USA             2h
# 7   tt0082979                        Reds  English        USA       3h 15min
# 19  tt0084434  An Officer and a Gentleman  English        USA        2h 4min
# 25  tt0119360                    In & Out  English        USA       1h 30min
# 26  tt0292542            Son of the Bride  Spanish  Argentina        2h 3min
#
#    mpaarating release date  metacritic score      budget  \
# 0           R     6-Feb-87              92.0   6000000.0
# 7          PG    25-Dec-81              76.0  32000000.0
# 19          R    13-Aug-82              75.0   7500000.0
# 25      PG-13    19-Sep-97              70.0  35000000.0
# 26          R    16-Aug-01              68.0         NaN
#
#        distributionCompany  ... Total_Noms               writer1  \
# 0           Orion Pictures  ...          7          Oliver Stone
# 7       Paramount Pictures  ...         12         Warren Beatty
# 19      Paramount Pictures  ...          6   Douglas Day Stewart
# 25      Paramount Pictures  ...          1          Paul Rudnick
# 26  Sony Pictures Classics  ...          1  Juan José Campanella
#
#              writer2              director     Lead_Actor Supporting_Actor_1  \
# 0                NaN          Oliver Stone  Charlie Sheen       Tom Berenger
# 7   Trevor Griffiths         Warren Beatty  Warren Beatty       Diane Keaton
# 19               NaN       Taylor Hackford   Richard Gere       Debra Winger
# 25               NaN              Frank Oz    Kevin Kline        Joan Cusack
# 26  Fernando Castets  Juan José Campanella  Ricardo Darín     Héctor Alterio
#
#    Supporting_Actor_2                genre   main_genre    subgenre
# 0        Willem Dafoe        'Drama' 'War'      'Drama'       'War'
# 7     Edward Herrmann  'Biography' 'Drama'  'Biography'     'Drama'
# 19        David Keith    'Drama' 'Romance'      'Drama'   'Romance'
# 25        Tom Selleck   'Comedy' 'Romance'     'Comedy'   'Romance'
# 26     Norma Aleandro     'Comedy' 'Drama'     'Comedy'     'Drama'
#
# [5 rows x 21 columns]

# %%
remove_quotation('genre')
remove_quotation('main_genre')
remove_quotation('subgenre')
# Out:
#          IMDBId                 movie title language    country  \
# 0     tt0091763                     Platoon  English        USA
# 7     tt0082979                        Reds  English        USA
# 19    tt0084434  An Officer and a Gentleman  English        USA
# 25    tt0119360                    In & Out  English        USA
# 26    tt0292542            Son of the Bride  Spanish  Argentina
# ...         ...                         ...      ...        ...
# 3705  tt3346410                      Helium   Danish    Denmark
# 3706  tt2980764                Get a Horse!  English        USA
# 3707  tt0097351             Field of Dreams  English        USA
# 3710  tt0281850                Fait d'hiver    Dutch    Belgium
# 3711  tt0087957                 Purple Rain  English        USA
#
#      runtime (mins) mpaarating release date  metacritic score      budget  \
# 0                2h          R     6-Feb-87              92.0   6000000.0
# 7          3h 15min         PG    25-Dec-81              76.0  32000000.0
# 19          2h 4min          R    13-Aug-82              75.0   7500000.0
# 25         1h 30min      PG-13    19-Sep-97              70.0  35000000.0
# 26          2h 3min          R    16-Aug-01              68.0         NaN
# ...             ...        ...          ...               ...         ...
# 3705          23min  Not Rated    31-Jan-14               NaN         NaN
# 3706           6min          G    27-Nov-13               NaN         NaN
# 3707       1h 47min         PG     5-May-89              57.0         NaN
# 3710           7min       7min          NaN               NaN     80000.0
# 3711       1h 51min          R    27-Jul-84              55.0   7200000.0
#
#                       distributionCompany  ... Total_Noms  \
# 0                          Orion Pictures  ...          7
# 7                      Paramount Pictures  ...         12
# 19                     Paramount Pictures  ...          6
# 25                     Paramount Pictures  ...          1
# 26                 Sony Pictures Classics  ...          1
# ...                                   ...  ...        ...
# 3705                                  NaN  ...          1
# 3706  Walt Disney Studios Motion Pictures  ...          1
# 3707                   Universal Pictures  ...          3
# 3710                                  NaN  ...          1
# 3711                         Warner Bros.  ...          1
#
#                             writer1              writer2  \
# 0                      Oliver Stone                  NaN
# 7                     Warren Beatty     Trevor Griffiths
# 19              Douglas Day Stewart                  NaN
# 25                     Paul Rudnick                  NaN
# 26             Juan José Campanella     Fernando Castets
# ...                             ...                  ...
# 3705  Christian Gamst Miller-Harris        Anders Walter
# 3706               Lauren MacMullan          Paul Briggs
# 3707                  W.P. Kinsella  Phil Alden Robinson
# 3710              Johan Verschueren                  NaN
# 3711                 Albert Magnoli        William Blinn
#
#                   director     Lead_Actor  Supporting_Actor_1  \
# 0             Oliver Stone  Charlie Sheen        Tom Berenger
# 7            Warren Beatty  Warren Beatty        Diane Keaton
# 19         Taylor Hackford   Richard Gere        Debra Winger
# 25                Frank Oz    Kevin Kline         Joan Cusack
# 26    Juan José Campanella  Ricardo Darín      Héctor Alterio
# ...                    ...            ...                 ...
# 3705         Anders Walter   Casper Crump  Pelle Falk Krusbæk
# 3706      Lauren MacMullan    Walt Disney   Marcellite Garner
# 3707   Phil Alden Robinson  Kevin Costner    James Earl Jones
# 3710           Dirk Beliën   Tom Van Dyck    Ellen Van Cutsem
# 3711        Albert Magnoli         Prince    Apollonia Kotero
#
#      Supporting_Actor_2              genre main_genre subgenre
# 0          Willem Dafoe        Drama' 'War      Drama      War
# 7       Edward Herrmann  Biography' 'Drama  Biography    Drama
# 19          David Keith    Drama' 'Romance      Drama  Romance
# 25          Tom Selleck   Comedy' 'Romance     Comedy  Romance
# 26       Norma Aleandro     Comedy' 'Drama     Comedy    Drama
# ...                 ...                ...        ...      ...
# 3705  Marijana Jankovic      Short' 'Drama      Short    Drama
# 3706       Russi Taylor  Animation' 'Short  Animation    Short
# 3707         Ray Liotta     Drama' 'Family      Drama   Family
# 3710       Aza Declercq     Short' 'Comedy      Short   Comedy
# 3711         Morris Day      Drama' 'Music      Drama    Music
#
# [1493 rows x 21 columns]

# %% [markdown]
# ## Explore Runtime

# %%
oscars_df['runtime (mins)'].value_counts()
# Out:
# 1h 45min    36
# 1h 58min    33
# 2h          32
# 1h 55min    30
# 1h 40min    30
#             ..
# 5min         1
# 3h 11min     1
# 1h 18min     1
# 5h 57min     1
# 3h 14min     1
# Name: runtime (mins), Length: 164, dtype: int64

# %%
import datetime
def runtime_to_minutes(runtimestring):
    if 'h' in runtimestring:
        runtime = runtimestring.split('h')
        minutes = int(runtime[0])*60 
        if 'min' in runtime[1]:
            mins = runtime[1].split('min')
            minutes += int(mins[0])
    else:
        runtime_minutes = runtimestring.split('min')
        minutes = int(runtime_minutes[0])
        
    return minutes

# %%
oscars_df['runtime (mins)'] = oscars_df['runtime (mins)'].apply(runtime_to_minutes)

# %%
oscars_df['runtime (mins)'].value_counts()
# Out:
# 105    36
# 118    33
# 120    32
# 115    30
# 100    30
#        ..
# 54      1
# 52      1
# 41      1
# 38      1
# 4       1
# Name: runtime (mins), Length: 164, dtype: int64

# %%
bool1 = oscars_df['runtime (mins)'] < 70
oscars_df[bool1]
oscars_df = oscars_df.drop(oscars_df[bool1].index)

# %% [markdown]
# Deleted all short film columns.Now I want to explore Release Date.

# %% [markdown]
# Change release date to datetime

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title language    country  runtime (mins)  \
# 0   tt0091763                     Platoon  English        USA             120
# 7   tt0082979                        Reds  English        USA             195
# 19  tt0084434  An Officer and a Gentleman  English        USA             124
# 25  tt0119360                    In & Out  English        USA              90
# 26  tt0292542            Son of the Bride  Spanish  Argentina             123
#
#    mpaarating release date  metacritic score      budget  \
# 0           R     6-Feb-87              92.0   6000000.0
# 7          PG    25-Dec-81              76.0  32000000.0
# 19          R    13-Aug-82              75.0   7500000.0
# 25      PG-13    19-Sep-97              70.0  35000000.0
# 26          R    16-Aug-01              68.0         NaN
#
#        distributionCompany  ... Total_Noms               writer1  \
# 0           Orion Pictures  ...          7          Oliver Stone
# 7       Paramount Pictures  ...         12         Warren Beatty
# 19      Paramount Pictures  ...          6   Douglas Day Stewart
# 25      Paramount Pictures  ...          1          Paul Rudnick
# 26  Sony Pictures Classics  ...          1  Juan José Campanella
#
#              writer2              director     Lead_Actor Supporting_Actor_1  \
# 0                NaN          Oliver Stone  Charlie Sheen       Tom Berenger
# 7   Trevor Griffiths         Warren Beatty  Warren Beatty       Diane Keaton
# 19               NaN       Taylor Hackford   Richard Gere       Debra Winger
# 25               NaN              Frank Oz    Kevin Kline        Joan Cusack
# 26  Fernando Castets  Juan José Campanella  Ricardo Darín     Héctor Alterio
#
#    Supporting_Actor_2              genre main_genre subgenre
# 0        Willem Dafoe        Drama' 'War      Drama      War
# 7     Edward Herrmann  Biography' 'Drama  Biography    Drama
# 19        David Keith    Drama' 'Romance      Drama  Romance
# 25        Tom Selleck   Comedy' 'Romance     Comedy  Romance
# 26     Norma Aleandro     Comedy' 'Drama     Comedy    Drama
#
# [5 rows x 21 columns]

# %%
oscars_df.drop(oscars_df.loc[oscars_df['release date']=='Episode aired 29 January 1996'].index, inplace=True)

# %%
oscars_df['release_date'] = pd.to_datetime(oscars_df['release date'],errors = 'coerce')

# %%
oscars_df.head()
# Out:
#        IMDBId                 movie title language    country  runtime (mins)  \
# 0   tt0091763                     Platoon  English        USA             120
# 7   tt0082979                        Reds  English        USA             195
# 19  tt0084434  An Officer and a Gentleman  English        USA             124
# 25  tt0119360                    In & Out  English        USA              90
# 26  tt0292542            Son of the Bride  Spanish  Argentina             123
#
#    mpaarating release date  metacritic score      budget  \
# 0           R     6-Feb-87              92.0   6000000.0
# 7          PG    25-Dec-81              76.0  32000000.0
# 19          R    13-Aug-82              75.0   7500000.0
# 25      PG-13    19-Sep-97              70.0  35000000.0
# 26          R    16-Aug-01              68.0         NaN
#
#        distributionCompany  ...               writer1           writer2  \
# 0           Orion Pictures  ...          Oliver Stone               NaN
# 7       Paramount Pictures  ...         Warren Beatty  Trevor Griffiths
# 19      Paramount Pictures  ...   Douglas Day Stewart               NaN
# 25      Paramount Pictures  ...          Paul Rudnick               NaN
# 26  Sony Pictures Classics  ...  Juan José Campanella  Fernando Castets
#
#                 director     Lead_Actor Supporting_Actor_1 Supporting_Actor_2  \
# 0           Oliver Stone  Charlie Sheen       Tom Berenger       Willem Dafoe
# 7          Warren Beatty  Warren Beatty       Diane Keaton    Edward Herrmann
# 19       Taylor Hackford   Richard Gere       Debra Winger        David Keith
# 25              Frank Oz    Kevin Kline        Joan Cusack        Tom Selleck
# 26  Juan José Campanella  Ricardo Darín     Héctor Alterio     Norma Aleandro
#
#                 genre main_genre subgenre release_date
# 0         Drama' 'War      Drama      War   1987-02-06
# 7   Biography' 'Drama  Biography    Drama   1981-12-25
# 19    Drama' 'Romance      Drama  Romance   1982-08-13
# 25   Comedy' 'Romance     Comedy  Romance   1997-09-19
# 26     Comedy' 'Drama     Comedy    Drama   2001-08-16
#
# [5 rows x 22 columns]

# %%
oscars_df.drop(['release date'], axis=1,inplace=True)

# %% [markdown]
# ## Explore Metacritic and see how many NaN we retrieve

# %%
oscars_df.groupby('metacritic score').tail()
# Out:
#          IMDBId               movie title language      country  \
# 147   tt0166943        Music of the Heart  English          USA
# 197   tt1065073                   Boyhood  English          USA
# 477   tt0111495         Three Colors: Red   French  Switzerland
# 566   tt0083922       Fanny and Alexander  Swedish       Sweden
# 576   tt0097937              My Left Foot  English      Ireland
# ...         ...                       ...      ...          ...
# 3698  tt0298203                    8 Mile  English          USA
# 3699  tt0162661             Sleepy Hollow  English      Germany
# 3702  tt0293508  The Phantom of the Opera  English           UK
# 3707  tt0097351           Field of Dreams  English          USA
# 3711  tt0087957               Purple Rain  English          USA
#
#       runtime (mins) mpaarating  metacritic score       budget  \
# 147              124         PG              54.0   27000000.0
# 197              165          R             100.0    4000000.0
# 477               99          R             100.0          NaN
# 566              188          R             100.0    6000000.0
# 576              103          R              97.0          NaN
# ...              ...        ...               ...          ...
# 3698             110          R              77.0   41000000.0
# 3699             105          R              65.0  100000000.0
# 3702             143      PG-13              40.0   70000000.0
# 3707             107         PG              57.0          NaN
# 3711             111          R              55.0    7200000.0
#
#      distributionCompany                              Awards  ...  \
# 147              Miramax      Best Actress in a Leading Role  ...
# 197            IFC Films     Best Motion Picture of the Year  ...
# 477              Miramax                 Best Cinematography  ...
# 566     Embassy Pictures   Best Art Direction-Set Decoration  ...
# 576              Miramax        Best Actor in a Leading Role  ...
# ...                  ...                                 ...  ...
# 3698  Universal Pictures           Best Music, Original Song  ...
# 3699  Paramount Pictures   Best Art Direction-Set Decoration  ...
# 3702        Warner Bros.  Best Achievement in Cinematography  ...
# 3707  Universal Pictures          Best Music, Original Score  ...
# 3711        Warner Bros.     Best Music, Original Song Score  ...
#
#                    writer1               writer2              director  \
# 147            Pamela Gray                   NaN            Wes Craven
# 197      Richard Linklater                   NaN     Richard Linklater
# 477   Krzysztof Kieslowski  Krzysztof Piesiewicz  Krzysztof Kieslowski
# 566         Ingmar Bergman                   NaN        Ingmar Bergman
# 576      Shane Connaughton          Jim Sheridan          Jim Sheridan
# ...                    ...                   ...                   ...
# 3698          Scott Silver                   NaN         Curtis Hanson
# 3699     Washington Irving          Kevin Yagher            Tim Burton
# 3702         Gaston Leroux   Andrew Lloyd Webber       Joel Schumacher
# 3707         W.P. Kinsella   Phil Alden Robinson   Phil Alden Robinson
# 3711        Albert Magnoli         William Blinn        Albert Magnoli
#
#             Lead_Actor      Supporting_Actor_1  Supporting_Actor_2  \
# 147       Meryl Streep         Cloris Leachman      Henry Dinhofer
# 197     Ellar Coltrane       Patricia Arquette         Ethan Hawke
# 477        Irène Jacob  Jean-Louis Trintignant    Frédérique Feder
# 566        Bertil Guve         Pernilla Allwin  Kristina Adolphson
# 576   Daniel Day-Lewis          Brenda Fricker       Alison Whelan
# ...                ...                     ...                 ...
# 3698            Eminem         Brittany Murphy        Kim Basinger
# 3699       Johnny Depp         Christina Ricci  Miranda Richardson
# 3702     Gerard Butler             Emmy Rossum      Patrick Wilson
# 3707     Kevin Costner        James Earl Jones          Ray Liotta
# 3711            Prince        Apollonia Kotero          Morris Day
#
#                   genre main_genre subgenre release_date
# 147       Drama' 'Music      Drama    Music   1999-10-29
# 197               Drama      Drama            2014-08-15
# 477     Drama' 'Mystery      Drama  Mystery   1994-11-23
# 566               Drama      Drama            1982-12-17
# 576   Biography' 'Drama  Biography    Drama   1990-03-30
# ...                 ...        ...      ...          ...
# 3698      Drama' 'Music      Drama    Music   2002-11-08
# 3699   Fantasy' 'Horror    Fantasy   Horror   1999-11-19
# 3702    Drama' 'Musical      Drama  Musical   2004-12-10
# 3707     Drama' 'Family      Drama   Family   1989-05-05
# 3711      Drama' 'Music      Drama    Music   1984-07-27
#
# [307 rows x 21 columns]

# %%
bool1 = pd.isnull(oscars_df['metacritic score'])
oscars_df[bool1]
# Out:
#          IMDBId          movie title   language       country  runtime (mins)  \
# 29    tt0082736             Mephisto  Hungarian  West Germany             144
# 32    tt0087027               Camila    Spanish     Argentina             105
# 33    tt0094924    A Cry in the Dark    English     Australia             120
# 58    tt0095530        Little Dorrit    English            UK             357
# 104   tt0111797  Eat Drink Man Woman   Mandarin        Taiwan             124
# ...         ...                  ...        ...           ...             ...
# 3631  tt0116040             Daylight    English           USA             114
# 3666  tt0088857       Broken Rainbow    English           USA              70
# 3668  tt0113896            My Family    English           USA             128
# 3684  tt0080337                 Agee    English           USA              98
# 3696  tt0095274    A Handful of Dust    English            UK             118
#
#      mpaarating  metacritic score      budget  \
# 29      Unrated               NaN         NaN
# 32            R               NaN         NaN
# 33        PG-13               NaN  15000000.0
# 58            G               NaN         NaN
# 104   Not Rated               NaN         NaN
# ...         ...               ...         ...
# 3631      PG-13               NaN  80000000.0
# 3666   1h 10min               NaN         NaN
# 3668          R               NaN   5500000.0
# 3684    Unrated               NaN         NaN
# 3696         PG               NaN         NaN
#
#                       distributionCompany  \
# 29    Analysis Film Releasing Corporation
# 32                      European Classics
# 33                           Warner Bros.
# 58               Cannon Film Distributors
# 104            The Samuel Goldwyn Company
# ...                                   ...
# 3631                   Universal Pictures
# 3666                           Earthworks
# 3668        American Broadcasting Company
# 3684                                  NaN
# 3696                      Home Box Office
#
#                                    Awards  ...              writer1  \
# 29             Best Foreign Language Film  ...          Péter Dobai
# 32             Best Foreign Language Film  ...  María Luisa Bemberg
# 33         Best Actress in a Leading Role  ...          John Bryson
# 58        Best Actor in a Supporting Role  ...      Charles Dickens
# 104            Best Foreign Language Film  ...              Ang Lee
# ...                                   ...  ...                  ...
# 3631  Best Effects, Sound Effects Editing  ...         Leslie Bohem
# 3666           Best Documentary, Features  ...         Maria Florio
# 3668                          Best Makeup  ...         Gregory Nava
# 3684           Best Documentary, Features  ...          Ross Spears
# 3696                  Best Costume Design  ...         Evelyn Waugh
#
#                   writer2             director             Lead_Actor  \
# 29           István Szabó         István Szabó  Klaus Maria Brandauer
# 32    Beda Docampo Feijóo  María Luisa Bemberg          Susú Pecoraro
# 33         Robert Caswell        Fred Schepisi           Meryl Streep
# 58       Christine Edzard     Christine Edzard           Derek Jacobi
# 104         James Schamus              Ang Lee            Sihung Lung
# ...                   ...                  ...                    ...
# 3631                  NaN            Rob Cohen     Sylvester Stallone
# 3666        Victoria Mudd        Victoria Mudd           Martin Sheen
# 3668          Anna Thomas         Gregory Nava            Jimmy Smits
# 3684                  NaN          Ross Spears             James Agee
# 3696         Tim Sullivan    Charles Sturridge            James Wilby
#
#         Supporting_Actor_1  Supporting_Actor_2                  genre  \
# 29          Krystyna Janda      Ildikó Bánsági                  Drama
# 32            Imanol Arias      Héctor Alterio        Drama' 'Romance
# 33               Sam Neill         Dale Reeves      Biography' 'Drama
# 58           Alec Guinness      Joan Greenwood        Drama' 'Romance
# 104          Kuei-Mei Yang         Yu-Wen Wang         Comedy' 'Drama
# ...                    ...                 ...                    ...
# 3631         Amy Brenneman     Viggo Mortensen     Action' 'Adventure
# 3666    Buffy Sainte-Marie    Burgess Meredith  Documentary' 'History
# 3668          Esai Morales  Edward James Olmos                  Drama
# 3684              Mia Agee       Mae Burroughs            Documentary
# 3696  Kristin Scott Thomas       Richard Beale        Drama' 'Romance
#
#        main_genre   subgenre release_date
# 29          Drama              1982-03-22
# 32          Drama    Romance   1985-03-15
# 33      Biography      Drama   1988-11-11
# 58          Drama    Romance   1988-10-21
# 104        Comedy      Drama   1994-08-03
# ...           ...        ...          ...
# 3631       Action  Adventure   1996-12-06
# 3666  Documentary    History          NaT
# 3668        Drama              1995-05-03
# 3684  Documentary              1980-11-14
# 3696        Drama    Romance   1988-06-24
#
# [187 rows x 21 columns]

# %% [markdown]
# Since we are looking for the metacritc score if a movie doesn't have a score it wont provide much information and will be dropped

# %%
oscars_df.dropna(subset=['metacritic score'],inplace=True)

# %%
oscars_df.shape
# Out:
# (1136, 21)

# %% [markdown]
# ## Now I want to explore the relationship between distribution company and budget to see if we can fill some of the budget NAN columns with the studios average budget

# %%
grouped = oscars_df.groupby('distributionCompany')['budget'].transform('mean')

# %%
oscars_df['budget'] = oscars_df['budget'].fillna(grouped)

# %%
oscars_df['budget']
# Out:
# 0       6.000000e+06
# 7       3.200000e+07
# 19      7.500000e+06
# 25      3.500000e+07
# 26      1.136429e+07
#             ...
# 3698    4.100000e+07
# 3699    1.000000e+08
# 3702    7.000000e+07
# 3707    4.617013e+07
# 3711    7.200000e+06
# Name: budget, Length: 1136, dtype: float64

# %% [markdown]
# ## Explore the ratings column

# %%
oscars_df.mpaarating.value_counts()
# Out:
# R            532
# PG-13        307
# PG           212
# Not Rated     34
# G             34
# Unrated        4
# TV-MA          2
# 1h 55min       1
# 2h 10min       1
# 1h 56min       1
# 2h 9min        1
# 1h 54min       1
# 1h 30min       1
# 1h 47min       1
# 1h 46min       1
# 1h 24min       1
# 1h 34min       1
# 1h 48min       1
# Name: mpaarating, dtype: int64

# %%
oscars_df['mpaarating'].replace(['TV-MA'],'R',inplace=True)
oscars_df['mpaarating'].replace(['1h 55min','1h 46min','1h 56min','2h 10min' ,      
                                 '2h 9min','1h 48min','1h 47min','1h 34min',       
                                 '1h 24min','1h 54min','1h 30min'],'Unrated',inplace=True)

# %%
oscars_df.mpaarating.value_counts()
# Out:
# R            534
# PG-13        307
# PG           212
# Not Rated     34
# G             34
# Unrated       15
# Name: mpaarating, dtype: int64

# %% [markdown]
# ## Create a Seasons column

# %%
def get_season(column):
    seasons_list = []
    month =  pd.DatetimeIndex(oscars_df[column]).month
    seasons_list = []
    for m in month:
        if m == 12 or m <= 3 :
            seasons_list.append('Winter')
        elif m <= 5 :
            seasons_list.append('Spring')
        elif m<= 8:
            seasons_list.append('Summer')
        else:
            seasons_list.append('Fall')
    return seasons_list

# %%
oscars_df['season'] = get_season('release_date')

# %%
oscars_df.season.value_counts()
# Out:
# Winter    464
# Fall      320
# Summer    237
# Spring    115
# Name: season, dtype: int64

# %% [markdown]
# ## Explore Awards Category

# %%
oscars_df['Awards'].value_counts()
# Out:
# Best Motion Picture of the Year                                                121
# Best Actor in a Leading Role                                                   107
# Best Actor in a Supporting Role                                                 77
# Best Actress in a Leading Role                                                  69
# Best Foreign Language Film of the Year                                          61
# Best Performance by an Actress in a Leading Role                                48
# Best Art Direction-Set Decoration                                               37
# Best Music, Original Song                                                       35
# Best Actress in a Supporting Role                                               34
# Best Foreign Language Film                                                      32
# Best Performance by an Actor in a Leading Role                                  30
# Best Effects, Sound Effects Editing                                             25
# Best Documentary, Features                                                      25
# Best Performance by an Actor in a Supporting Role                               23
# Best Animated Feature Film of the Year                                          21
# Best Effects, Visual Effects                                                    21
# Best Achievement in Music Written for Motion Pictures, Original Song            20
# Best Achievement in Cinematography                                              20
# Best Cinematography                                                             19
# Best Achievement in Costume Design                                              19
# Best Costume Design                                                             17
# Best Achievement in Visual Effects                                              17
# Best Writing, Screenplay Written Directly for the Screen                        16
# Best Performance by an Actress in a Supporting Role                             16
# Best Writing, Original Screenplay                                               15
# Best Picture                                                                    15
# Best Achievement in Sound Mixing                                                13
# Best Makeup                                                                     13
# Best Director                                                                   12
# Best Sound                                                                      12
# Best Music, Original Musical or Comedy Score                                    12
# Best Music, Original Score                                                      11
# Best Film Editing                                                               10
# Best Animated Feature                                                            9
# Best Writing, Adapted Screenplay                                                 9
# Best Achievement in Art Direction                                                9
# Best Achievement in Music Written for Motion Pictures (Original Song)            8
# Best Animated Feature Film                                                       8
# Best Achievement in Music Written for Motion Pictures, Original Score            8
# Best Achievement in Production Design                                            7
# Best Achievement in Makeup and Hairstyling                                       6
# Best Achievement in Makeup                                                       6
# Best Documentary Feature                                                         6
# Best Achievement in Sound Editing                                                5
# Best Writing, Screenplay Based on Material Previously Produced or Published      4
# Best Documentary, Feature                                                        4
# Best Adapted Screenplay                                                          3
# Best Achievement in Music Written for Motion Pictures (Original Score)           3
# Best Original Screenplay                                                         3
# Best Achievement in Directing                                                    3
# Best Writing, Screenplay Based on Material from Another Medium                   2
# Best Sound Editing                                                               2
# Best Achievement in Film Editing                                                 2
# Best International Feature Film                                                  2
# Best Visual Effects                                                              1
# Best Music, Original Song Score and Its Adaptation or Best Adaptation Score      1
# Best Music, Original Dramatic Score                                              1
# Best Music, Original Song Score                                                  1
# Name: Awards, dtype: int64

# %%
oscars_df.to_csv('oscar_movies_data.csv',encoding='utf-8-sig')
