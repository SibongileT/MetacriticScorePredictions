# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split, validation_curve
from sklearn.linear_model import Lasso,LassoCV,LinearRegression,RidgeCV
from sklearn.preprocessing import StandardScaler,PolynomialFeatures

# %%
oscars_df = pd.read_csv('oscar_movies_data_2.csv')

# %%
oscars_df.describe()
# Out:
#         Unnamed: 0  runtime (mins)  metacritic score        budget  \
# count  1136.000000     1136.000000       1136.000000  1.072000e+03
# mean   1974.561620      120.032570         72.083627  4.289049e+07
# std     981.326583       21.817864         13.554168  5.066237e+07
# min       0.000000       70.000000         16.000000  6.500000e+04
# 25%    1132.750000      105.000000         64.000000  1.193676e+07
# 50%    2181.500000      118.000000         74.000000  2.500000e+07
# 75%    2841.750000      132.000000         82.000000  5.200000e+07
# max    3302.000000      224.000000        100.000000  3.210000e+08
#
#         Total_Noms  Avg_Award_Score  Awards_Best Actor in a Leading Role  \
# count  1136.000000      1136.000000                           479.000000
# mean      2.930458        75.760802                             0.223382
# std       2.699895         4.823890                             0.416948
# min       1.000000        55.000000                             0.000000
# 25%       1.000000        73.186275                             0.000000
# 50%       2.000000        75.769912                             0.000000
# 75%       4.000000        78.828571                             0.000000
# max      16.000000        86.111111                             1.000000
#
#        Awards_Best Actor in a Supporting Role  \
# count                              479.000000
# mean                                 0.160752
# std                                  0.367686
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Awards_Best Actress in a Leading Role  \
# count                             479.000000
# mean                                0.144050
# std                                 0.351508
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Awards_Best Art Direction-Set Decoration  ...  Writer_Aaron Sorkin  \
# count                                479.000000  ...            63.000000
# mean                                   0.077244  ...             0.095238
# std                                    0.267258  ...             0.295901
# min                                    0.000000  ...             0.000000
# 25%                                    0.000000  ...             0.000000
# 50%                                    0.000000  ...             0.000000
# 75%                                    0.000000  ...             0.000000
# max                                    1.000000  ...             1.000000
#
#        Writer_Joel Coen  Writer_John Logan  Writer_Lawrence Kasdan  \
# count         63.000000          63.000000               63.000000
# mean           0.142857           0.079365                0.111111
# std            0.352738           0.272479                0.316794
# min            0.000000           0.000000                0.000000
# 25%            0.000000           0.000000                0.000000
# 50%            0.000000           0.000000                0.000000
# 75%            0.000000           0.000000                0.000000
# max            1.000000           1.000000                1.000000
#
#        Writer_Paul Thomas Anderson  Writer_Pedro Almodóvar  \
# count                    63.000000               63.000000
# mean                      0.079365                0.079365
# std                       0.272479                0.272479
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                0.000000
# max                       1.000000                1.000000
#
#        Writer_Peter Morgan  Writer_Quentin Tarantino  \
# count            63.000000                 63.000000
# mean              0.063492                  0.095238
# std               0.245805                  0.295901
# min               0.000000                  0.000000
# 25%               0.000000                  0.000000
# 50%               0.000000                  0.000000
# 75%               0.000000                  0.000000
# max               1.000000                  1.000000
#
#        Writer_William Shakespeare  Writer_Woody Allen
# count                   63.000000           63.000000
# mean                     0.063492            0.190476
# std                      0.245805            0.395831
# min                      0.000000            0.000000
# 25%                      0.000000            0.000000
# 50%                      0.000000            0.000000
# 75%                      0.000000            0.000000
# max                      1.000000            1.000000
#
# [8 rows x 91 columns]

# %%
oscars_df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
oscars_df.head()
# Out:
#       IMDBId                 movie title language    country  runtime (mins)  \
# 0  tt0091763                     Platoon  English        USA             120
# 1  tt0082979                        Reds  English        USA             195
# 2  tt0084434  An Officer and a Gentleman  English        USA             124
# 3  tt0119360                    In & Out  English        USA              90
# 4  tt0292542            Son of the Bride  Spanish  Argentina             123
#
#   mpaarating  metacritic score        budget     distributionCompany  \
# 0          R              92.0  6.000000e+06          Orion Pictures
# 1         PG              76.0  3.200000e+07      Paramount Pictures
# 2          R              75.0  7.500000e+06      Paramount Pictures
# 3      PG-13              70.0  3.500000e+07      Paramount Pictures
# 4          R              68.0  1.193676e+07  Sony Pictures Classics
#
#                               Awards  ...  Writer_Aaron Sorkin  \
# 0    Best Actor in a Supporting Role  ...                  NaN
# 1       Best Actor in a Leading Role  ...                  NaN
# 2    Best Actor in a Supporting Role  ...                  NaN
# 3  Best Actress in a Supporting Role  ...                  NaN
# 4         Best Foreign Language Film  ...                  NaN
#
#   Writer_Joel Coen Writer_John Logan Writer_Lawrence Kasdan  \
# 0              NaN               NaN                    NaN
# 1              NaN               NaN                    NaN
# 2              NaN               NaN                    NaN
# 3              NaN               NaN                    NaN
# 4              NaN               NaN                    NaN
#
#   Writer_Paul Thomas Anderson Writer_Pedro Almodóvar Writer_Peter Morgan  \
# 0                         NaN                    NaN                 NaN
# 1                         NaN                    NaN                 NaN
# 2                         NaN                    NaN                 NaN
# 3                         NaN                    NaN                 NaN
# 4                         NaN                    NaN                 NaN
#
#   Writer_Quentin Tarantino Writer_William Shakespeare Writer_Woody Allen
# 0                      NaN                        NaN                NaN
# 1                      NaN                        NaN                NaN
# 2                      NaN                        NaN                NaN
# 3                      NaN                        NaN                NaN
# 4                      NaN                        NaN                NaN
#
# [5 rows x 108 columns]

# %%
numerics = ['int16','int32','int64','float16','float32','float64']
numerical_vars = list(oscars_df.select_dtypes(include=numerics).columns)
oscars_data = oscars_df[numerical_vars]
oscars_data.shape
# Out:
# (1136, 90)

# %%
oscars_data.columns
# Out:
# Index(['runtime (mins)', 'metacritic score', 'budget', 'Total_Noms',
#        'Avg_Award_Score', 'Awards_Best Actor in a Leading Role',
#        'Awards_Best Actor in a Supporting Role',
#        'Awards_Best Actress in a Leading Role',
#        'Awards_Best Art Direction-Set Decoration',
#        'Awards_Best Cinematography', 'Awards_Best Director',
#        'Awards_Best Film Editing', 'Awards_Best Motion Picture of the Year',
#        'Awards_Best Picture', 'Awards_Best Sound', 'Director_Avg_Score',
#        'Total_Director_Movies', 'Lead_Actor_Avg_Score',
#        'Total_Movies_Lead_Actor', 'Avg_Rating_by_Genre',
#        'Buena Vista Pictures', 'Columbia Pictures', 'Fox Searchlight Pictures',
#        'Miramax', 'Paramount Pictures', 'Sony Pictures Classics',
#        'Twentieth Century Fox', 'Universal Pictures',
#        'Walt Disney Studios Motion Pictures', 'Warner Bros.', 'Genre_Action',
#        'Genre_Adventure', 'Genre_Animation', 'Genre_Biography', 'Genre_Comedy',
#        'Genre_Crime', 'Genre_Documentary', 'Genre_Drama', 'Genre_Fantasy',
#        'Genre_Horror', 'Subgenre_Adventure', 'Subgenre_Comedy',
#        'Subgenre_Crime', 'Subgenre_Drama', 'Subgenre_Fantasy',
#        'Subgenre_History', 'Subgenre_Music', 'Subgenre_Mystery',
#        'Subgenre_Romance', 'Subgenre_Thriller', 'Director_Barry Levinson',
#        'Director_Clint Eastwood', 'Director_Martin Scorsese',
#        'Director_Ridley Scott', 'Director_Robert Zemeckis',
#        'Director_Ron Howard', 'Director_Stephen Frears',
#        'Director_Steven Spielberg', 'Director_Tim Burton',
#        'Director_Woody Allen', 'Lead_Actor_Brad Pitt',
#        'Lead_Actor_Harrison Ford', 'Lead_Actor_Johnny Depp',
#        'Lead_Actor_Leonardo DiCaprio', 'Lead_Actor_Meryl Streep',
#        'Lead_Actor_Michael Douglas', 'Lead_Actor_Robert De Niro',
#        'Lead_Actor_Robin Williams', 'Lead_Actor_Tom Cruise',
#        'Lead_Actor_Tom Hanks', 'Fall', 'Spring', 'Summer', 'Winter', 'G',
#        'Not Rated', 'PG', 'PG-13', 'R', 'Unrated', 'Writer_Aaron Sorkin',
#        'Writer_Joel Coen', 'Writer_John Logan', 'Writer_Lawrence Kasdan',
#        'Writer_Paul Thomas Anderson', 'Writer_Pedro Almodóvar',
#        'Writer_Peter Morgan', 'Writer_Quentin Tarantino',
#        'Writer_William Shakespeare', 'Writer_Woody Allen'],
#       dtype='object')

# %%
oscars_data.corr()
# Out:
#                             runtime (mins)  metacritic score    budget  \
# runtime (mins)                    1.000000         -0.019315  0.215425
# metacritic score                 -0.019315          1.000000 -0.157224
# budget                            0.215425         -0.157224  1.000000
# Total_Noms                        0.355896          0.327954  0.047432
# Avg_Award_Score                   0.086005          0.472480 -0.063835
# ...                                    ...               ...       ...
# Writer_Pedro Almodóvar           -0.215690          0.262293 -0.189725
# Writer_Peter Morgan              -0.056219          0.007698 -0.067855
# Writer_Quentin Tarantino          0.478316          0.042797  0.084962
# Writer_William Shakespeare        0.156014         -0.248121 -0.091080
# Writer_Woody Allen               -0.570291         -0.022064 -0.255973
#
#                             Total_Noms  Avg_Award_Score  \
# runtime (mins)                0.355896         0.086005
# metacritic score              0.327954         0.472480
# budget                        0.047432        -0.063835
# Total_Noms                    1.000000         0.289615
# Avg_Award_Score               0.289615         1.000000
# ...                                ...              ...
# Writer_Pedro Almodóvar       -0.222301        -0.052859
# Writer_Peter Morgan          -0.025416         0.084199
# Writer_Quentin Tarantino      0.247848         0.165826
# Writer_William Shakespeare   -0.071828        -0.220342
# Writer_Woody Allen           -0.177043        -0.052113
#
#                             Awards_Best Actor in a Leading Role  \
# runtime (mins)                                         0.057316
# metacritic score                                       0.018230
# budget                                                -0.099809
# Total_Noms                                             0.034515
# Avg_Award_Score                                       -0.168470
# ...                                                         ...
# Writer_Pedro Almodóvar                                -0.055902
# Writer_Peter Morgan                                   -0.080322
# Writer_Quentin Tarantino                               0.160357
# Writer_William Shakespeare                             0.266667
# Writer_Woody Allen                                     0.124226
#
#                             Awards_Best Actor in a Supporting Role  \
# runtime (mins)                                           -0.002587
# metacritic score                                         -0.057095
# budget                                                   -0.086524
# Total_Noms                                               -0.082633
# Avg_Award_Score                                          -0.228600
# ...                                                            ...
# Writer_Pedro Almodóvar                                   -0.100000
# Writer_Peter Morgan                                      -0.143684
# Writer_Quentin Tarantino                                 -0.041833
# Writer_William Shakespeare                               -0.178885
# Writer_Woody Allen                                        0.100000
#
#                             Awards_Best Actress in a Leading Role  \
# runtime (mins)                                          -0.110538
# metacritic score                                        -0.117517
# budget                                                  -0.057325
# Total_Noms                                              -0.171212
# Avg_Award_Score                                         -0.432965
# ...                                                           ...
# Writer_Pedro Almodóvar                                        NaN
# Writer_Peter Morgan                                           NaN
# Writer_Quentin Tarantino                                      NaN
# Writer_William Shakespeare                                    NaN
# Writer_Woody Allen                                            NaN
#
#                             Awards_Best Art Direction-Set Decoration  \
# runtime (mins)                                              0.047673
# metacritic score                                           -0.138721
# budget                                                      0.026732
# Total_Noms                                                 -0.101990
# Avg_Award_Score                                            -0.221517
# ...                                                              ...
# Writer_Pedro Almodóvar                                     -0.074702
# Writer_Peter Morgan                                        -0.107335
# Writer_Quentin Tarantino                                   -0.178571
# Writer_William Shakespeare                                  0.454344
# Writer_Woody Allen                                          0.019920
#
#                             Awards_Best Cinematography  ...  \
# runtime (mins)                               -0.008730  ...
# metacritic score                             -0.094469  ...
# budget                                       -0.008485  ...
# Total_Noms                                   -0.081325  ...
# Avg_Award_Score                              -0.056533  ...
# ...                                                ...  ...
# Writer_Pedro Almodóvar                       -0.031250  ...
# Writer_Peter Morgan                          -0.044901  ...
# Writer_Quentin Tarantino                     -0.074702  ...
# Writer_William Shakespeare                   -0.055902  ...
# Writer_Woody Allen                           -0.083333  ...
#
#                             Writer_Aaron Sorkin  Writer_Joel Coen  \
# runtime (mins)                        -0.023114         -0.132803
# metacritic score                      -0.023612          0.096561
# budget                                 0.033988         -0.066141
# Total_Noms                            -0.079862          0.020791
# Avg_Award_Score                       -0.028251          0.251645
# ...                                         ...               ...
# Writer_Pedro Almodóvar                -0.095260         -0.119866
# Writer_Peter Morgan                   -0.084478         -0.106299
# Writer_Quentin Tarantino              -0.105263         -0.132453
# Writer_William Shakespeare            -0.084478         -0.106299
# Writer_Woody Allen                    -0.157378         -0.198030
#
#                             Writer_John Logan  Writer_Lawrence Kasdan  \
# runtime (mins)                       0.229385                0.031129
# metacritic score                    -0.079062               -0.302794
# budget                               0.588325                0.127137
# Total_Noms                           0.259185               -0.012004
# Avg_Award_Score                      0.023887               -0.293702
# ...                                       ...                     ...
# Writer_Pedro Almodóvar              -0.086207               -0.103807
# Writer_Peter Morgan                 -0.076450               -0.092057
# Writer_Quentin Tarantino            -0.095260               -0.114708
# Writer_William Shakespeare          -0.076450               -0.092057
# Writer_Woody Allen                  -0.142422               -0.171499
#
#                             Writer_Paul Thomas Anderson  \
# runtime (mins)                                 0.366141
# metacritic score                               0.271909
# budget                                        -0.074738
# Total_Noms                                     0.112646
# Avg_Award_Score                                0.093793
# ...                                                 ...
# Writer_Pedro Almodóvar                        -0.086207
# Writer_Peter Morgan                           -0.076450
# Writer_Quentin Tarantino                      -0.095260
# Writer_William Shakespeare                    -0.076450
# Writer_Woody Allen                            -0.142422
#
#                             Writer_Pedro Almodóvar  Writer_Peter Morgan  \
# runtime (mins)                           -0.215690            -0.056219
# metacritic score                          0.262293             0.007698
# budget                                   -0.189725            -0.067855
# Total_Noms                               -0.222301            -0.025416
# Avg_Award_Score                          -0.052859             0.084199
# ...                                            ...                  ...
# Writer_Pedro Almodóvar                    1.000000            -0.076450
# Writer_Peter Morgan                      -0.076450             1.000000
# Writer_Quentin Tarantino                 -0.095260            -0.084478
# Writer_William Shakespeare               -0.076450            -0.067797
# Writer_Woody Allen                       -0.142422            -0.126302
#
#                             Writer_Quentin Tarantino  \
# runtime (mins)                              0.478316
# metacritic score                            0.042797
# budget                                      0.084962
# Total_Noms                                  0.247848
# Avg_Award_Score                             0.165826
# ...                                              ...
# Writer_Pedro Almodóvar                     -0.095260
# Writer_Peter Morgan                        -0.084478
# Writer_Quentin Tarantino                    1.000000
# Writer_William Shakespeare                 -0.084478
# Writer_Woody Allen                         -0.157378
#
#                             Writer_William Shakespeare  Writer_Woody Allen
# runtime (mins)                                0.156014           -0.570291
# metacritic score                             -0.248121           -0.022064
# budget                                       -0.091080           -0.255973
# Total_Noms                                   -0.071828           -0.177043
# Avg_Award_Score                              -0.220342           -0.052113
# ...                                                ...                 ...
# Writer_Pedro Almodóvar                       -0.076450           -0.142422
# Writer_Peter Morgan                          -0.067797           -0.126302
# Writer_Quentin Tarantino                     -0.084478           -0.157378
# Writer_William Shakespeare                    1.000000           -0.126302
# Writer_Woody Allen                           -0.126302            1.000000
#
# [90 rows x 90 columns]

# %%
plt.figure(figsize=(40,40))
sns.heatmap(oscars_data.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(oscars_data, vars=['metacritic score','budget','Total_Director_Movies','runtime (mins)','Total_Noms','Avg_Award_Score','Lead_Actor_Avg_Score','Director_Avg_Score'])

# %%
oscars_data.fillna(0,inplace=True)
# Out:
# /Users/sibongiletoure/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/frame.py:4316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
def residuals_plot(y_pred,y_test):
    residuals = y_test - y_pred

    plt.figure(figsize=(12,12))
    plt.scatter(y_pred,residuals)

    plt.axhline(0,linestyle="--",color='gray')
    plt.xlabel('Predicted Values',fontsize=18)
    plt.ylabel('Residuals',fontsize=18)

# %%
def residual_scatter(y_pred,y_test):
    plt.scatter(y_pred, y_test, alpha=.1)
    plt.plot(np.linspace(50,100,1), np.linspace(50,100,1))

# %% [markdown]
# ## Split test

# %%
X = oscars_data.drop(columns=['metacritic score'])
y = oscars_data['metacritic score']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=27)

# %%
X_train.describe()
# Out:
#        runtime (mins)        budget  Total_Noms  Avg_Award_Score  \
# count      908.000000  9.080000e+02  908.000000       908.000000
# mean       120.633260  4.096697e+07    2.889868        75.720575
# std         22.232035  5.076025e+07    2.632799         4.831326
# min         70.000000  0.000000e+00    1.000000        55.000000
# 25%        105.000000  1.000000e+07    1.000000        73.186275
# 50%        118.000000  2.300000e+07    2.000000        75.769912
# 75%        132.000000  5.000000e+07    4.000000        78.828571
# max        224.000000  3.210000e+08   14.000000        86.111111
#
#        Awards_Best Actor in a Leading Role  \
# count                           908.000000
# mean                              0.085903
# std                               0.280375
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Awards_Best Actor in a Supporting Role  \
# count                              908.000000
# mean                                 0.064978
# std                                  0.246623
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Awards_Best Actress in a Leading Role  \
# count                             908.000000
# mean                                0.064978
# std                                 0.246623
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Awards_Best Art Direction-Set Decoration  Awards_Best Cinematography  \
# count                                908.000000                  908.000000
# mean                                   0.033040                    0.016520
# std                                    0.178839                    0.127534
# min                                    0.000000                    0.000000
# 25%                                    0.000000                    0.000000
# 50%                                    0.000000                    0.000000
# 75%                                    0.000000                    0.000000
# max                                    1.000000                    1.000000
#
#        Awards_Best Director  ...  Writer_Aaron Sorkin  Writer_Joel Coen  \
# count            908.000000  ...           908.000000        908.000000
# mean               0.009912  ...             0.006608          0.009912
# std                0.099118  ...             0.081065          0.099118
# min                0.000000  ...             0.000000          0.000000
# 25%                0.000000  ...             0.000000          0.000000
# 50%                0.000000  ...             0.000000          0.000000
# 75%                0.000000  ...             0.000000          0.000000
# max                1.000000  ...             1.000000          1.000000
#
#        Writer_John Logan  Writer_Lawrence Kasdan  Writer_Paul Thomas Anderson  \
# count         908.000000              908.000000                   908.000000
# mean            0.002203                0.005507                     0.004405
# std             0.046906                0.074043                     0.066262
# min             0.000000                0.000000                     0.000000
# 25%             0.000000                0.000000                     0.000000
# 50%             0.000000                0.000000                     0.000000
# 75%             0.000000                0.000000                     0.000000
# max             1.000000                1.000000                     1.000000
#
#        Writer_Pedro Almodóvar  Writer_Peter Morgan  Writer_Quentin Tarantino  \
# count              908.000000           908.000000                908.000000
# mean                 0.005507             0.002203                  0.006608
# std                  0.074043             0.046906                  0.081065
# min                  0.000000             0.000000                  0.000000
# 25%                  0.000000             0.000000                  0.000000
# 50%                  0.000000             0.000000                  0.000000
# 75%                  0.000000             0.000000                  0.000000
# max                  1.000000             1.000000                  1.000000
#
#        Writer_William Shakespeare  Writer_Woody Allen
# count                  908.000000          908.000000
# mean                     0.002203            0.012115
# std                      0.046906            0.109458
# min                      0.000000            0.000000
# 25%                      0.000000            0.000000
# 50%                      0.000000            0.000000
# 75%                      0.000000            0.000000
# max                      1.000000            1.000000
#
# [8 rows x 89 columns]

# %%
X_test.describe()
# Out:
#        runtime (mins)        budget  Total_Noms  Avg_Award_Score  \
# count      228.000000  2.280000e+02  228.000000       228.000000
# mean       117.640351  3.851139e+07    3.092105        75.921005
# std         19.950656  4.795065e+07    2.952685         4.801383
# min         75.000000  0.000000e+00    1.000000        64.229167
# 25%        102.000000  7.741882e+06    1.000000        73.186275
# 50%        116.000000  2.200000e+07    2.000000        75.769912
# 75%        130.000000  4.725000e+07    4.000000        78.871795
# max        188.000000  3.000000e+08   16.000000        86.111111
#
#        Awards_Best Actor in a Leading Role  \
# count                           228.000000
# mean                              0.127193
# std                               0.333922
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        Awards_Best Actor in a Supporting Role  \
# count                              228.000000
# mean                                 0.078947
# std                                  0.270250
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        Awards_Best Actress in a Leading Role  \
# count                             228.000000
# mean                                0.043860
# std                                 0.205233
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Awards_Best Art Direction-Set Decoration  Awards_Best Cinematography  \
# count                                228.000000                  228.000000
# mean                                   0.030702                    0.017544
# std                                    0.172888                    0.131575
# min                                    0.000000                    0.000000
# 25%                                    0.000000                    0.000000
# 50%                                    0.000000                    0.000000
# 75%                                    0.000000                    0.000000
# max                                    1.000000                    1.000000
#
#        Awards_Best Director  ...  Writer_Aaron Sorkin  Writer_Joel Coen  \
# count            228.000000  ...                228.0             228.0
# mean               0.013158  ...                  0.0               0.0
# std                0.114201  ...                  0.0               0.0
# min                0.000000  ...                  0.0               0.0
# 25%                0.000000  ...                  0.0               0.0
# 50%                0.000000  ...                  0.0               0.0
# 75%                0.000000  ...                  0.0               0.0
# max                1.000000  ...                  0.0               0.0
#
#        Writer_John Logan  Writer_Lawrence Kasdan  Writer_Paul Thomas Anderson  \
# count         228.000000              228.000000                   228.000000
# mean            0.013158                0.008772                     0.004386
# std             0.114201                0.093452                     0.066227
# min             0.000000                0.000000                     0.000000
# 25%             0.000000                0.000000                     0.000000
# 50%             0.000000                0.000000                     0.000000
# 75%             0.000000                0.000000                     0.000000
# max             1.000000                1.000000                     1.000000
#
#        Writer_Pedro Almodóvar  Writer_Peter Morgan  Writer_Quentin Tarantino  \
# count                   228.0           228.000000                     228.0
# mean                      0.0             0.008772                       0.0
# std                       0.0             0.093452                       0.0
# min                       0.0             0.000000                       0.0
# 25%                       0.0             0.000000                       0.0
# 50%                       0.0             0.000000                       0.0
# 75%                       0.0             0.000000                       0.0
# max                       0.0             1.000000                       0.0
#
#        Writer_William Shakespeare  Writer_Woody Allen
# count                  228.000000          228.000000
# mean                     0.008772            0.004386
# std                      0.093452            0.066227
# min                      0.000000            0.000000
# 25%                      0.000000            0.000000
# 50%                      0.000000            0.000000
# 75%                      0.000000            0.000000
# max                      1.000000            1.000000
#
# [8 rows x 89 columns]

# %% [markdown]
# ## Scale Data

# %%
X_train_scale = X_train.copy()
X_test_scale = X_test.copy()

# %%
scale = StandardScaler().fit(X_train_scale)
X_train_scale = scale.transform(X_train_scale)
X_test_scale = scale.transform(X_test_scale)

# %% [markdown]
# ## Simple Linear regression

# %%
lm = LinearRegression()
lm.fit(X_train_scale,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test_scale)

# %%
list(zip(oscars_data.drop(columns='metacritic score'),lm.coef_))
# Out:
# [('runtime (mins)', -0.28951482835717124),
#  ('budget', -1.1054964816651642),
#  ('Total_Noms', 2.642340267701697),
#  ('Avg_Award_Score', 0.6021407389935054),
#  ('Awards_Best Actor in a Leading Role', 0.22161108330465495),
#  ('Awards_Best Actor in a Supporting Role', 0.2934459178583473),
#  ('Awards_Best Actress in a Leading Role', 0.33791702368815474),
#  ('Awards_Best Art Direction-Set Decoration', -0.36128987445141414),
#  ('Awards_Best Cinematography', -0.060895661831100956),
#  ('Awards_Best Director', 0.2025446722943931),
#  ('Awards_Best Film Editing', -0.3747167259056752),
#  ('Awards_Best Motion Picture of the Year', -0.48441804367972496),
#  ('Awards_Best Picture', 0.5881166220119951),
#  ('Awards_Best Sound', -0.08777158059291512),
#  ('Director_Avg_Score', 7.300967764068805),
#  ('Total_Director_Movies', -0.40840405173245486),
#  ('Lead_Actor_Avg_Score', 4.676760258282238),
#  ('Total_Movies_Lead_Actor', -0.1700948072751487),
#  ('Avg_Rating_by_Genre', 0.6784958433753784),
#  ('Buena Vista Pictures', -0.08515714494558468),
#  ('Columbia Pictures', -0.05322431691444007),
#  ('Fox Searchlight Pictures', 0.07304375472028218),
#  ('Miramax', -0.1562490459898882),
#  ('Paramount Pictures', 0.09283153461577509),
#  ('Sony Pictures Classics', 0.3008763137673849),
#  ('Twentieth Century Fox', 0.25794847829084333),
#  ('Universal Pictures', -0.2318919013579111),
#  ('Walt Disney Studios Motion Pictures', 0.31125725505960267),
#  ('Warner Bros.', -0.0958635420612261),
#  ('Genre_Action', 0.111360699998176),
#  ('Genre_Adventure', -0.49183852670086636),
#  ('Genre_Animation', -0.27698332620189436),
#  ('Genre_Biography', -0.8047729682594601),
#  ('Genre_Comedy', -0.5811523442578859),
#  ('Genre_Crime', -0.7483257787579868),
#  ('Genre_Documentary', -0.6984421357102992),
#  ('Genre_Drama', -1.4870773471699825),
#  ('Genre_Fantasy', -0.589940931489145),
#  ('Genre_Horror', -0.1501953085583576),
#  ('Subgenre_Adventure', -0.03303664967820691),
#  ('Subgenre_Comedy', 0.05514834370880428),
#  ('Subgenre_Crime', 0.10731728385388051),
#  ('Subgenre_Drama', -0.42366545292014557),
#  ('Subgenre_Fantasy', -0.018927274247487746),
#  ('Subgenre_History', -0.17313660613826598),
#  ('Subgenre_Music', 0.14930241643403463),
#  ('Subgenre_Mystery', 0.04784383150895832),
#  ('Subgenre_Romance', -0.15249649920702202),
#  ('Subgenre_Thriller', -0.0840160338284095),
#  ('Director_Barry Levinson', -0.13042130372559912),
#  ('Director_Clint Eastwood', -0.004149508202885066),
#  ('Director_Martin Scorsese', 0.588774670945452),
#  ('Director_Ridley Scott', 0.09735898931876696),
#  ('Director_Robert Zemeckis', 0.20539707576949057),
#  ('Director_Ron Howard', 0.17996403734012656),
#  ('Director_Stephen Frears', 0.0227095543333945),
#  ('Director_Steven Spielberg', 0.10631853962892168),
#  ('Director_Tim Burton', 0.2577782321400922),
#  ('Director_Woody Allen', -667907949532.5643),
#  ('Lead_Actor_Brad Pitt', -0.2522040048117344),
#  ('Lead_Actor_Harrison Ford', -0.1939094835286641),
#  ('Lead_Actor_Johnny Depp', 0.3788030014721143),
#  ('Lead_Actor_Leonardo DiCaprio', -0.3445659427147931),
#  ('Lead_Actor_Meryl Streep', -0.056285180645570476),
#  ('Lead_Actor_Michael Douglas', -0.08316932390922249),
#  ('Lead_Actor_Robert De Niro', -0.3575123473422003),
#  ('Lead_Actor_Robin Williams', 0.38308268715133553),
#  ('Lead_Actor_Tom Cruise', -0.047524286437228225),
#  ('Lead_Actor_Tom Hanks', 0.09401989897208618),
#  ('Fall', 3130827922.9462786),
#  ('Spring', 2080430894.7205381),
#  ('Summer', 2748629755.611243),
#  ('Winter', 3390534486.698261),
#  ('G', -69281191152.27258),
#  ('Not Rated', -70467429659.65828),
#  ('PG', -155260983803.19675),
#  ('PG-13', -177422605874.7959),
#  ('R', -200049512484.0042),
#  ('Unrated', -47607808240.777306),
#  ('Writer_Aaron Sorkin', 0.06778422319944),
#  ('Writer_Joel Coen', -0.069088311339778),
#  ('Writer_John Logan', -0.23814925877577797),
#  ('Writer_Lawrence Kasdan', 0.11116139545842574),
#  ('Writer_Paul Thomas Anderson', 0.06686963549776592),
#  ('Writer_Pedro Almodóvar', -0.004468511605693615),
#  ('Writer_Peter Morgan', -0.016003931414565603),
#  ('Writer_Quentin Tarantino', 0.09421598178213281),
#  ('Writer_William Shakespeare', 0.1496805781980819),
#  ('Writer_Woody Allen', 667907949532.7795)]

# %%
lm.intercept_
# Out:
# 71.41628729649621

# %%
lm.score(X_train_scale,y_train)
# Out:
# 0.8402927501918056

# %%
lm.score(X_test_scale,y_test)
# Out:
# 0.7614682316559473

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf 

model = sm.OLS(y_train, sm.add_constant(X_train_scale))
results = model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       metacritic score   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     50.23
# Date:                Wed, 07 Oct 2020   Prob (F-statistic):          2.16e-271
# Time:                        21:26:06   Log-Likelihood:                -2834.6
# No. Observations:                 908   AIC:                             5843.
# Df Residuals:                     821   BIC:                             6262.
# Df Model:                          86
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         71.4163      0.192    372.754      0.000      71.040      71.792
# x1            -0.2894      0.267     -1.085      0.278      -0.813       0.234
# x2            -1.1055      0.291     -3.800      0.000      -1.677      -0.535
# x3             2.6422      0.308      8.587      0.000       2.038       3.246
# x4             0.6021      0.280      2.149      0.032       0.052       1.152
# x5             0.2215      0.238      0.929      0.353      -0.246       0.689
# x6             0.2935      0.221      1.330      0.184      -0.140       0.727
# x7             0.3379      0.220      1.539      0.124      -0.093       0.769
# x8            -0.3613      0.216     -1.671      0.095      -0.786       0.063
# x9            -0.0609      0.203     -0.299      0.765      -0.460       0.338
# x10            0.2025      0.210      0.966      0.334      -0.209       0.614
# x11           -0.3748      0.227     -1.652      0.099      -0.820       0.071
# x12           -0.4843      0.287     -1.685      0.092      -1.048       0.080
# x13            0.5882      0.215      2.733      0.006       0.166       1.011
# x14           -0.0876      0.208     -0.421      0.674      -0.496       0.321
# x15            7.3010      0.313     23.343      0.000       6.687       7.915
# x16           -0.4087      0.547     -0.747      0.456      -1.483       0.666
# x17            4.6768      0.317     14.756      0.000       4.055       5.299
# x18           -0.1701      0.439     -0.388      0.698      -1.031       0.691
# x19            0.6786      0.325      2.088      0.037       0.041       1.316
# x20           -0.0851      0.228     -0.373      0.709      -0.533       0.363
# x21           -0.0531      0.222     -0.239      0.811      -0.489       0.382
# x22            0.0731      0.205      0.356      0.722      -0.329       0.476
# x23           -0.1563      0.213     -0.735      0.462      -0.574       0.261
# x24            0.0929      0.231      0.401      0.688      -0.361       0.547
# x25            0.3008      0.217      1.388      0.166      -0.125       0.726
# x26            0.2579      0.218      1.181      0.238      -0.171       0.686
# x27           -0.2319      0.223     -1.041      0.298      -0.669       0.205
# x28            0.3113      0.235      1.323      0.186      -0.151       0.773
# x29           -0.0959      0.234     -0.410      0.682      -0.555       0.363
# x30            0.1116      1.086      0.103      0.918      -2.021       2.244
# x31           -0.4917      0.810     -0.607      0.544      -2.081       1.098
# x32           -0.2770      0.806     -0.344      0.731      -1.860       1.306
# x33           -0.8045      1.119     -0.719      0.472      -3.001       1.392
# x34           -0.5809      1.159     -0.501      0.616      -2.855       1.693
# x35           -0.7482      0.860     -0.870      0.385      -2.436       0.940
# x36           -0.6982      0.620     -1.126      0.261      -1.916       0.519
# x37           -1.4868      1.385     -1.074      0.283      -4.205       1.232
# x38           -0.5898      0.265     -2.228      0.026      -1.109      -0.070
# x39           -0.1500      0.307     -0.489      0.625      -0.752       0.452
# x40           -0.0330      0.342     -0.096      0.923      -0.705       0.639
# x41            0.0552      0.258      0.214      0.831      -0.451       0.562
# x42            0.1073      0.254      0.423      0.672      -0.390       0.605
# x43           -0.4236      0.419     -1.010      0.313      -1.247       0.399
# x44           -0.0189      0.237     -0.080      0.936      -0.483       0.445
# x45           -0.1731      0.215     -0.806      0.421      -0.595       0.249
# x46            0.1492      0.218      0.685      0.494      -0.278       0.577
# x47            0.0478      0.219      0.218      0.827      -0.382       0.478
# x48           -0.1524      0.247     -0.616      0.538      -0.638       0.333
# x49           -0.0840      0.212     -0.396      0.692      -0.500       0.332
# x50           -0.1304      0.213     -0.613      0.540      -0.548       0.287
# x51           -0.0041      0.253     -0.016      0.987      -0.501       0.492
# x52            0.5890      0.327      1.800      0.072      -0.053       1.231
# x53            0.0976      0.222      0.441      0.660      -0.337       0.533
# x54            0.2057      0.243      0.848      0.397      -0.270       0.682
# x55            0.1800      0.237      0.759      0.448      -0.285       0.645
# x56            0.0227      0.217      0.104      0.917      -0.404       0.449
# x57            0.1066      0.382      0.279      0.780      -0.644       0.857
# x58            0.2578      0.266      0.970      0.332      -0.264       0.779
# x59            0.1078      0.131      0.825      0.409      -0.149       0.364
# x60           -0.2522      0.220     -1.148      0.251      -0.683       0.179
# x61           -0.1939      0.216     -0.897      0.370      -0.618       0.230
# x62            0.3788      0.241      1.572      0.116      -0.094       0.852
# x63           -0.3446      0.246     -1.401      0.161      -0.827       0.138
# x64           -0.0562      0.262     -0.215      0.830      -0.570       0.458
# x65           -0.0832      0.235     -0.354      0.724      -0.545       0.379
# x66           -0.3577      0.235     -1.520      0.129      -0.819       0.104
# x67            0.3830      0.212      1.809      0.071      -0.033       0.799
# x68           -0.0475      0.234     -0.203      0.839      -0.508       0.413
# x69            0.0940      0.333      0.283      0.778      -0.559       0.747
# x70           -0.0870      0.147     -0.593      0.553      -0.375       0.201
# x71            0.1547      0.178      0.870      0.385      -0.195       0.504
# x72            0.4655      0.164      2.831      0.005       0.143       0.788
# x73           -0.3920      0.139     -2.823      0.005      -0.665      -0.119
# x74            0.0017      0.221      0.008      0.994      -0.431       0.435
# x75            0.0317      0.202      0.157      0.875      -0.364       0.428
# x76           -0.0531      0.174     -0.305      0.761      -0.395       0.289
# x77           -0.3127      0.153     -2.043      0.041      -0.613      -0.012
# x78            0.2949      0.151      1.956      0.051      -0.001       0.591
# x79            0.0496      0.201      0.247      0.805      -0.344       0.443
# x80            0.0679      0.207      0.328      0.743      -0.339       0.474
# x81           -0.0692      0.201     -0.344      0.731      -0.463       0.325
# x82           -0.2382      0.218     -1.094      0.274      -0.665       0.189
# x83            0.1110      0.203      0.546      0.585      -0.288       0.510
# x84            0.0669      0.198      0.337      0.736      -0.323       0.456
# x85           -0.0044      0.204     -0.021      0.983      -0.406       0.397
# x86           -0.0161      0.207     -0.078      0.938      -0.423       0.391
# x87            0.0941      0.207      0.455      0.649      -0.312       0.500
# x88            0.1495      0.202      0.741      0.459      -0.247       0.546
# x89            0.1078      0.131      0.825      0.409      -0.149       0.364
# ==============================================================================
# Omnibus:                       16.321   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.814
# Skew:                          -0.005   Prob(JB):                     3.36e-07
# Kurtosis:                       3.888   Cond. No.                     4.19e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.17e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from math import sqrt
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
rms = sqrt(mean_squared_error(y_test,y_pred))
rms
# Out:
# 36.78801440500139
# 4.258877702721786
# 6.065312391377825

# %% [markdown]
# ## Apply ridge regression

# %%
rm = RidgeCV() 
rm.fit(X_train_scale, y_train)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]))

# %%
list(zip(oscars_data.drop(columns='metacritic score'),rm.coef_))
# Out:
# [('runtime (mins)', -0.28032637051411413),
#  ('budget', -1.0801891499148928),
#  ('Total_Noms', 2.573193559317982),
#  ('Avg_Award_Score', 0.623498164795306),
#  ('Awards_Best Actor in a Leading Role', 0.24474963191455967),
#  ('Awards_Best Actor in a Supporting Role', 0.309787776060805),
#  ('Awards_Best Actress in a Leading Role', 0.34147496174123515),
#  ('Awards_Best Art Direction-Set Decoration', -0.3506062689099778),
#  ('Awards_Best Cinematography', -0.041799866181015055),
#  ('Awards_Best Director', 0.2004358776278785),
#  ('Awards_Best Film Editing', -0.37423310765476536),
#  ('Awards_Best Motion Picture of the Year', -0.43288756022113795),
#  ('Awards_Best Picture', 0.5946326183898307),
#  ('Awards_Best Sound', -0.09840617100269222),
#  ('Director_Avg_Score', 7.174248235877856),
#  ('Total_Director_Movies', -0.3102038514048262),
#  ('Lead_Actor_Avg_Score', 4.694765444382194),
#  ('Total_Movies_Lead_Actor', -0.17288308972375432),
#  ('Avg_Rating_by_Genre', 0.6924792759935077),
#  ('Buena Vista Pictures', -0.08713748694252388),
#  ('Columbia Pictures', -0.0615341038755961),
#  ('Fox Searchlight Pictures', 0.0768161133804719),
#  ('Miramax', -0.14719078057757562),
#  ('Paramount Pictures', 0.07447256209113284),
#  ('Sony Pictures Classics', 0.3055492152526651),
#  ('Twentieth Century Fox', 0.24693836076859155),
#  ('Universal Pictures', -0.2290304364538045),
#  ('Walt Disney Studios Motion Pictures', 0.2970964153155915),
#  ('Warner Bros.', -0.10136079497633466),
#  ('Genre_Action', 0.5645725621857958),
#  ('Genre_Adventure', -0.1397679814162398),
#  ('Genre_Animation', 0.08095361185456973),
#  ('Genre_Biography', -0.30227764402310253),
#  ('Genre_Comedy', -0.05011863207878875),
#  ('Genre_Crime', -0.3651893908057757),
#  ('Genre_Documentary', -0.40614492963813653),
#  ('Genre_Drama', -0.8160490521183963),
#  ('Genre_Fantasy', -0.5086608681666078),
#  ('Genre_Horror', -0.04646512853572293),
#  ('Subgenre_Adventure', -0.025708878849333594),
#  ('Subgenre_Comedy', 0.060307165305483856),
#  ('Subgenre_Crime', 0.10683231087681744),
#  ('Subgenre_Drama', -0.417539868323237),
#  ('Subgenre_Fantasy', -0.023601908495041846),
#  ('Subgenre_History', -0.17681137733388597),
#  ('Subgenre_Music', 0.14503624830559936),
#  ('Subgenre_Mystery', 0.03728660042273546),
#  ('Subgenre_Romance', -0.15587639801674913),
#  ('Subgenre_Thriller', -0.0700013271988218),
#  ('Director_Barry Levinson', -0.142729093499657),
#  ('Director_Clint Eastwood', -0.02388789991092466),
#  ('Director_Martin Scorsese', 0.5427545729478549),
#  ('Director_Ridley Scott', 0.08851660120162741),
#  ('Director_Robert Zemeckis', 0.18335092572300482),
#  ('Director_Ron Howard', 0.15083364732658033),
#  ('Director_Stephen Frears', 0.011447320672751449),
#  ('Director_Steven Spielberg', 0.06827971769830121),
#  ('Director_Tim Burton', 0.23855524440549214),
#  ('Director_Woody Allen', 0.0942932403592156),
#  ('Lead_Actor_Brad Pitt', -0.25165241610768874),
#  ('Lead_Actor_Harrison Ford', -0.1832624300175686),
#  ('Lead_Actor_Johnny Depp', 0.36453738167782035),
#  ('Lead_Actor_Leonardo DiCaprio', -0.3397840954607041),
#  ('Lead_Actor_Meryl Streep', -0.05748323352778861),
#  ('Lead_Actor_Michael Douglas', -0.08121483714262645),
#  ('Lead_Actor_Robert De Niro', -0.35076953548426193),
#  ('Lead_Actor_Robin Williams', 0.3603528510191456),
#  ('Lead_Actor_Tom Cruise', -0.04983117732700304),
#  ('Lead_Actor_Tom Hanks', 0.09428731204128615),
#  ('Fall', -0.0940302308808807),
#  ('Spring', 0.15407520879369585),
#  ('Summer', 0.46773357950796424),
#  ('Winter', -0.38689380424268993),
#  ('G', 0.008374646319985413),
#  ('Not Rated', 0.03745927224473622),
#  ('PG', -0.04815597717129583),
#  ('PG-13', -0.31963689374203863),
#  ('R', 0.29340969550508755),
#  ('Unrated', 0.04770697178432165),
#  ('Writer_Aaron Sorkin', 0.060489828808011126),
#  ('Writer_Joel Coen', -0.07223821436331601),
#  ('Writer_John Logan', -0.23154472612738308),
#  ('Writer_Lawrence Kasdan', 0.10969332006655819),
#  ('Writer_Paul Thomas Anderson', 0.06591573703662235),
#  ('Writer_Pedro Almodóvar', -0.0016565187175867635),
#  ('Writer_Peter Morgan', -0.018335438589594244),
#  ('Writer_Quentin Tarantino', 0.08193921369681334),
#  ('Writer_William Shakespeare', 0.1351753857888135),
#  ('Writer_Woody Allen', 0.09429324035922804)]

# %%
y_pred = rm.predict(X_test_scale)

# %%
rm.score(X_train_scale,y_train)
# Out:
# 0.8401805949707286

# %%
rm.score(X_test_scale,y_test)
# Out:
# 0.7637860526744435

# %%
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
rms = sqrt(mean_squared_error(y_test,y_pred))
rms
# Out:
# 36.430544062125854
# 4.23455551073672
# 6.035772035301354

# %%
res_plot = residuals_plot(y_pred,y_test)
res_plot

# %%
scatter_plot = residual_scatter(y_pred,y_test)
scatter_plot

# %% [markdown]
# ## Model Without dummy variables

# %%
oscars_df_no_dummy = oscars_data[['metacritic score','budget','Total_Director_Movies','runtime (mins)','Total_Noms','Avg_Award_Score','Lead_Actor_Avg_Score','Director_Avg_Score','Total_Movies_Lead_Actor']]

# %%
oscars_df_no_dummy.corr()
# Out:
#                          metacritic score    budget  Total_Director_Movies  \
# metacritic score                 1.000000 -0.162162               0.045808
# budget                          -0.162162  1.000000               0.170166
# Total_Director_Movies            0.045808  0.170166               1.000000
# runtime (mins)                  -0.019315  0.232852               0.255501
# Total_Noms                       0.327954  0.075834               0.243436
# Avg_Award_Score                  0.472480 -0.067099               0.000174
# Lead_Actor_Avg_Score             0.798651 -0.119302              -0.014514
# Director_Avg_Score               0.843538 -0.120329               0.054304
# Total_Movies_Lead_Actor         -0.102874  0.193248               0.290773
#
#                          runtime (mins)  Total_Noms  Avg_Award_Score  \
# metacritic score              -0.019315    0.327954         0.472480
# budget                         0.232852    0.075834        -0.067099
# Total_Director_Movies          0.255501    0.243436         0.000174
# runtime (mins)                 1.000000    0.355896         0.086005
# Total_Noms                     0.355896    1.000000         0.289615
# Avg_Award_Score                0.086005    0.289615         1.000000
# Lead_Actor_Avg_Score          -0.045243    0.205334         0.435059
# Director_Avg_Score            -0.029389    0.180483         0.455920
# Total_Movies_Lead_Actor        0.209672    0.190182        -0.047617
#
#                          Lead_Actor_Avg_Score  Director_Avg_Score  \
# metacritic score                     0.798651            0.843538
# budget                              -0.119302           -0.120329
# Total_Director_Movies               -0.014514            0.054304
# runtime (mins)                      -0.045243           -0.029389
# Total_Noms                           0.205334            0.180483
# Avg_Award_Score                      0.435059            0.455920
# Lead_Actor_Avg_Score                 1.000000            0.730323
# Director_Avg_Score                   0.730323            1.000000
# Total_Movies_Lead_Actor             -0.128810           -0.105291
#
#                          Total_Movies_Lead_Actor
# metacritic score                       -0.102874
# budget                                  0.193248
# Total_Director_Movies                   0.290773
# runtime (mins)                          0.209672
# Total_Noms                              0.190182
# Avg_Award_Score                        -0.047617
# Lead_Actor_Avg_Score                   -0.128810
# Director_Avg_Score                     -0.105291
# Total_Movies_Lead_Actor                 1.000000

# %%
plt.figure(figsize=(40,40))
sns.heatmap(oscars_df_no_dummy.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>
